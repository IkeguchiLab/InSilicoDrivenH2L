# %%
# First we do a set of imports
import csv
from pprint import pprint
import cinnabar
from cinnabar import plotting as cinnabar_plotting
from cinnabar import femap, stats

# %%
# temporarily loaded for the creation of a TSV file, although it is not used
# read in the experimental data

experimental_data = {}
experimental_filename = '../../RBFE_validation/NES/H_pocket/star_map/experimental_core1.tsv'

with open(experimental_filename, 'r') as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"')
    headers = next(rd)
    for row in rd:
        experimental_data[row[0]] = {}
        experimental_data[row[0]]['dG'] = float(row[1])
        experimental_data[row[0]]['ddG'] = float(row[2])

pprint(experimental_data)
# Out:
# {'lig_1': {'dG': -8.56, 'ddG': 0.0},
#  'lig_2': {'dG': -9.08, 'ddG': 0.0},
#  'lig_3': {'dG': -9.85, 'ddG': 0.0},
#  'lig_4': {'dG': -9.39, 'ddG': 0.0},
#  'lig_5': {'dG': -10.91, 'ddG': 0.0},
#  'lig_6': {'dG': -9.64, 'ddG': 0.0},
#  'lig_7': {'dG': -10.37, 'ddG': 0.0},
#  'lig_8': {'dG': -9.35, 'ddG': 0.0},
#  'lig_9': {'dG': -10.17, 'ddG': 0.0}}

# %%
# Read in calculated results

calculated_data = {}
calculated_filename = './final_results_core4_R1_star.tsv'

with open(calculated_filename, 'r') as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"')
    headers = next(rd)
    for row in rd:
        tag = row[0] + "->" + row[1]
        calculated_data[tag] = {}
        calculated_data[tag]['ligand_i'] = row[0]
        calculated_data[tag]['ligand_j'] = row[1]
        calculated_data[tag]['dG'] = float(row[2])
        calculated_data[tag]['ddG'] = float(row[3])

pprint(calculated_data)
# Out:
# {'lig_4-99->lig_1-1': {'dG': -2.02,
#                        'ddG': 0.01,
#                        'ligand_i': 'lig_4-99',
#                        'ligand_j': 'lig_1-1'},
#  'lig_4-99->lig_10046-1': {'dG': -4.5,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10046-1'},
#  'lig_4-99->lig_10084-1': {'dG': -3.9300000000000033,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10084-1'},
#  'lig_4-99->lig_10092-6': {'dG': -0.370000000000001,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10092-6'},
#  'lig_4-99->lig_10092-8': {'dG': 0.6699999999999999,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10092-8'},
#  'lig_4-99->lig_10106-2': {'dG': -2.3500000000000005,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10106-2'},
#  'lig_4-99->lig_10106-3': {'dG': 0.4199999999999999,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10106-3'},
#  'lig_4-99->lig_10106-8': {'dG': -5.539999999999999,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10106-8'},
#  'lig_4-99->lig_10117-1': {'dG': -5.75,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10117-1'},
#  'lig_4-99->lig_10134-1': {'dG': -1.2100000000000009,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10134-1'},
#  'lig_4-99->lig_10134-2': {'dG': -0.7899999999999991,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10134-2'},
#  'lig_4-99->lig_10139-1': {'dG': -2.640000000000001,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10139-1'},
#  'lig_4-99->lig_10186-2': {'dG': -1.23,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10186-2'},
#  'lig_4-99->lig_10202-1': {'dG': -3.4,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10202-1'},
#  'lig_4-99->lig_10202-2': {'dG': -3.85,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10202-2'},
#  'lig_4-99->lig_10204-1': {'dG': -3.28,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10204-1'},
#  'lig_4-99->lig_10205-1': {'dG': -2.18,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10205-1'},
#  'lig_4-99->lig_10205-2': {'dG': -1.2599999999999998,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_10205-2'},
#  'lig_4-99->lig_10213-1': {'dG': -2.43,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_4-99',
#                            'ligand_j': 'lig_

#                           'ddG': 0.01,
#                           'ligand_i': 'lig_4-99',
#                           'ligand_j': 'lig_9792-3'},
#  'lig_4-99->lig_9812-1': {'dG': -4.629999999999999,
#                           'ddG': 0.01,
#                           'ligand_i': 'lig_4-99',
#                           'ligand_j': 'lig_9812-1'},
#  'lig_4-99->lig_9923-1': {'dG': -3.1200000000000045,
#                           'ddG': 0.01,
#                           'ligand_i': 'lig_4-99',
#                           'ligand_j': 'lig_9923-1'},
#  'lig_4-99->lig_9953-1': {'dG': -4.970000000000006,
#                           'ddG': 0.01,
#                           'ligand_i': 'lig_4-99',
#                           'ligand_j': 'lig_9953-1'}}

# %%
cinnabar_filename = './final_results_core4_R1_star_cin.tsv'

with open(cinnabar_filename, 'w') as f:
    f.write("# Experimental block\n")
    f.write("# Ligand, expt_DDG, expt_dDDG\n")
    for entry in experimental_data:
        dG = experimental_data[entry]['dG']
        ddG = experimental_data[entry]['ddG']
        f.write(f"{entry},{dG:.2f},{ddG:.2f}\n")
    f.write('\n')
    f.write('# Calculated block\n')
    f.write('# Ligand1,Ligand2,calc_DDG,calc_dDDG(MBAR),calc_dDDG(additional)\n')
    for entry in calculated_data:
        dG = calculated_data[entry]['dG']
        ddG = calculated_data[entry]['ddG']
        molA = calculated_data[entry]['ligand_i']
        molB = calculated_data[entry]['ligand_j']
        f.write(f"{molA},{molB},{dG:.2f},0,{ddG:.2f}\n")

# %%
fe = femap.FEMap.from_csv('./final_results_core4_R1_star_cin.tsv')
fe.generate_absolute_values()  # Get MLE generated estimates of the absolute values
fe.draw_graph()
fe.generate_absolute_values()
# Out:
# /home/hiroyuki/miniforge3/envs/openfe_env/lib/python3.12/site-packages/cinnabar/femap.py:35: UserWarning: Assuming kcal/mol units on measurements
#   warnings.warn("Assuming kcal/mol units on measurements")

# %%
dG_results = {}
nodes = list(fe.to_legacy_graph().nodes.data())
print(nodes)


for key in range(len(nodes)):
    dG_results[nodes[key][0]] = {
        #'experimental_estimate': nodes[key][1]['exp_DG'],
        #'experimental_error': nodes[key][1]['exp_dDG'],
        'calculated_estimate': round(nodes[key][1]['calc_DG'],2),
        'calculated_error': round(nodes[key][1]['calc_dDG'],2),
    }

# write out the calculated results
# set the DE(MLE) of "lig_4-99" as the reference to 0
with open('./cinnabar_output_core4_star.dat', 'w') as f:
    writer = csv.writer(f, delimiter="\t", lineterminator="\n")
    writer.writerow(["ligand", "DG(MLE)", "uncertainty (kcal/mol)",])
    for ligand in dG_results:
        writer.writerow([
            ligand,
            dG_results[ligand]['calculated_estimate']-1.87,
            dG_results[ligand]['calculated_error'],
        ])
        print(dG_results[ligand])
# Out:
# [('lig_4-99', {'calc_DG': 1.8707343857240906, 'calc_dDG': 0.00026189133875551007}), ('lig_1-1', {'calc_DG': -0.1492656142765113, 'calc_dDG': 0.009996565345841164}), ('lig_10046-1', {'calc_DG': -2.6292656142756026, 'calc_dDG': 0.009996565345840924}), ('lig_10084-1', {'calc_DG': -2.0592656142764385, 'calc_dDG': 0.009996565345841039}), ('lig_10092-6', {'calc_DG': 1.5007343857239077, 'calc_dDG': 0.009996565345841348}), ('lig_10092-8', {'calc_DG': 2.540734385724109, 'calc_dDG': 0.009996565345841412}), ('lig_10106-2', {'calc_DG': -0.47926561427506026, 'calc_dDG': 0.009996565345841535}), ('l
70073438572409, 'calc_dDG': 0.009996565345841143}), ('lig_10597-1', {'calc_DG': -3.829265614275915, 'calc_dDG': 0.009996565345841145}), ('lig_10599-1', {'calc_DG': -2.669265614275902, 'calc_dDG': 0.009996565345841138}), ('lig_10599-2', {'calc_DG': -1.2892656142759207, 'calc_dDG': 0.009996565345841148}), ('lig_106-1', {'calc_DG': 2.2907343857241034, 'calc_dDG': 0.00999656534584115}), ('lig_10675-1', {'calc_DG': -0.7892656142759172, 'calc_dDG': 0.009996565345841143}), ('lig_10677-1', {'calc_DG': 1.000734385724079, 'calc_dDG': 0.009996565345841138}), ('lig_10703-1', {'calc_DG': 2.6907343857240726, 'calc_dDG': 0.009996565345841143}), ('lig_10715-1', {'calc_DG': 0.9307343857240823, 'calc_dDG ...
# {'calculated_estimate': 1.87, 'calculated_error': 0.0}
# {'calculated_estimate': -0.15, 'calculated_error': 0.01}
# {'calculated_estimate': -2.63, 'calculated_error': 0.01}
# {'calculated_estimate': -2.06, 'calculated_error': 0.01}
# {'calculated_estimate': 1.5, 'calculated_error': 0.01}
# {'calculated_estimate': 2.54, 'calculated_error': 0.01}
# {'calculated_estimate': -0.48, 'calculated_error': 0.01}
# {'calculated_estimate': 2.29, 'calculated_error': 0.01}
# {'calculated_estimate': -3.67, 'calculated_error': 0.01}
# {'calculated_estimate': -3.88, 'calculated_error': 0.01}
# {'calculated_estimate': 0.66, 'calculated_error': 0.01}
# {'calculated_estimate': 1.08, 'calculated_error': 0.01}
# {'calculated_estimate': -0.77, 'calculated_error': 0.01}
# {'calculated_estimate': 0.64, 'calculated_error': 0.01}
# {'calculated_estimate': -1.53, 'calculated_error': 0.01}
# {'calculated_estimate': -1.98, 'calculated_error': 0.01}
# {'calculated_estimate': -1.41, 'calculated_error': 0.01}
# {'calculated_estimate': -0.31, 'calculated_error': 0.01}
# {'calculated_estimate': 0.61, 'calculated_error': 0.01}
# {'calculated_estimate': -0.56, 'calculated_error': 0.01}
# {'calculated_estimate': -0.34, 'calculated_error': 0.01}
# {'calculated_estimate': 1.78, 'calculated_error': 0.01}
# {'calculated_estimate': 5.23, 'calculated_error': 0.01}
# {'calculated_estimate': 1.48, 'calculated_error': 0.01}
# {'calculated_estimate': 1.34, 'calculated_error': 0.01}
# {'calculated_estimate': 4.39, 'calculated_error': 0.01}
# {'calculated_estimate': 2.86, 'calculated_error': 0.01}
# {'calculated_estimate': -0.51, 'calculated_error': 0.01}
# {'calculated_estimate': 1.15, 'calculated_error': 0.01}
# {'calculated_estimate': 2.32, 'calculated_error': 0.01}
# {'calculated_estimate': -3.64, 'calculated_error': 0.01}
# {'calculated_estimate': -4.4, 'calculated_error': 0.01}
# {'calculated_estimate': -3.07, 'calculated_error': 0.01}
# {'calculated_estimate': 0.05, 'calculated_error': 0.01}
# {'calculated_estimate': -2.71, 'calculated_error': 0.01}
# {'calculated_estimate': -0.44, 'calculated_error': 0.01}
# {'calculated_estimate': 1.34, 'calculated_error': 0.01}
# {'calculated_estimate': 1.11, 'calculated_error': 0.01}
# {'calculated_estimate': -2.05, 'calculated_error': 0.01}
# {'calculated_estimate': 2.7, 'calculated_error': 0.01}
# {'calculated_estimate': -3.83, 'calculated_error': 0.01}
# {'calculated_estimate': -2.67, 'calculated_error': 0.01}
# {'calculated_estimate': -1.29, 'calculated_error': 0.01}
# {'calculated_estimate': 2.29, 'calculated_error': 0.01}
# {'calculated_estimate': -0.79, 'calculated_error': 0.01}
# {'calculated_estimate': 1.0, 'calculated_error': 0.01}
# {'calculated_estimate': 2.69, 'calculated_error': 0.01}
# {'calculated_estimate': 0.93, 'calculated_error': 0.01}
# {'calculated_estimate': 1.23, 'calculated_error': 0.01}
# {'calculated_estimate': 5.34, 'calculated_error': 0.01}
# {'calculated_estimate': -0.43, 'calculated_error': 0.01}
# {'calculated_estimate': -2.47, 'calculated_error': 0.01}
# {'calculated_estimate': -2.52, 'calculated_error': 0.01}
# {'calculated_estimate': -2.55, 'calculated_error': 0.01}
# {'calculated_estimate': -4.1, 'calculated_error': 0.01}
# {'calculated_estimate': -1.82, 'calculated_error': 0.01}
# {'calculated_estimate': -0.6, 'calculated_error': 0.01}
# {'calculated_estimate': -2.14, 'calculated_error': 0.01}
# {'calculated_estimate': -4.72, 'calculated_error': 0.01}
# {'calculated_estimate': -5.01, 'calculated_error': 0.01}
# {'calculated_estimate': -5.19, 'calculated_error': 0.01}
# {'calculated_estimate': -0.94, 'calculated_error': 0.01}
# {'calculated_estimate': 1.14, 'calculated_error': 0.01}
# {'calculated_estimate': -0.9, 'calculated_error': 0.01}
# {'calculated_estimate': 0.88, 'calculated_error': 0.01}
# {'calculated_estimate': 1.06, 'calculated_error': 0.01}
# {'calculated_estimate': -2.96, 'calculated_error': 0.01}
# {'calculated_estimate': -0.61, 'calculated_error': 0.01}
# {'calculated_estimate': -0.62, 'calculated_error': 0.01}
# {'calculated_estimate': -1.01, 'calculated_error': 0.01}
# {'calculated_estimate': 2.47, 'calculated_error': 0.01}
# {'calculated_estimate': 6.93, 'calculated_error': 0.01}
# {'calculated_estimate': 0.3, 'calculated_error': 0.01}
# {'calculated_estimate': -0.99, 'calculated_error': 0.01}
# {'calculated_estimate': -2.34, 'calculated_error': 0.01}
# {'calculated_estimate': -1.44, 'calculated_error': 0.01}
# {'calculated_estimate': -1.63, 'calculated_error': 0.01}
# {'calculated_estimate': -2.25, 'calculated_error': 0.01}
# {'calculated_estimate': -0.6, 'calculated_error': 0.01}
# {'calculated_estimate': -2.26, 'calculated_error': 0.01}
# {'calculated_estimate': 0.7, 'calculated_error': 0.01}
# {'calculated_estimate': 1.04, 'calculated_error': 0.01}
# {'calculated_estimate': -1.75, 'calculated_error': 0.01}
# {'calculated_estimate': 0.12, 'calculated_error': 0.01}
# {'calculated_estimate': -0.33, 'calculated_error': 0.01}
# {'calculated_estimate': 0.22, 'calculated_error': 0.01}
# {'calculated_estimate': -1.71, 'calculated_error': 0.01}
# {'calculated_estimate': -0.06, 'calculated_error': 0.01}
# {'calculated_estimate': -0.98, 'calculated_error': 0.01}
# {'calculated_estimate': 1.03, 'calculated_error': 0.01}
# {'calculated_estimate': 0.8, 'calculated_error': 0.01}
# {'calculated_estimate': -0.2, 'calculated_error': 0.01}
# {'calculated_estimate': 1.35, 'calculated_error': 0.01}
# {'calculated_estimate': -1.52, 'calculated_error': 0.01}
# {'calculated_estimate': -1.57, 'calculated_error': 0.01}
# {'calculated_estimate': 2.03, 'calculated_error': 0.01}
# {'calculated_estimate': -1.62, 'calculated_error': 0.01}
# {'calculated_estimate': 1.1, 'calculated_error': 0.01}
# {'calculated_estimate': 0.12, 'calculated_error': 0.01}
# {'calculated_estimate': 0.67, 'calculated_error': 0.01}
# {'calculated_estimate': -0.68, 'calculated_error': 0.01}
# {'calculated_estimate': -0.64, 'calculated_error': 0.01}
# {'calculated_estimate': -0.89, 'calculated_error': 0.01}
# {'calculated_estimate': -1.79, 'calculated_error': 0.01}
# {'calculated_estimate': 2.17, 'calculated_error': 0.01}
# {'calculated_estimate': 1.14, 'calculated_error': 0.01}
# {'calculated_estimate': -1.53, 'calculated_error': 0.01}
# {'calculated_estimate': -1.18, 'calculated_error': 0.01}
# {'calculated_estimate': -1.12, 'calculated_error': 0.01}
# {'calculated_estimate': 0.46, 'calculated_error': 0.01}
# {'calculated_estimate': -2.78, 'calculated_error': 0.01}
# {'calculated_estimate': -2.44, 'calculated_error': 0.01}
# {'calculated_estimate': -3.65, 'calculated_error': 0.01}
# {'calculated_estimate': -1.66, 'calculated_error': 0.01}
# {'calculated_estimate': -1.99, 'calculated_error': 0.01}
# {'calculated_estimate': 2.27, 'calculated_error': 0.01}
# {'calculated_estimate': 4.67, 'calculated_error': 0.01}
# {'calculated_estimate': -1.69, 'calculated_error': 0.01}
# {'calculated_estimate': 1.16, 'calculated_error': 0.01}
# {'calculated_estimate': -1.56, 'calculated_error': 0.01}
# {'calculated_estimate': -1.04, 'calculated_error': 0.01}
# {'calculated_estimate': -2.15, 'calculated_error': 0.01}
# {'calculated_estimate': 1.88, 'calculated_error': 0.01}
# {'calculated_estimate': 4.28, 'calculated_error': 0.01}
# {'calculated_estimate': 0.41, 'calculated_error': 0.01}
# {'calculated_estimate': -0.03, 'calculated_error': 0.01}
# {'calculated_estimate': -3.45, 'calculated_error': 0.01}
# {'calculated_estimate': -0.94, 'calculated_error': 0.01}
# {'calculated_estimate': -4.98, 'calculated_error': 0.01}
# {'calculated_estimate': -2.22, 'calculated_error': 0.01}
# {'calculated_estimate': 0.73, 'calculated_error': 0.01}
# {'calculated_estimate': -3.32, 'calculated_error': 0.01}
# {'calculated_estimate': -1.3, 'calculated_error': 0.01}
# {'calculated_estimate': -0.23, 'calculated_error': 0.01}
# {'calculated_estimate': -1.23, 'calculated_error': 0.01}
# {'calculated_estimate': 3.1, 'calculated_error': 0.01}
# {'calculated_estimate': -2.11, 'calculated_error': 0.01}
# {'calculated_estimate': -1.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.04, 'calculated_error': 0.01}
# {'calculated_estimate': 1.79, 'calculated_error': 0.01}
# {'calculated_estimate': -0.98, 'calculated_error': 0.01}
# {'calculated_estimate': 1.63, 'calculated_error': 0.01}
# {'calculated_estimate': 0.46, 'calculated_error': 0.01}
# {'calculated_estimate': -0.93, 'calculated_error': 0.01}
# {'calculated_estimate': 0.22, 'calculated_error': 0.01}
# {'calculated_estimate': -0.63, 'calculated_error': 0.01}
# {'calculated_estimate': 1.2, 'calculated_error': 0.01}
# {'calculated_estimate': 1.25, 'calculated_error': 0.01}
# {'calculated_estimate': -1.71, 'calculated_error': 0.01}
# {'calculated_estimate': -1.04, 'calculated_error': 0.01}
# {'calculated_estimate': 1.68, 'calculated_error': 0.01}
# {'calculated_estimate': 0.52, 'calculated_error': 0.01}
# {'calculated_estimate': -2.8, 'calculated_error': 0.01}
# {'calculated_estimate': -1.94, 'calculated_error': 0.01}
# {'calculated_estimate': 0.28, 'calculated_error': 0.01}
# {'calculated_estimate': 0.05, 'calculated_error': 0.01}
# {'calculated_estimate': 1.29, 'calculated_error': 0.01}
# {'calculated_estimate': -0.75, 'calculated_error': 0.01}
# {'calculated_estimate': -0.28, 'calculated_error': 0.01}
# {'calculated_estimate': 0.7, 'calculated_error': 0.01}
# {'calculated_estimate': -3.84, 'calculated_error': 0.01}
# {'calculated_estimate': -2.08, 'calculated_error': 0.01}
# {'calculated_estimate': -3.81, 'calculated_error': 0.01}
# {'calculated_estimate': -1.64, 'calculated_error': 0.01}
# {'calculated_estimate': 1.02, 'calculated_error': 0.01}
# {'calculated_estimate': 0.22, 'calculated_error': 0.01}
# {'calculated_estimate': -0.11, 'calculated_error': 0.01}
# {'calculated_estimate': 0.14, 'calculated_error': 0.01}
# {'calculated_estimate': -1.02, 'calculated_error': 0.01}
# {'calculated_estimate': -2.36, 'calculated_error': 0.01}
# {'calculated_estimate': -1.23, 'calculated_error': 0.01}
# {'calculated_estimate': -0.43, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': 0.65, 'calculated_error': 0.01}
# {'calculated_estimate': 1.4, 'calculated_error': 0.01}
# {'calculated_estimate': -0.11, 'calculated_error': 0.01}
# {'calculated_estimate': -1.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.03, 'calculated_error': 0.01}
# {'calculated_estimate': 1.93, 'calculated_error': 0.01}
# {'calculated_estimate': 1.93, 'calculated_error': 0.01}
# {'calculated_estimate': 0.01, 'calculated_error': 0.01}
# {'calculated_estimate': -1.19, 'calculated_error': 0.01}
# {'calculated_estimate': -0.66, 'calculated_error': 0.01}
# {'calculated_estimate': -0.12, 'calculated_error': 0.01}
# {'calculated_estimate': -1.47, 'calculated_error': 0.01}
# {'calculated_estimate': -1.81, 'calculated_error': 0.01}
# {'calculated_estimate': -0.68, 'calculated_error': 0.01}
# {'calculated_estimate': -0.97, 'calculated_error': 0.01}
# {'calculated_estimate': 0.58, 'calculated_error': 0.01}
# {'calculated_estimate': 1.32, 'calculated_error': 0.01}
# {'calculated_estimate': 1.67, 'calculated_error': 0.01}
# {'calculated_estimate': -0.69, 'calculated_error': 0.01}
# {'calculated_estimate': 2.27, 'calculated_error': 0.01}
# {'calculated_estimate': 2.25, 'calculated_error': 0.01}
# {'calculated_estimate': 1.83, 'calculated_error': 0.01}
# {'calculated_estimate': 0.67, 'calculated_error': 0.01}
# {'calculated_estimate': -0.52, 'calculated_error': 0.01}
# {'calculated_estimate': -3.93, 'calculated_error': 0.01}
# {'calculated_estimate': 3.93, 'calculated_error': 0.01}
# {'calculated_estimate': -1.74, 'calculated_error': 0.01}
# {'calculated_estimate': 0.94, 'calculated_error': 0.01}
# {'calculated_estimate': -0.61, 'calculated_error': 0.01}
# {'calculated_estimate': 1.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.36, 'calculated_error': 0.01}
# {'calculated_estimate': 0.43, 'calculated_error': 0.01}
# {'calculated_estimate': 0.34, 'calculated_error': 0.01}
# {'calculated_estimate': 0.24, 'calculated_error': 0.01}
# {'calculated_estimate': 1.46, 'calculated_error': 0.01}
# {'calculated_estimate': 0.18, 'calculated_error': 0.01}
# {'calculated_estimate': 2.92, 'calculated_error': 0.01}
# {'calculated_estimate': 0.64, 'calculated_error': 0.01}
# {'calculated_estimate': 6.45, 'calculated_error': 0.01}
# {'calculated_estimate': 1.58, 'calculated_error': 0.01}
# {'calculated_estimate': 1.05, 'calculated_error': 0.01}
# {'calculated_estimate': 2.03, 'calculated_error': 0.01}
# {'calculated_estimate': 0.29, 'calculated_error': 0.01}
# {'calculated_estimate': -0.65, 'calculated_error': 0.01}
# {'calculated_estimate': 2.02, 'calculated_error': 0.01}
# {'calculated_estimate': -2.65, 'calculated_error': 0.01}
# {'calculated_estimate': 0.69, 'calculated_error': 0.01}
# {'calculated_estimate': -0.59, 'calculated_error': 0.01}
# {'calculated_estimate': 1.28, 'calculated_error': 0.01}
# {'calculated_estimate': -0.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.1, 'calculated_error': 0.01}
# {'calculated_estimate': 1.26, 'calculated_error': 0.01}
# {'calculated_estimate': -4.47, 'calculated_error': 0.01}
# {'calculated_estimate': -0.44, 'calculated_error': 0.01}
# {'calculated_estimate': -3.48, 'calculated_error': 0.01}
# {'calculated_estimate': -1.1, 'calculated_error': 0.01}
# {'calculated_estimate': -1.84, 'calculated_error': 0.01}
# {'calculated_estimate': -0.85, 'calculated_error': 0.01}
# {'calculated_estimate': -1.56, 'calculated_error': 0.01}
# {'calculated_estimate': -0.52, 'calculated_error': 0.01}
# {'calculated_estimate': -2.06, 'calculated_error': 0.01}
# {'calculated_estimate': 0.38, 'calculated_error': 0.01}
# {'calculated_estimate': -0.04, 'calculated_error': 0.01}
# {'calculated_estimate': -0.25, 'calculated_error': 0.01}
# {'calculated_estimate': -0.85, 'calculated_error': 0.01}
# {'calculated_estimate': -3.39, 'calculated_error': 0.01}
# {'calculated_estimate': -0.9, 'calculated_error': 0.01}
# {'calculated_estimate': -1.69, 'calculated_error': 0.01}
# {'calculated_estimate': -2.45, 'calculated_error': 0.01}
# {'calculated_estimate': 3.44, 'calculated_error': 0.01}
# {'calculated_estimate': -1.01, 'calculated_error': 0.01}
# {'calculated_estimate': -1.94, 'calculated_error': 0.01}
# {'calculated_estimate': -0.83, 'calculated_error': 0.01}
# {'calculated_estimate': -1.06, 'calculated_error': 0.01}
# {'calculated_estimate': 0.48, 'calculated_error': 0.01}
# {'calculated_estimate': -0.42, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.01}
# {'calculated_estimate': -0.67, 'calculated_error': 0.01}
# {'calculated_estimate': -4.99, 'calculated_error': 0.01}
# {'calculated_estimate': -0.47, 'calculated_error': 0.01}
# {'calculated_estimate': -0.19, 'calculated_error': 0.01}
# {'calculated_estimate': -0.94, 'calculated_error': 0.01}
# {'calculated_estimate': 1.24, 'calculated_error': 0.01}
# {'calculated_estimate': -1.46, 'calculated_error': 0.01}
# {'calculated_estimate': 0.43, 'calculated_error': 0.01}
# {'calculated_estimate': 3.36, 'calculated_error': 0.01}
# {'calculated_estimate': 1.89, 'calculated_error': 0.01}
# {'calculated_estimate': 1.35, 'calculated_error': 0.01}
# {'calculated_estimate': 1.54, 'calculated_error': 0.01}
# {'calculated_estimate': 2.72, 'calculated_error': 0.01}
# {'calculated_estimate': -1.68, 'calculated_error': 0.01}
# {'calculated_estimate': -1.04, 'calculated_error': 0.01}
# {'calculated_estimate': -1.34, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': 1.26, 'calculated_error': 0.01}
# {'calculated_estimate': -0.67, 'calculated_error': 0.01}
# {'calculated_estimate': -0.65, 'calculated_error': 0.01}
# {'calculated_estimate': 1.72, 'calculated_error': 0.01}
# {'calculated_estimate': 0.84, 'calculated_error': 0.01}
# {'calculated_estimate': 0.85, 'calculated_error': 0.01}
# {'calculated_estimate': 2.43, 'calculated_error': 0.01}
# {'calculated_estimate': 4.59, 'calculated_error': 0.01}
# {'calculated_estimate': -4.52, 'calculated_error': 0.01}
# {'calculated_estimate': 2.29, 'calculated_error': 0.01}
# {'calculated_estimate': 3.35, 'calculated_error': 0.01}
# {'calculated_estimate': -0.11, 'calculated_error': 0.01}
# {'calculated_estimate': 3.55, 'calculated_error': 0.01}
# {'calculated_estimate': 2.25, 'calculated_error': 0.01}
# {'calculated_estimate': 5.75, 'calculated_error': 0.01}
# {'calculated_estimate': -0.25, 'calculated_error': 0.01}
# {'calculated_estimate': 2.04, 'calculated_error': 0.01}
# {'calculated_estimate': -0.46, 'calculated_error': 0.01}
# {'calculated_estimate': -1.13, 'calculated_error': 0.01}
# {'calculated_estimate': -1.53, 'calculated_error': 0.01}
# {'calculated_estimate': 1.39, 'calculated_error': 0.01}
# {'calculated_estimate': 1.64, 'calculated_error': 0.01}
# {'calculated_estimate': -2.3, 'calculated_error': 0.01}
# {'calculated_estimate': -0.5, 'calculated_error': 0.01}
# {'calculated_estimate': -1.49, 'calculated_error': 0.01}
# {'calculated_estimate': -1.11, 'calculated_error': 0.01}
# {'calculated_estimate': -0.62, 'calculated_error': 0.01}
# {'calculated_estimate': -1.6, 'calculated_error': 0.01}
# {'calculated_estimate': -0.73, 'calculated_error': 0.01}
# {'calculated_estimate': -1.62, 'calculated_error': 0.01}
# {'calculated_estimate': -0.94, 'calculated_error': 0.01}
# {'calculated_estimate': -3.25, 'calculated_error': 0.01}
# {'calculated_estimate': 0.42, 'calculated_error': 0.01}
# {'calculated_estimate': 0.45, 'calculated_error': 0.01}
# {'calculated_estimate': -0.13, 'calculated_error': 0.01}
# {'calculated_estimate': 1.39, 'calculated_error': 0.01}
# {'calculated_estimate': 1.38, 'calculated_error': 0.01}
# {'calculated_estimate': -1.76, 'calculated_error': 0.01}
# {'calculated_estimate': 1.01, 'calculated_error': 0.01}
# {'calculated_estimate': 3.07, 'calculated_error': 0.01}
# {'calculated_estimate': 0.12, 'calculated_error': 0.01}
# {'calculated_estimate': -2.58, 'calculated_error': 0.01}
# {'calculated_estimate': -0.22, 'calculated_error': 0.01}
# {'calculated_estimate': -2.05, 'calculated_error': 0.01}
# {'calculated_estimate': -2.11, 'calculated_error': 0.01}
# {'calculated_estimate': -0.35, 'calculated_error': 0.01}
# {'calculated_estimate': -1.17, 'calculated_error': 0.01}
# {'calculated_estimate': -1.78, 'calculated_error': 0.01}
# {'calculated_estimate': -0.84, 'calculated_error': 0.01}
# {'calculated_estimate': 1.68, 'calculated_error': 0.01}
# {'calculated_estimate': -0.17, 'calculated_error': 0.01}
# {'calculated_estimate': -0.86, 'calculated_error': 0.01}
# {'calculated_estimate': -1.52, 'calculated_error': 0.01}
# {'calculated_estimate': -0.33, 'calculated_error': 0.01}
# {'calculated_estimate': -2.45, 'calculated_error': 0.01}
# {'calculated_estimate': -1.17, 'calculated_error': 0.01}
# {'calculated_estimate': -0.7, 'calculated_error': 0.01}
# {'calculated_estimate': -3.71, 'calculated_error': 0.01}
# {'calculated_estimate': -0.8, 'calculated_error': 0.01}
# {'calculated_estimate': -0.93, 'calculated_error': 0.01}
# {'calculated_estimate': -0.5, 'calculated_error': 0.01}
# {'calculated_estimate': -2.84, 'calculated_error': 0.01}
# {'calculated_estimate': -0.58, 'calculated_error': 0.01}
# {'calculated_estimate': 1.76, 'calculated_error': 0.01}
# {'calculated_estimate': 0.52, 'calculated_error': 0.01}
# {'calculated_estimate': 0.05, 'calculated_error': 0.01}
# {'calculated_estimate': 1.09, 'calculated_error': 0.01}
# {'calculated_estimate': -1.29, 'calculated_error': 0.01}
# {'calculated_estimate': -0.88, 'calculated_error': 0.01}
# {'calculated_estimate': -0.61, 'calculated_error': 0.01}
# {'calculated_estimate': -3.09, 'calculated_error': 0.01}
# {'calculated_estimate': 1.66, 'calculated_error': 0.01}
# {'calculated_estimate': -0.58, 'calculated_error': 0.01}
# {'calculated_estimate': -0.6, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.01}
# {'calculated_estimate': 0.25, 'calculated_error': 0.01}
# {'calculated_estimate': -1.88, 'calculated_error': 0.01}
# {'calculated_estimate': -2.74, 'calculated_error': 0.01}
# {'calculated_estimate': 1.15, 'calculated_error': 0.01}
# {'calculated_estimate': 2.41, 'calculated_error': 0.01}
# {'calculated_estimate': -0.34, 'calculated_error': 0.01}
# {'calculated_estimate': -1.1, 'calculated_error': 0.01}
# {'calculated_estimate': 0.02, 'calculated_error': 0.01}
# {'calculated_estimate': -0.74, 'calculated_error': 0.01}
# {'calculated_estimate': -1.1, 'calculated_error': 0.01}
# {'calculated_estimate': 1.38, 'calculated_error': 0.01}
# {'calculated_estimate': -2.03, 'calculated_error': 0.01}
# {'calculated_estimate': -0.28, 'calculated_error': 0.01}
# {'calculated_estimate': 4.02, 'calculated_error': 0.01}
# {'calculated_estimate': 1.43, 'calculated_error': 0.01}
# {'calculated_estimate': 0.94, 'calculated_error': 0.01}
# {'calculated_estimate': -0.52, 'calculated_error': 0.01}
# {'calculated_estimate': -0.14, 'calculated_error': 0.01}
# {'calculated_estimate': 3.64, 'calculated_error': 0.01}
# {'calculated_estimate': -1.27, 'calculated_error': 0.01}
# {'calculated_estimate': -1.36, 'calculated_error': 0.01}
# {'calculated_estimate': 2.67, 'calculated_error': 0.01}
# {'calculated_estimate': -0.45, 'calculated_error': 0.01}
# {'calculated_estimate': -1.05, 'calculated_error': 0.01}
# {'calculated_estimate': 0.09, 'calculated_error': 0.01}
# {'calculated_estimate': -3.03, 'calculated_error': 0.01}
# {'calculated_estimate': 0.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.36, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.01}
# {'calculated_estimate': 1.43, 'calculated_error': 0.01}
# {'calculated_estimate': 0.73, 'calculated_error': 0.01}
# {'calculated_estimate': -0.46, 'calculated_error': 0.01}
# {'calculated_estimate': 3.48, 'calculated_error': 0.01}
# {'calculated_estimate': 2.73, 'calculated_error': 0.01}
# {'calculated_estimate': -0.2, 'calculated_error': 0.01}
# {'calculated_estimate': 0.49, 'calculated_error': 0.01}
# {'calculated_estimate': -2.02, 'calculated_error': 0.01}
# {'calculated_estimate': -3.99, 'calculated_error': 0.01}
# {'calculated_estimate': -0.92, 'calculated_error': 0.01}
# {'calculated_estimate': -2.54, 'calculated_error': 0.01}
# {'calculated_estimate': -2.05, 'calculated_error': 0.01}
# {'calculated_estimate': 1.36, 'calculated_error': 0.01}
# {'calculated_estimate': -0.7, 'calculated_error': 0.01}
# {'calculated_estimate': -1.24, 'calculated_error': 0.01}
# {'calculated_estimate': -0.78, 'calculated_error': 0.01}
# {'calculated_estimate': -0.5, 'calculated_error': 0.01}
# {'calculated_estimate': -0.53, 'calculated_error': 0.01}
# {'calculated_estimate': 1.26, 'calculated_error': 0.01}
# {'calculated_estimate': 0.31, 'calculated_error': 0.01}
# {'calculated_estimate': -0.13, 'calculated_error': 0.01}
# {'calculated_estimate': 0.61, 'calculated_error': 0.01}
# {'calculated_estimate': 1.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.71, 'calculated_error': 0.01}
# {'calculated_estimate': 0.96, 'calculated_error': 0.01}
# {'calculated_estimate': 3.61, 'calculated_error': 0.01}
# {'calculated_estimate': -0.04, 'calculated_error': 0.01}
# {'calculated_estimate': -0.84, 'calculated_error': 0.01}
# {'calculated_estimate': 1.88, 'calculated_error': 0.01}
# {'calculated_estimate': 1.25, 'calculated_error': 0.01}
# {'calculated_estimate': -1.76, 'calculated_error': 0.01}
# {'calculated_estimate': 2.19, 'calculated_error': 0.01}
# {'calculated_estimate': 1.02, 'calculated_error': 0.01}
# {'calculated_estimate': 1.08, 'calculated_error': 0.01}
# {'calculated_estimate': -1.69, 'calculated_error': 0.01}
# {'calculated_estimate': 1.92, 'calculated_error': 0.01}
# {'calculated_estimate': 0.12, 'calculated_error': 0.01}
# {'calculated_estimate': -3.08, 'calculated_error': 0.01}
# {'calculated_estimate': 0.46, 'calculated_error': 0.01}
# {'calculated_estimate': -0.43, 'calculated_error': 0.01}
# {'calculated_estimate': -1.48, 'calculated_error': 0.01}
# {'calculated_estimate': -1.88, 'calculated_error': 0.01}
# {'calculated_estimate': 0.05, 'calculated_error': 0.01}
# {'calculated_estimate': -2.13, 'calculated_error': 0.01}
# {'calculated_estimate': -1.75, 'calculated_error': 0.01}
# {'calculated_estimate': -2.01, 'calculated_error': 0.01}
# {'calculated_estimate': -1.62, 'calculated_error': 0.01}
# {'calculated_estimate': 2.63, 'calculated_error': 0.01}
# {'calculated_estimate': -3.24, 'calculated_error': 0.01}
# {'calculated_estimate': -1.87, 'calculated_error': 0.01}
# {'calculated_estimate': -0.56, 'calculated_error': 0.01}
# {'calculated_estimate': 1.58, 'calculated_error': 0.01}
# {'calculated_estimate': 0.75, 'calculated_error': 0.01}
# {'calculated_estimate': 0.04, 'calculated_error': 0.01}
# {'calculated_estimate': -1.38, 'calculated_error': 0.01}
# {'calculated_estimate': 2.66, 'calculated_error': 0.01}
# {'calculated_estimate': -1.15, 'calculated_error': 0.01}
# {'calculated_estimate': 2.14, 'calculated_error': 0.01}
# {'calculated_estimate': 1.84, 'calculated_error': 0.01}
# {'calculated_estimate': 2.05, 'calculated_error': 0.01}
# {'calculated_estimate': 1.43, 'calculated_error': 0.01}
# {'calculated_estimate': -1.25, 'calculated_error': 0.01}
# {'calculated_estimate': 4.22, 'calculated_error': 0.01}
# {'calculated_estimate': 0.68, 'calculated_error': 0.01}
# {'calculated_estimate': 2.03, 'calculated_error': 0.01}
# {'calculated_estimate': 0.98, 'calculated_error': 0.01}
# {'calculated_estimate': 3.48, 'calculated_error': 0.01}
# {'calculated_estimate': 0.1, 'calculated_error': 0.01}
# {'calculated_estimate': -1.46, 'calculated_error': 0.01}
# {'calculated_estimate': -0.39, 'calculated_error': 0.01}
# {'calculated_estimate': 2.33, 'calculated_error': 0.01}
# {'calculated_estimate': 4.65, 'calculated_error': 0.01}
# {'calculated_estimate': 1.61, 'calculated_error': 0.01}
# {'calculated_estimate': 2.58, 'calculated_error': 0.01}
# {'calculated_estimate': 4.33, 'calculated_error': 0.01}
# {'calculated_estimate': -1.35, 'calculated_error': 0.01}
# {'calculated_estimate': -0.95, 'calculated_error': 0.01}
# {'calculated_estimate': 0.68, 'calculated_error': 0.01}
# {'calculated_estimate': 1.93, 'calculated_error': 0.01}
# {'calculated_estimate': -1.48, 'calculated_error': 0.01}
# {'calculated_estimate': 0.19, 'calculated_error': 0.01}
# {'calculated_estimate': 1.9, 'calculated_error': 0.01}
# {'calculated_estimate': -1.97, 'calculated_error': 0.01}
# {'calculated_estimate': -3.4, 'calculated_error': 0.01}
# {'calculated_estimate': 2.98, 'calculated_error': 0.01}
# {'calculated_estimate': 1.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.21, 'calculated_error': 0.01}
# {'calculated_estimate': -2.65, 'calculated_error': 0.01}
# {'calculated_estimate': 0.74, 'calculated_error': 0.01}
# {'calculated_estimate': 1.6, 'calculated_error': 0.01}
# {'calculated_estimate': -0.41, 'calculated_error': 0.01}
# {'calculated_estimate': 0.86, 'calculated_error': 0.01}
# {'calculated_estimate': 0.56, 'calculated_error': 0.01}
# {'calculated_estimate': 0.06, 'calculated_error': 0.01}
# {'calculated_estimate': 0.33, 'calculated_error': 0.01}
# {'calculated_estimate': -3.33, 'calculated_error': 0.01}
# {'calculated_estimate': -0.93, 'calculated_error': 0.01}
# {'calculated_estimate': 0.67, 'calculated_error': 0.01}
# {'calculated_estimate': 2.87, 'calculated_error': 0.01}
# {'calculated_estimate': 4.29, 'calculated_error': 0.01}
# {'calculated_estimate': -3.65, 'calculated_error': 0.01}
# {'calculated_estimate': -0.72, 'calculated_error': 0.01}
# {'calculated_estimate': 0.11, 'calculated_error': 0.01}
# {'calculated_estimate': 1.58, 'calculated_error': 0.01}
# {'calculated_estimate': -2.44, 'calculated_error': 0.01}
# {'calculated_estimate': -2.58, 'calculated_error': 0.01}
# {'calculated_estimate': -0.7, 'calculated_error': 0.01}
# {'calculated_estimate': -3.31, 'calculated_error': 0.01}
# {'calculated_estimate': -2.13, 'calculated_error': 0.01}
# {'calculated_estimate': -1.31, 'calculated_error': 0.01}
# {'calculated_estimate': 2.83, 'calculated_error': 0.01}
# {'calculated_estimate': -2.47, 'calculated_error': 0.01}
# {'calculated_estimate': 0.25, 'calculated_error': 0.01}
# {'calculated_estimate': -2.99, 'calculated_error': 0.01}
# {'calculated_estimate': 2.04, 'calculated_error': 0.01}
# {'calculated_estimate': -1.38, 'calculated_error': 0.01}
# {'calculated_estimate': -2.32, 'calculated_error': 0.01}
# {'calculated_estimate': -1.63, 'calculated_error': 0.01}
# {'calculated_estimate': -0.87, 'calculated_error': 0.01}
# {'calculated_estimate': 0.28, 'calculated_error': 0.01}
# {'calculated_estimate': 3.25, 'calculated_error': 0.01}
# {'calculated_estimate': -1.07, 'calculated_error': 0.01}
# {'calculated_estimate': 0.8, 'calculated_error': 0.01}
# {'calculated_estimate': 0.76, 'calculated_error': 0.01}
# {'calculated_estimate': 1.3, 'calculated_error': 0.01}
# {'calculated_estimate': -0.52, 'calculated_error': 0.01}
# {'calculated_estimate': 3.61, 'calculated_error': 0.01}
# {'calculated_estimate': 1.82, 'calculated_error': 0.01}
# {'calculated_estimate': 0.92, 'calculated_error': 0.01}
# {'calculated_estimate': 1.11, 'calculated_error': 0.01}
# {'calculated_estimate': 0.15, 'calculated_error': 0.01}
# {'calculated_estimate': 1.85, 'calculated_error': 0.01}
# {'calculated_estimate': -4.1, 'calculated_error': 0.01}
# {'calculated_estimate': -0.05, 'calculated_error': 0.01}
# {'calculated_estimate': -2.32, 'calculated_error': 0.01}
# {'calculated_estimate': 1.4, 'calculated_error': 0.01}
# {'calculated_estimate': 5.65, 'calculated_error': 0.01}
# {'calculated_estimate': 0.11, 'calculated_error': 0.01}
# {'calculated_estimate': -1.54, 'calculated_error': 0.01}
# {'calculated_estimate': -3.32, 'calculated_error': 0.01}
# {'calculated_estimate': -0.15, 'calculated_error': 0.01}
# {'calculated_estimate': -0.45, 'calculated_error': 0.01}
# {'calculated_estimate': 3.42, 'calculated_error': 0.01}
# {'calculated_estimate': 1.62, 'calculated_error': 0.01}
# {'calculated_estimate': 1.54, 'calculated_error': 0.01}
# {'calculated_estimate': 2.77, 'calculated_error': 0.01}
# {'calculated_estimate': 1.76, 'calculated_error': 0.01}
# {'calculated_estimate': 5.05, 'calculated_error': 0.01}
# {'calculated_estimate': 2.34, 'calculated_error': 0.01}
# {'calculated_estimate': -0.77, 'calculated_error': 0.01}
# {'calculated_estimate': 0.73, 'calculated_error': 0.01}
# {'calculated_estimate': 1.39, 'calculated_error': 0.01}
# {'calculated_estimate': 3.13, 'calculated_error': 0.01}
# {'calculated_estimate': 2.23, 'calculated_error': 0.01}
# {'calculated_estimate': -3.61, 'calculated_error': 0.01}
# {'calculated_estimate': 0.76, 'calculated_error': 0.01}
# {'calculated_estimate': 0.46, 'calculated_error': 0.01}
# {'calculated_estimate': -3.71, 'calculated_error': 0.01}
# {'calculated_estimate': -1.6, 'calculated_error': 0.01}
# {'calculated_estimate': 1.98, 'calculated_error': 0.01}
# {'calculated_estimate': 1.51, 'calculated_error': 0.01}
# {'calculated_estimate': -0.09, 'calculated_error': 0.01}
# {'calculated_estimate': 0.32, 'calculated_error': 0.01}
# {'calculated_estimate': 4.94, 'calculated_error': 0.01}
# {'calculated_estimate': -0.33, 'calculated_error': 0.01}
# {'calculated_estimate': 2.86, 'calculated_error': 0.01}
# {'calculated_estimate': -4.31, 'calculated_error': 0.01}
# {'calculated_estimate': -2.56, 'calculated_error': 0.01}
# {'calculated_estimate': 0.65, 'calculated_error': 0.01}
# {'calculated_estimate': -0.12, 'calculated_error': 0.01}
# {'calculated_estimate': -0.62, 'calculated_error': 0.01}
# {'calculated_estimate': -2.03, 'calculated_error': 0.01}
# {'calculated_estimate': 2.35, 'calculated_error': 0.01}
# {'calculated_estimate': 1.23, 'calculated_error': 0.01}
# {'calculated_estimate': -1.1, 'calculated_error': 0.01}
# {'calculated_estimate': -0.03, 'calculated_error': 0.01}
# {'calculated_estimate': -1.51, 'calculated_error': 0.01}
# {'calculated_estimate': 1.35, 'calculated_error': 0.01}
# {'calculated_estimate': -2.25, 'calculated_error': 0.01}
# {'calculated_estimate': -0.18, 'calculated_error': 0.01}
# {'calculated_estimate': 1.22, 'calculated_error': 0.01}
# {'calculated_estimate': -0.44, 'calculated_error': 0.01}
# {'calculated_estimate': 0.76, 'calculated_error': 0.01}
# {'calculated_estimate': 2.19, 'calculated_error': 0.01}
# {'calculated_estimate': -4.57, 'calculated_error': 0.01}
# {'calculated_estimate': -2.18, 'calculated_error': 0.01}
# {'calculated_estimate': -0.62, 'calculated_error': 0.01}
# {'calculated_estimate': -0.91, 'calculated_error': 0.01}
# {'calculated_estimate': 5.34, 'calculated_error': 0.01}
# {'calculated_estimate': 4.5, 'calculated_error': 0.01}
# {'calculated_estimate': -0.85, 'calculated_error': 0.01}
# {'calculated_estimate': 0.81, 'calculated_error': 0.01}
# {'calculated_estimate': 0.57, 'calculated_error': 0.01}
# {'calculated_estimate': -0.54, 'calculated_error': 0.01}
# {'calculated_estimate': -2.13, 'calculated_error': 0.01}
# {'calculated_estimate': -1.99, 'calculated_error': 0.01}
# {'calculated_estimate': -0.22, 'calculated_error': 0.01}
# {'calculated_estimate': -0.06, 'calculated_error': 0.01}
# {'calculated_estimate': -0.3, 'calculated_error': 0.01}
# {'calculated_estimate': -0.26, 'calculated_error': 0.01}
# {'calculated_estimate': -1.49, 'calculated_error': 0.01}
# {'calculated_estimate': 0.24, 'calculated_error': 0.01}
# {'calculated_estimate': 0.62, 'calculated_error': 0.01}
# {'calculated_estimate': 1.02, 'calculated_error': 0.01}
# {'calculated_estimate': -1.0, 'calculated_error': 0.01}
# {'calculated_estimate': -2.79, 'calculated_error': 0.01}
# {'calculated_estimate': 0.92, 'calculated_error': 0.01}
# {'calculated_estimate': -0.83, 'calculated_error': 0.01}
# {'calculated_estimate': 1.25, 'calculated_error': 0.01}
# {'calculated_estimate': -3.57, 'calculated_error': 0.01}
# {'calculated_estimate': -0.46, 'calculated_error': 0.01}
# {'calculated_estimate': 0.67, 'calculated_error': 0.01}
# {'calculated_estimate': -0.01, 'calculated_error': 0.01}
# {'calculated_estimate': -0.85, 'calculated_error': 0.01}
# {'calculated_estimate': -2.31, 'calculated_error': 0.01}
# {'calculated_estimate': 1.24, 'calculated_error': 0.01}
# {'calculated_estimate': 4.52, 'calculated_error': 0.01}
# {'calculated_estimate': -0.85, 'calculated_error': 0.01}
# {'calculated_estimate': 0.62, 'calculated_error': 0.01}
# {'calculated_estimate': 0.6, 'calculated_error': 0.01}
# {'calculated_estimate': -1.14, 'calculated_error': 0.01}
# {'calculated_estimate': 0.44, 'calculated_error': 0.01}
# {'calculated_estimate': -3.58, 'calculated_error': 0.01}
# {'calculated_estimate': -2.5, 'calculated_error': 0.01}
# {'calculated_estimate': -1.71, 'calculated_error': 0.01}
# {'calculated_estimate': -1.9, 'calculated_error': 0.01}
# {'calculated_estimate': 0.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.3, 'calculated_error': 0.01}
# {'calculated_estimate': 0.35, 'calculated_error': 0.01}
# {'calculated_estimate': 2.32, 'calculated_error': 0.01}
# {'calculated_estimate': -3.24, 'calculated_error': 0.01}
# {'calculated_estimate': 2.18, 'calculated_error': 0.01}
# {'calculated_estimate': -0.81, 'calculated_error': 0.01}
# {'calculated_estimate': 3.49, 'calculated_error': 0.01}
# {'calculated_estimate': 1.27, 'calculated_error': 0.01}
# {'calculated_estimate': -0.85, 'calculated_error': 0.01}
# {'calculated_estimate': 5.64, 'calculated_error': 0.01}
# {'calculated_estimate': 3.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.88, 'calculated_error': 0.01}
# {'calculated_estimate': 0.39, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.01}
# {'calculated_estimate': -0.7, 'calculated_error': 0.01}
# {'calculated_estimate': -0.61, 'calculated_error': 0.01}
# {'calculated_estimate': 1.52, 'calculated_error': 0.01}
# {'calculated_estimate': 1.53, 'calculated_error': 0.01}
# {'calculated_estimate': -2.86, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': 3.68, 'calculated_error': 0.01}
# {'calculated_estimate': 0.02, 'calculated_error': 0.01}
# {'calculated_estimate': 1.99, 'calculated_error': 0.01}
# {'calculated_estimate': -0.4, 'calculated_error': 0.01}
# {'calculated_estimate': 3.47, 'calculated_error': 0.01}
# {'calculated_estimate': 0.72, 'calculated_error': 0.01}
# {'calculated_estimate': 0.49, 'calculated_error': 0.01}
# {'calculated_estimate': -0.53, 'calculated_error': 0.01}
# {'calculated_estimate': -1.84, 'calculated_error': 0.01}
# {'calculated_estimate': 1.14, 'calculated_error': 0.01}
# {'calculated_estimate': 3.61, 'calculated_error': 0.01}
# {'calculated_estimate': 1.36, 'calculated_error': 0.01}
# {'calculated_estimate': 1.26, 'calculated_error': 0.01}
# {'calculated_estimate': 0.35, 'calculated_error': 0.01}
# {'calculated_estimate': 0.46, 'calculated_error': 0.01}
# {'calculated_estimate': 1.78, 'calculated_error': 0.01}
# {'calculated_estimate': -2.59, 'calculated_error': 0.01}
# {'calculated_estimate': 0.93, 'calculated_error': 0.01}
# {'calculated_estimate': 0.02, 'calculated_error': 0.01}
# {'calculated_estimate': 0.06, 'calculated_error': 0.01}
# {'calculated_estimate': -0.55, 'calculated_error': 0.01}
# {'calculated_estimate': 0.62, 'calculated_error': 0.01}
# {'calculated_estimate': 4.47, 'calculated_error': 0.01}
# {'calculated_estimate': -0.04, 'calculated_error': 0.01}
# {'calculated_estimate': -1.21, 'calculated_error': 0.01}
# {'calculated_estimate': -1.56, 'calculated_error': 0.01}
# {'calculated_estimate': -2.47, 'calculated_error': 0.01}
# {'calculated_estimate': 0.36, 'calculated_error': 0.01}
# {'calculated_estimate': 0.2, 'calculated_error': 0.01}
# {'calculated_estimate': -1.0, 'calculated_error': 0.01}
# {'calculated_estimate': -0.14, 'calculated_error': 0.01}
# {'calculated_estimate': 2.46, 'calculated_error': 0.01}
# {'calculated_estimate': -2.47, 'calculated_error': 0.01}
# {'calculated_estimate': 3.2, 'calculated_error': 0.01}
# {'calculated_estimate': 1.45, 'calculated_error': 0.01}
# {'calculated_estimate': -2.13, 'calculated_error': 0.01}
# {'calculated_estimate': 0.71, 'calculated_error': 0.01}
# {'calculated_estimate': 0.38, 'calculated_error': 0.01}
# {'calculated_estimate': 1.01, 'calculated_error': 0.01}
# {'calculated_estimate': -0.58, 'calculated_error': 0.01}
# {'calculated_estimate': -1.34, 'calculated_error': 0.01}
# {'calculated_estimate': 2.59, 'calculated_error': 0.01}
# {'calculated_estimate': 1.13, 'calculated_error': 0.01}
# {'calculated_estimate': 2.66, 'calculated_error': 0.01}
# {'calculated_estimate': -3.09, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.01}
# {'calculated_estimate': -0.75, 'calculated_error': 0.01}
# {'calculated_estimate': -0.1, 'calculated_error': 0.01}
# {'calculated_estimate': 3.72, 'calculated_error': 0.01}
# {'calculated_estimate': 6.4, 'calculated_error': 0.01}
# {'calculated_estimate': 3.63, 'calculated_error': 0.01}
# {'calculated_estimate': 0.87, 'calculated_error': 0.01}
# {'calculated_estimate': 2.78, 'calculated_error': 0.01}
# {'calculated_estimate': -0.42, 'calculated_error': 0.01}
# {'calculated_estimate': 2.92, 'calculated_error': 0.01}
# {'calculated_estimate': 0.82, 'calculated_error': 0.01}
# {'calculated_estimate': -2.9, 'calculated_error': 0.01}
# {'calculated_estimate': 5.0, 'calculated_error': 0.01}
# {'calculated_estimate': -2.68, 'calculated_error': 0.01}
# {'calculated_estimate': -1.54, 'calculated_error': 0.01}
# {'calculated_estimate': 5.21, 'calculated_error': 0.01}
# {'calculated_estimate': 1.19, 'calculated_error': 0.01}
# {'calculated_estimate': 0.18, 'calculated_error': 0.01}
# {'calculated_estimate': 0.38, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': -1.1, 'calculated_error': 0.01}
# {'calculated_estimate': -2.16, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': 0.65, 'calculated_error': 0.01}
# {'calculated_estimate': 0.85, 'calculated_error': 0.01}
# {'calculated_estimate': 0.47, 'calculated_error': 0.01}
# {'calculated_estimate': -2.94, 'calculated_error': 0.01}
# {'calculated_estimate': -0.54, 'calculated_error': 0.01}
# {'calculated_estimate': 1.41, 'calculated_error': 0.01}
# {'calculated_estimate': 1.9, 'calculated_error': 0.01}
# {'calculated_estimate': 3.17, 'calculated_error': 0.01}
# {'calculated_estimate': 2.86, 'calculated_error': 0.01}
# {'calculated_estimate': 0.06, 'calculated_error': 0.01}
# {'calculated_estimate': 1.85, 'calculated_error': 0.01}
# {'calculated_estimate': -1.22, 'calculated_error': 0.01}
# {'calculated_estimate': 1.31, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': 0.67, 'calculated_error': 0.01}
# {'calculated_estimate': 3.51, 'calculated_error': 0.01}
# {'calculated_estimate': -1.89, 'calculated_error': 0.01}
# {'calculated_estimate': 3.03, 'calculated_error': 0.01}
# {'calculated_estimate': 3.43, 'calculated_error': 0.01}
# {'calculated_estimate': 0.81, 'calculated_error': 0.01}
# {'calculated_estimate': -0.89, 'calculated_error': 0.01}
# {'calculated_estimate': 2.63, 'calculated_error': 0.01}
# {'calculated_estimate': 2.53, 'calculated_error': 0.01}
# {'calculated_estimate': 2.78, 'calculated_error': 0.01}
# {'calculated_estimate': 2.34, 'calculated_error': 0.01}
# {'calculated_estimate': 2.06, 'calculated_error': 0.01}
# {'calculated_estimate': -1.17, 'calculated_error': 0.01}
# {'calculated_estimate': -1.08, 'calculated_error': 0.01}
# {'calculated_estimate': -0.9, 'calculated_error': 0.01}
# {'calculated_estimate': 1.49, 'calculated_error': 0.01}
# {'calculated_estimate': 0.94, 'calculated_error': 0.01}
# {'calculated_estimate': -0.55, 'calculated_error': 0.01}
# {'calculated_estimate': -5.4, 'calculated_error': 0.01}
# {'calculated_estimate': 3.19, 'calculated_error': 0.01}
# {'calculated_estimate': 0.68, 'calculated_error': 0.01}
# {'calculated_estimate': 0.49, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': 0.23, 'calculated_error': 0.01}
# {'calculated_estimate': 0.51, 'calculated_error': 0.01}
# {'calculated_estimate': 1.84, 'calculated_error': 0.01}
# {'calculated_estimate': 3.73, 'calculated_error': 0.01}
# {'calculated_estimate': -2.34, 'calculated_error': 0.01}
# {'calculated_estimate': -0.12, 'calculated_error': 0.01}
# {'calculated_estimate': -2.51, 'calculated_error': 0.01}
# {'calculated_estimate': -2.85, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.01}
# {'calculated_estimate': -2.61, 'calculated_error': 0.01}
# {'calculated_estimate': 0.52, 'calculated_error': 0.01}
# {'calculated_estimate': 4.51, 'calculated_error': 0.01}
# {'calculated_estimate': -1.51, 'calculated_error': 0.01}
# {'calculated_estimate': -0.58, 'calculated_error': 0.01}
# {'calculated_estimate': -2.42, 'calculated_error': 0.01}
# {'calculated_estimate': -1.58, 'calculated_error': 0.01}
# {'calculated_estimate': -0.48, 'calculated_error': 0.01}
# {'calculated_estimate': -0.7, 'calculated_error': 0.01}
# {'calculated_estimate': -1.17, 'calculated_error': 0.01}
# {'calculated_estimate': 3.59, 'calculated_error': 0.01}
# {'calculated_estimate': 1.16, 'calculated_error': 0.01}
# {'calculated_estimate': 0.11, 'calculated_error': 0.01}
# {'calculated_estimate': -1.96, 'calculated_error': 0.01}
# {'calculated_estimate': -1.87, 'calculated_error': 0.01}
# {'calculated_estimate': -1.22, 'calculated_error': 0.01}
# {'calculated_estimate': 0.49, 'calculated_error': 0.01}
# {'calculated_estimate': 1.17, 'calculated_error': 0.01}
# {'calculated_estimate': -1.55, 'calculated_error': 0.01}
# {'calculated_estimate': -2.53, 'calculated_error': 0.01}
# {'calculated_estimate': -1.41, 'calculated_error': 0.01}
# {'calculated_estimate': 0.87, 'calculated_error': 0.01}
# {'calculated_estimate': -3.24, 'calculated_error': 0.01}
# {'calculated_estimate': -3.12, 'calculated_error': 0.01}
# {'calculated_estimate': -3.0, 'calculated_error': 0.01}
# {'calculated_estimate': -0.64, 'calculated_error': 0.01}
# {'calculated_estimate': -3.83, 'calculated_error': 0.01}
# {'calculated_estimate': 2.45, 'calculated_error': 0.01}
# {'calculated_estimate': -1.33, 'calculated_error': 0.01}
# {'calculated_estimate': -5.49, 'calculated_error': 0.01}
# {'calculated_estimate': -3.65, 'calculated_error': 0.01}
# {'calculated_estimate': -1.89, 'calculated_error': 0.01}
# {'calculated_estimate': -2.24, 'calculated_error': 0.01}
# {'calculated_estimate': -0.89, 'calculated_error': 0.01}
# {'calculated_estimate': -1.3, 'calculated_error': 0.01}
# {'calculated_estimate': 1.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.78, 'calculated_error': 0.01}
# {'calculated_estimate': -2.05, 'calculated_error': 0.01}
# {'calculated_estimate': -1.32, 'calculated_error': 0.01}
# {'calculated_estimate': 2.72, 'calculated_error': 0.01}
# {'calculated_estimate': 2.13, 'calculated_error': 0.01}
# {'calculated_estimate': -0.86, 'calculated_error': 0.01}
# {'calculated_estimate': -0.53, 'calculated_error': 0.01}
# {'calculated_estimate': 1.76, 'calculated_error': 0.01}
# {'calculated_estimate': 2.97, 'calculated_error': 0.01}
# {'calculated_estimate': -0.61, 'calculated_error': 0.01}
# {'calculated_estimate': -1.18, 'calculated_error': 0.01}
# ...
# {'calculated_estimate': -0.49, 'calculated_error': 0.01}
# {'calculated_estimate': -0.89, 'calculated_error': 0.01}
# {'calculated_estimate': 0.99, 'calculated_error': 0.01}
# {'calculated_estimate': 1.26, 'calculated_error': 0.01}
# {'calculated_estimate': -0.49, 'calculated_error': 0.01}
# {'calculated_estimate': 2.09, 'calculated_error': 0.01}
# {'calculated_estimate': -2.2, 'calculated_error': 0.01}
# {'calculated_estimate': 0.48, 'calculated_error': 0.01}
# {'calculated_estimate': 1.04, 'calculated_error': 0.01}
# {'calculated_estimate': 3.4, 'calculated_error': 0.01}
# {'calculated_estimate': 0.66, 'calculated_error': 0.01}
# {'calculated_estimate': -1.27, 'calculated_error': 0.01}
# {'calculated_estimate': -4.27, 'calculated_error': 0.01}
# {'calculated_estimate': -5.08, 'calculated_error': 0.01}
# {'calculated_estimate': -5.12, 'calculated_error': 0.01}
# {'calculated_estimate': -1.68, 'calculated_error': 0.01}
# {'calculated_estimate': 3.01, 'calculated_error': 0.01}
# {'calculated_estimate': 1.21, 'calculated_error': 0.01}
# {'calculated_estimate': 1.63, 'calculated_error': 0.01}
# {'calculated_estimate': -2.61, 'calculated_error': 0.01}
# {'calculated_estimate': -2.09, 'calculated_error': 0.01}
# {'calculated_estimate': 1.51, 'calculated_error': 0.01}
# {'calculated_estimate': -1.71, 'calculated_error': 0.01}
# {'calculated_estimate': -1.9, 'calculated_error': 0.01}
# {'calculated_estimate': 1.02, 'calculated_error': 0.01}
# {'calculated_estimate': 0.69, 'calculated_error': 0.01}
# {'calculated_estimate': 1.67, 'calculated_error': 0.01}
# {'calculated_estimate': 3.67, 'calculated_error': 0.01}
# {'calculated_estimate': 2.49, 'calculated_error': 0.01}
# {'calculated_estimate': -0.32, 'calculated_error': 0.01}
# {'calculated_estimate': -0.13, 'calculated_error': 0.01}
# {'calculated_estimate': -0.74, 'calculated_error': 0.01}
# {'calculated_estimate': -3.22, 'calculated_error': 0.01}
# {'calculated_estimate': 0.79, 'calculated_error': 0.01}
# {'calculated_estimate': -0.73, 'calculated_error': 0.01}
# {'calculated_estimate': -1.99, 'calculated_error': 0.01}
# {'calculated_estimate': -1.83, 'calculated_error': 0.01}
# {'calculated_estimate': -2.12, 'calculated_error': 0.01}
# {'calculated_estimate': -1.7, 'calculated_error': 0.01}
# {'calculated_estimate': -1.8, 'calculated_error': 0.01}
# {'calculated_estimate': 1.81, 'calculated_error': 0.01}
# {'calculated_estimate': 0.09, 'calculated_error': 0.01}
# {'calculated_estimate': -0.3, 'calculated_error': 0.01}
# {'calculated_estimate': -1.48, 'calculated_error': 0.01}
# {'calculated_estimate': 0.07, 'calculated_error': 0.01}
# {'calculated_estimate': -1.23, 'calculated_error': 0.01}
# {'calculated_estimate': -2.0, 'calculated_error': 0.01}
# {'calculated_estimate': -2.28, 'calculated_error': 0.01}
# {'calculated_estimate': -3.39, 'calculated_error': 0.01}
# {'calculated_estimate': 1.83, 'calculated_error': 0.01}
# {'calculated_estimate': -1.31, 'calculated_error': 0.01}
# {'calculated_estimate': -0.45, 'calculated_error': 0.01}
# {'calculated_estimate': -2.13, 'calculated_error': 0.01}
# {'calculated_estimate': -2.13, 'calculated_error': 0.01}
# {'calculated_estimate': -0.23, 'calculated_error': 0.01}
# {'calculated_estimate': -1.54, 'calculated_error': 0.01}
# {'calculated_estimate': -3.76, 'calculated_error': 0.01}
# {'calculated_estimate': -0.14, 'calculated_error': 0.01}
# {'calculated_estimate': -1.36, 'calculated_error': 0.01}
# {'calculated_estimate': -3.53, 'calculated_error': 0.01}
# {'calculated_estimate': -4.0, 'calculated_error': 0.01}
# {'calculated_estimate': 0.12, 'calculated_error': 0.01}
# {'calculated_estimate': -0.23, 'calculated_error': 0.01}
# {'calculated_estimate': -0.99, 'calculated_error': 0.01}
# {'calculated_estimate': -2.74, 'calculated_error': 0.01}
# {'calculated_estimate': 1.66, 'calculated_error': 0.01}
# {'calculated_estimate': -0.03, 'calculated_error': 0.01}
# {'calculated_estimate': -0.52, 'calculated_error': 0.01}
# {'calculated_estimate': 2.29, 'calculated_error': 0.01}
# {'calculated_estimate': 5.69, 'calculated_error': 0.01}
# {'calculated_estimate': -0.13, 'calculated_error': 0.01}
# {'calculated_estimate': 0.72, 'calculated_error': 0.01}
# {'calculated_estimate': 1.02, 'calculated_error': 0.01}
# {'calculated_estimate': -0.62, 'calculated_error': 0.01}
# {'calculated_estimate': 0.6, 'calculated_error': 0.01}
# {'calculated_estimate': 0.97, 'calculated_error': 0.01}
# {'calculated_estimate': 2.9, 'calculated_error': 0.01}
# {'calculated_estimate': -0.87, 'calculated_error': 0.01}
# {'calculated_estimate': -0.75, 'calculated_error': 0.01}
# {'calculated_estimate': -0.96, 'calculated_error': 0.01}
# {'calculated_estimate': -1.32, 'calculated_error': 0.01}
# {'calculated_estimate': 0.57, 'calculated_error': 0.01}
# {'calculated_estimate': -2.77, 'calculated_error': 0.01}
# {'calculated_estimate': 0.16, 'calculated_error': 0.01}
# {'calculated_estimate': 0.01, 'calculated_error': 0.01}
# {'calculated_estimate': -0.33, 'calculated_error': 0.01}
# {'calculated_estimate': -0.1, 'calculated_error': 0.01}
# {'calculated_estimate': 5.51, 'calculated_error': 0.01}
# {'calculated_estimate': 5.86, 'calculated_error': 0.01}
# {'calculated_estimate': -1.89, 'calculated_error': 0.01}
# {'calculated_estimate': 0.73, 'calculated_error': 0.01}
# {'calculated_estimate': -1.74, 'calculated_error': 0.01}
# {'calculated_estimate': 0.87, 'calculated_error': 0.01}
# {'calculated_estimate': 0.97, 'calculated_error': 0.01}
# {'calculated_estimate': 0.86, 'calculated_error': 0.01}
# {'calculated_estimate': 4.49, 'calculated_error': 0.01}
# {'calculated_estimate': 0.12, 'calculated_error': 0.01}
# {'calculated_estimate': 0.1, 'calculated_error': 0.01}
# {'calculated_estimate': -1.93, 'calculated_error': 0.01}
# {'calculated_estimate': 3.22, 'calculated_error': 0.01}
# {'calculated_estimate': 3.89, 'calculated_error': 0.01}
# {'calculated_estimate': 1.03, 'calculated_error': 0.01}
# {'calculated_estimate': -2.93, 'calculated_error': 0.01}
# {'calculated_estimate': 1.51, 'calculated_error': 0.01}
# {'calculated_estimate': -1.08, 'calculated_error': 0.01}
# {'calculated_estimate': 0.12, 'calculated_error': 0.01}
# {'calculated_estimate': -1.81, 'calculated_error': 0.01}
# {'calculated_estimate': 1.91, 'calculated_error': 0.01}
# {'calculated_estimate': -0.01, 'calculated_error': 0.01}
# {'calculated_estimate': 0.25, 'calculated_error': 0.01}
# {'calculated_estimate': 1.91, 'calculated_error': 0.01}
# {'calculated_estimate': 0.11, 'calculated_error': 0.01}
# {'calculated_estimate': 2.74, 'calculated_error': 0.01}
# {'calculated_estimate': -0.78, 'calculated_error': 0.01}
# {'calculated_estimate': 1.81, 'calculated_error': 0.01}
# {'calculated_estimate': -0.03, 'calculated_error': 0.01}
# {'calculated_estimate': 0.89, 'calculated_error': 0.01}
# {'calculated_estimate': 2.35, 'calculated_error': 0.01}
# {'calculated_estimate': 1.45, 'calculated_error': 0.01}
# {'calculated_estimate': -1.13, 'calculated_error': 0.01}
# {'calculated_estimate': -0.21, 'calculated_error': 0.01}
# {'calculated_estimate': 2.19, 'calculated_error': 0.01}
# {'calculated_estimate': 3.14, 'calculated_error': 0.01}
# {'calculated_estimate': -0.58, 'calculated_error': 0.01}
# {'calculated_estimate': 1.52, 'calculated_error': 0.01}
# {'calculated_estimate': -0.78, 'calculated_error': 0.01}
# {'calculated_estimate': -0.44, 'calculated_error': 0.01}
# {'calculated_estimate': -0.82, 'calculated_error': 0.01}
# {'calculated_estimate': -1.82, 'calculated_error': 0.01}
# {'calculated_estimate': -2.17, 'calculated_error': 0.01}
# {'calculated_estimate': -2.31, 'calculated_error': 0.01}
# {'calculated_estimate': -0.69, 'calculated_error': 0.01}
# {'calculated_estimate': 0.08, 'calculated_error': 0.01}
# {'calculated_estimate': -1.66, 'calculated_error': 0.01}
# {'calculated_estimate': -1.81, 'calculated_error': 0.01}
# {'calculated_estimate': -0.8, 'calculated_error': 0.01}
# {'calculated_estimate': -2.44, 'calculated_error': 0.01}
# {'calculated_estimate': -1.13, 'calculated_error': 0.01}
# {'calculated_estimate': -1.38, 'calculated_error': 0.01}
# {'calculated_estimate': -0.78, 'calculated_error': 0.01}
# {'calculated_estimate': 0.87, 'calculated_error': 0.01}
# {'calculated_estimate': 1.78, 'calculated_error': 0.01}
# {'calculated_estimate': -0.94, 'calculated_error': 0.01}
# {'calculated_estimate': 1.86, 'calculated_error': 0.01}
# {'calculated_estimate': -0.84, 'calculated_error': 0.01}
# {'calculated_estimate': -4.55, 'calculated_error': 0.01}
# {'calculated_estimate': 0.08, 'calculated_error': 0.01}
# {'calculated_estimate': -1.5, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': -0.59, 'calculated_error': 0.01}
# {'calculated_estimate': -0.42, 'calculated_error': 0.01}
# {'calculated_estimate': 2.91, 'calculated_error': 0.01}
# {'calculated_estimate': 1.4, 'calculated_error': 0.01}
# {'calculated_estimate': 1.1, 'calculated_error': 0.01}
# {'calculated_estimate': -1.76, 'calculated_error': 0.01}
# {'calculated_estimate': 0.0, 'calculated_error': 0.01}
# {'calculated_estimate': 5.45, 'calculated_error': 0.01}
# {'calculated_estimate': 1.47, 'calculated_error': 0.01}
# {'calculated_estimate': -0.01, 'calculated_error': 0.01}
# {'calculated_estimate': 2.06, 'calculated_error': 0.01}
# {'calculated_estimate': 3.11, 'calculated_error': 0.01}
# {'calculated_estimate': 1.22, 'calculated_error': 0.01}
# {'calculated_estimate': 1.16, 'calculated_error': 0.01}
# {'calculated_estimate': -0.76, 'calculated_error': 0.01}
# {'calculated_estimate': 1.34, 'calculated_error': 0.01}
# {'calculated_estimate': -1.32, 'calculated_error': 0.01}
# {'calculated_estimate': 1.57, 'calculated_error': 0.01}
# {'calculated_estimate': 2.0, 'calculated_error': 0.01}
# {'calculated_estimate': 0.78, 'calculated_error': 0.01}
# {'calculated_estimate': 2.07, 'calculated_error': 0.01}
# {'calculated_estimate': -1.24, 'calculated_error': 0.01}
# {'calculated_estimate': 1.55, 'calculated_error': 0.01}
# {'calculated_estimate': 3.96, 'calculated_error': 0.01}
# {'calculated_estimate': 0.58, 'calculated_error': 0.01}
# {'calculated_estimate': -0.6, 'calculated_error': 0.01}
# {'calculated_estimate': 0.17, 'calculated_error': 0.01}
# {'calculated_estimate': 1.82, 'calculated_error': 0.01}
# {'calculated_estimate': 0.36, 'calculated_error': 0.01}
# {'calculated_estimate': -2.15, 'calculated_error': 0.01}
# {'calculated_estimate': -0.39, 'calculated_error': 0.01}
# {'calculated_estimate': 1.0, 'calculated_error': 0.01}
# {'calculated_estimate': 2.69, 'calculated_error': 0.01}
# {'calculated_estimate': 0.99, 'calculated_error': 0.01}
# {'calculated_estimate': 1.33, 'calculated_error': 0.01}
# {'calculated_estimate': 0.66, 'calculated_error': 0.01}
# {'calculated_estimate': -2.34, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': 3.39, 'calculated_error': 0.01}
# {'calculated_estimate': 1.28, 'calculated_error': 0.01}
# {'calculated_estimate': 4.56, 'calculated_error': 0.01}
# {'calculated_estimate': -1.32, 'calculated_error': 0.01}
# {'calculated_estimate': 1.23, 'calculated_error': 0.01}
# {'calculated_estimate': 0.22, 'calculated_error': 0.01}
# {'calculated_estimate': -1.78, 'calculated_error': 0.01}
# {'calculated_estimate': -2.13, 'calculated_error': 0.01}
# {'calculated_estimate': 0.87, 'calculated_error': 0.01}
# {'calculated_estimate': 2.63, 'calculated_error': 0.01}
# {'calculated_estimate': -0.53, 'calculated_error': 0.01}
# {'calculated_estimate': -0.34, 'calculated_error': 0.01}
# {'calculated_estimate': -0.06, 'calculated_error': 0.01}
# {'calculated_estimate': 0.01, 'calculated_error': 0.01}
# {'calculated_estimate': 2.57, 'calculated_error': 0.01}
# {'calculated_estimate': -0.27, 'calculated_error': 0.01}
# {'calculated_estimate': 1.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.67, 'calculated_error': 0.01}
# {'calculated_estimate': 0.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.29, 'calculated_error': 0.01}
# {'calculated_estimate': -0.65, 'calculated_error': 0.01}
# {'calculated_estimate': 0.17, 'calculated_error': 0.01}
# {'calculated_estimate': 1.94, 'calculated_error': 0.01}
# {'calculated_estimate': -2.63, 'calculated_error': 0.01}
# {'calculated_estimate': 2.04, 'calculated_error': 0.01}
# {'calculated_estimate': -0.89, 'calculated_error': 0.01}
# {'calculated_estimate': -1.09, 'calculated_error': 0.01}
# {'calculated_estimate': -0.44, 'calculated_error': 0.01}
# {'calculated_estimate': 0.64, 'calculated_error': 0.01}
# {'calculated_estimate': 0.92, 'calculated_error': 0.01}
# {'calculated_estimate': 0.42, 'calculated_error': 0.01}
# {'calculated_estimate': -2.61, 'calculated_error': 0.01}
# {'calculated_estimate': -0.94, 'calculated_error': 0.01}
# {'calculated_estimate': 1.23, 'calculated_error': 0.01}
# {'calculated_estimate': 0.14, 'calculated_error': 0.01}
# {'calculated_estimate': 1.77, 'calculated_error': 0.01}
# {'calculated_estimate': 4.99, 'calculated_error': 0.01}
# {'calculated_estimate': -1.82, 'calculated_error': 0.01}
# {'calculated_estimate': -2.8, 'calculated_error': 0.01}
# {'calculated_estimate': 0.36, 'calculated_error': 0.01}
# {'calculated_estimate': -1.22, 'calculated_error': 0.01}
# {'calculated_estimate': -1.67, 'calculated_error': 0.01}
# {'calculated_estimate': -1.27, 'calculated_error': 0.01}
# {'calculated_estimate': 1.42, 'calculated_error': 0.01}
# {'calculated_estimate': -1.01, 'calculated_error': 0.01}
# {'calculated_estimate': -1.51, 'calculated_error': 0.01}
# {'calculated_estimate': 0.14, 'calculated_error': 0.01}
# {'calculated_estimate': -2.65, 'calculated_error': 0.01}
# {'calculated_estimate': 0.67, 'calculated_error': 0.01}
# {'calculated_estimate': -1.49, 'calculated_error': 0.01}
# {'calculated_estimate': -0.62, 'calculated_error': 0.01}
# {'calculated_estimate': 0.07, 'calculated_error': 0.01}
# {'calculated_estimate': -1.3, 'calculated_error': 0.01}
# {'calculated_estimate': 2.24, 'calculated_error': 0.01}
# {'calculated_estimate': 0.04, 'calculated_error': 0.01}
# {'calculated_estimate': -0.9, 'calculated_error': 0.01}
# {'calculated_estimate': -1.85, 'calculated_error': 0.01}
# {'calculated_estimate': -1.15, 'calculated_error': 0.01}
# {'calculated_estimate': -0.23, 'calculated_error': 0.01}
# {'calculated_estimate': -0.36, 'calculated_error': 0.01}
# {'calculated_estimate': -3.39, 'calculated_error': 0.01}
# {'calculated_estimate': -3.28, 'calculated_error': 0.01}
# {'calculated_estimate': -3.02, 'calculated_error': 0.01}
# {'calculated_estimate': -3.06, 'calculated_error': 0.01}
# {'calculated_estimate': 1.68, 'calculated_error': 0.01}
# {'calculated_estimate': -0.12, 'calculated_error': 0.01}
# {'calculated_estimate': -2.02, 'calculated_error': 0.01}
# {'calculated_estimate': -1.79, 'calculated_error': 0.01}
# {'calculated_estimate': 1.83, 'calculated_error': 0.01}
# {'calculated_estimate': 0.35, 'calculated_error': 0.01}
# {'calculated_estimate': -1.62, 'calculated_error': 0.01}
# {'calculated_estimate': 2.47, 'calculated_error': 0.01}
# {'calculated_estimate': 1.77, 'calculated_error': 0.01}
# {'calculated_estimate': 2.69, 'calculated_error': 0.01}
# {'calculated_estimate': -0.31, 'calculated_error': 0.01}
# {'calculated_estimate': 0.56, 'calculated_error': 0.01}
# {'calculated_estimate': -0.6, 'calculated_error': 0.01}
# {'calculated_estimate': 3.93, 'calculated_error': 0.01}
# {'calculated_estimate': 3.49, 'calculated_error': 0.01}
# {'calculated_estimate': -1.5, 'calculated_error': 0.01}
# {'calculated_estimate': 0.61, 'calculated_error': 0.01}
# {'calculated_estimate': 0.9, 'calculated_error': 0.01}
# {'calculated_estimate': -1.29, 'calculated_error': 0.01}
# {'calculated_estimate': 1.02, 'calculated_error': 0.01}
# {'calculated_estimate': 1.35, 'calculated_error': 0.01}
# {'calculated_estimate': -1.05, 'calculated_error': 0.01}
# {'calculated_estimate': 3.55, 'calculated_error': 0.01}
# {'calculated_estimate': 2.93, 'calculated_error': 0.01}
# {'calculated_estimate': 3.07, 'calculated_error': 0.01}
# {'calculated_estimate': -1.51, 'calculated_error': 0.01}
# {'calculated_estimate': -3.05, 'calculated_error': 0.01}
# {'calculated_estimate': 1.6, 'calculated_error': 0.01}
# {'calculated_estimate': 2.43, 'calculated_error': 0.01}
# {'calculated_estimate': -2.76, 'calculated_error': 0.01}
# {'calculated_estimate': -1.25, 'calculated_error': 0.01}
# {'calculated_estimate': -3.1, 'calculated_error': 0.01}

# %%
import pandas as pd

# タブ区切りのファイルを読み込む
df = pd.read_csv('./cinnabar_output_core4_star.dat', delimiter='\t')

# 'ligand'カラムから'lig_'を取り除いた新しいカラム'ligand_num'を作成
df['ligand_num'] = df['ligand'].str.replace('lig_', '')

# カンマ区切りのCSVファイルとして保存
df.to_csv('./cinnabar_output_core4_star.csv', index=False)
