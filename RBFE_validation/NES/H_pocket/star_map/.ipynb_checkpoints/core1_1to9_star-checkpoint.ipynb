# %%
# First we do a set of imports
import csv
from pprint import pprint
import cinnabar
from cinnabar import plotting as cinnabar_plotting
from cinnabar import femap, stats

# %%
# read in the experimental data

experimental_data = {}
experimental_filename = 'experimental_core1.tsv'

with open(experimental_filename, 'r') as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"')
    headers = next(rd)
    for row in rd:
        experimental_data[row[0]] = {}
        experimental_data[row[0]]['dG'] = float(row[1])
        experimental_data[row[0]]['ddG'] = float(row[2])

pprint(experimental_data)
# Out:
# {'1': {'dG': -8.56, 'ddG': 0.0},
#  '2': {'dG': -9.08, 'ddG': 0.0},
#  '3': {'dG': -9.85, 'ddG': 0.0},
#  '4': {'dG': -9.39, 'ddG': 0.0},
#  '5': {'dG': -10.91, 'ddG': 0.0},
#  '6': {'dG': -9.64, 'ddG': 0.0},
#  '7': {'dG': -10.37, 'ddG': 0.0},
#  '8': {'dG': -9.35, 'ddG': 0.0},
#  '9': {'dG': -10.17, 'ddG': 0.0}}

# %%
# Read in calculated results

calculated_data = {}
calculated_filename = './final_results_20250215_paper_core1_1to9_star_BAR.tsv'

with open(calculated_filename, 'r') as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"')
    headers = next(rd)
    for row in rd:
        tag = row[0] + "->" + row[1]
        calculated_data[tag] = {}
        calculated_data[tag]['ligand_i'] = row[0]
        calculated_data[tag]['ligand_j'] = row[1]
        calculated_data[tag]['dG'] = float(row[2])
        calculated_data[tag]['ddG'] = float(row[3])

pprint(calculated_data)
# Out:
# {'1->2': {'dG': -1.2233333333333336,
#           'ddG': 0.7099530500908724,
#           'ligand_i': '1',
#           'ligand_j': '2'},
#  '1->3': {'dG': -1.52,
#           'ddG': 0.1039230484541327,
#           'ligand_i': '1',
#           'ligand_j': '3'},
#  '1->4': {'dG': -0.65,
#           'ddG': 0.6148983655857285,
#           'ligand_i': '1',
#           'ligand_j': '4'},
#  '1->5': {'dG': -3.243333333333333,
#           'ddG': 0.5033222956847162,
#           'ligand_i': '1',
#           'ligand_j': '5'},
#  '1->6': {'dG': -1.5566666666666664,
#           'ddG': 1.5800421935294433,
#           'ligand_i': '1',
#           'ligand_j': '6'},
#  '1->7': {'dG': -1.81,
#           'ddG': 0.5058655947976695,
#           'ligand_i': '1',
#           'ligand_j': '7'},
#  '1->8': {'dG': -1.113333333333333,
#           'ddG': 0.9166424239218548,
#           'ligand_i': '1',
#           'ligand_j': '8'},
#  '1->9': {'dG': -3.626666666666667,
#           'ddG': 1.2033841171186084,
#           'ligand_i': '1',
#           'ligand_j': '9'}}

# %%
cinnabar_filename = './cinnabar_input_core1_1to9_star_BAR.csv'

with open(cinnabar_filename, 'w') as f:
    f.write("# Experimental block\n")
    f.write("# Ligand, expt_DDG, expt_dDDG\n")
    for entry in experimental_data:
        dG = experimental_data[entry]['dG']
        ddG = experimental_data[entry]['ddG']
        f.write(f"{entry},{dG:.2f},{ddG:.2f}\n")
    f.write('\n')
    f.write('# Calculated block\n')
    f.write('# Ligand1,Ligand2,calc_DDG,calc_dDDG(MBAR),calc_dDDG(additional)\n')
    for entry in calculated_data:
        dG = calculated_data[entry]['dG']
        ddG = calculated_data[entry]['ddG']
        molA = calculated_data[entry]['ligand_i']
        molB = calculated_data[entry]['ligand_j']
        f.write(f"{molA},{molB},{dG:.2f},0,{ddG:.2f}\n")

# %%
fe = femap.FEMap.from_csv('./cinnabar_input_core1_1to9_star_BAR.csv')
fe.generate_absolute_values()  # Get MLE generated estimates of the absolute values
fe.draw_graph()
# Out:
# /home/hiroyuki/miniforge3/envs/openfe_env/lib/python3.12/site-packages/cinnabar/femap.py:35: UserWarning: Assuming kcal/mol units on measurements
#   warnings.warn("Assuming kcal/mol units on measurements")

# %%
# note you can pass the filename argument to write things out to file
cinnabar_plotting.plot_DDGs(fe.to_legacy_graph(), figsize=5)

# %%
# note you can pass the filename argument to write to file
cinnabar_plotting.plot_DGs(fe.to_legacy_graph(), figsize=5)

# %%
data = femap.read_csv('./cinnabar_input_core1_1to9_star_BAR.csv')
exp_DG_sum = sum([data['Experimental'][i].DG for i in data['Experimental'].keys()])
shift = exp_DG_sum / len(data['Experimental'].keys())
print(type(shift.m))

cinnabar_plotting.plot_DGs(fe.to_legacy_graph(), figsize=5,  shift=shift.m, filename='./core1_star_1to9_BAR.svg', xy_lim=[-13.5,-7])
# Out:
# /home/hiroyuki/miniforge3/envs/openfe_env/lib/python3.12/site-packages/cinnabar/femap.py:35: UserWarning: Assuming kcal/mol units on measurements
#   warnings.warn("Assuming kcal/mol units on measurements")
# <class 'float'>

# %%
dG_results = {}
nodes = list(fe.to_legacy_graph().nodes.data())

for key in range(len(nodes)):
    dG_results[nodes[key][0]] = {
        'experimental_estimate': nodes[key][1]['exp_DG'],
        'experimental_error': nodes[key][1]['exp_dDG'],
        'calculated_estimate': round(nodes[key][1]['calc_DG'],2),
        'calculated_error': round(nodes[key][1]['calc_dDG'],2),
    }

# We can now print out the results
pprint(dG_results)

# write out the calculated results
with open('./dG_calculated_results_NES.dat', 'w') as f:
    writer = csv.writer(f, delimiter="\t", lineterminator="\n")
    writer.writerow(["ligand", "DG(MLE)", "uncertainty (kcal/mol)",])
    for ligand in dG_results:
        writer.writerow([
            ligand,
            dG_results[ligand]['calculated_estimate']+shift.m,
            dG_results[ligand]['calculated_error'],
        ])
        print(dG_results[ligand])

# write out the experimental results
with open('./dG_experimental_results_NES.dat', 'w') as f:
    writer = csv.writer(f, delimiter="\t", lineterminator="\n")
    writer.writerow(["ligand", "DG", "uncertainty (kcal/mol)",])
    for ligand in dG_results:
        writer.writerow([
            ligand,
            dG_results[ligand]['experimental_estimate'],
            dG_results[ligand]['experimental_error'],
        ])
# Out:
# {'1': {'calculated_error': 0.68,
#        'calculated_estimate': 0.92,
#        'experimental_error': 0.0,
#        'experimental_estimate': -8.56},
#  '2': {'calculated_error': 0.58,
#        'calculated_estimate': -0.09,
#        'experimental_error': 0.0,
#        'experimental_estimate': -9.08},
#  '3': {'calculated_error': 0.57,
#        'calculated_estimate': -0.23,
#        'experimental_error': 0.0,
#        'experimental_estimate': -9.85},
#  '4': {'calculated_error': 1.27,
#        'calculated_estimate': 1.8,
#        'experimental_error': 0.0,
#        'experimental_estimate': -9.39},
#  '5': {'calculated_error': 0.97,
#        'calculated_estimate': -2.42,
#        'experimental_error': 0.0,
#        'experimental_estimate': -10.91},
#  '6': {'calculated_error': 0.57,
#        'calculated_estimate': 0.9,
#        'experimental_error': 0.0,
#        'experimental_estimate': -9.64},
#  '7': {'calculated_error': 0.87,
#        'calculated_estimate': -0.29,
#        'experimental_error': 0.0,
#        'experimental_estimate': -10.37},
#  '8': {'calculated_error': 0.97,
#        'calculated_estimate': -0.93,
#        'experimental_error': 0.0,
#        'experimental_estimate': -9.35},
#  '9': {'calculated_error': 1.27,
#        'calculated_estimate': 0.34,
#        'experimental_error': 0.0,
#        'experimental_estimate': -10.17}}
# {'experimental_estimate': -8.56, 'experimental_error': 0.0, 'calculated_estimate': 0.92, 'calculated_error': 0.68}
# {'experimental_estimate': -9.08, 'experimental_error': 0.0, 'calculated_estimate': -0.09, 'calculated_error': 0.58}
# {'experimental_estimate': -10.91, 'experimental_error': 0.0, 'calculated_estimate': -2.42, 'calculated_error': 0.97}
# {'experimental_estimate': -9.35, 'experimental_error': 0.0, 'calculated_estimate': -0.93, 'calculated_error': 0.97}
# {'experimental_estimate': -9.85, 'experimental_error': 0.0, 'calculated_estimate': -0.23, 'calculated_error': 0.57}
# {'experimental_estimate': -9.64, 'experimental_error': 0.0, 'calculated_estimate': 0.9, 'calculated_error': 0.57}
# {'experimental_estimate': -9.39, 'experimental_error': 0.0, 'calculated_estimate': 1.8, 'calculated_error': 1.27}
# {'experimental_estimate': -10.37, 'experimental_error': 0.0, 'calculated_estimate': -0.29, 'calculated_error': 0.87}
# {'experimental_estimate': -10.17, 'experimental_error': 0.0, 'calculated_estimate': 0.34, 'calculated_error': 1.27}
