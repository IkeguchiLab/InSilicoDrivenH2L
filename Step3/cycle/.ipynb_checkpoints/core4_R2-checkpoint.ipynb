# %%
# First we do a set of imports
import csv
from pprint import pprint
import cinnabar
from cinnabar import plotting as cinnabar_plotting
from cinnabar import femap, stats

# %%
# temporarily loaded for the creation of a TSV file, although it is not used
# read in the experimental data

experimental_data = {}
experimental_filename = '../../RBFE_validation/NES/M_pocket/all/experimental_core4_Mpocket.tsv'

with open(experimental_filename, 'r') as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"')
    headers = next(rd)
    for row in rd:
        experimental_data[row[0]] = {}
        experimental_data[row[0]]['dG'] = float(row[1])
        experimental_data[row[0]]['ddG'] = float(row[2])

pprint(experimental_data)
# Out:
# {'lig_13': {'dG': -10.5, 'ddG': 0.0},
#  'lig_18': {'dG': -8.68, 'ddG': 0.0},
#  'lig_19': {'dG': -8.45, 'ddG': 0.0},
#  'lig_20': {'dG': -8.46, 'ddG': 0.0},
#  'lig_21': {'dG': -8.51, 'ddG': 0.0},
#  'lig_22': {'dG': -8.7, 'ddG': 0.0},
#  'lig_23': {'dG': -8.48, 'ddG': 0.0},
#  'lig_27': {'dG': -10.02, 'ddG': 0.0},
#  'lig_28': {'dG': -9.13, 'ddG': 0.0},
#  'lig_29': {'dG': -9.56, 'ddG': 0.0},
#  'lig_30': {'dG': -10.67, 'ddG': 0.0},
#  'lig_31': {'dG': -9.55, 'ddG': 0.0},
#  'lig_32': {'dG': -9.77, 'ddG': 0.0},
#  'lig_33': {'dG': -10.75, 'ddG': 0.0},
#  'lig_34': {'dG': -11.21, 'ddG': 0.0},
#  'lig_35': {'dG': -10.42, 'ddG': 0.0},
#  'lig_36': {'dG': -10.75, 'ddG': 0.0}}

# %%
# Read in calculated results

calculated_data = {}
calculated_filename = './final_results_core4_R2.tsv'

with open(calculated_filename, 'r') as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"')
    headers = next(rd)
    for row in rd:
        tag = row[0] + "->" + row[1]
        calculated_data[tag] = {}
        calculated_data[tag]['ligand_i'] = row[0]
        calculated_data[tag]['ligand_j'] = row[1]
        calculated_data[tag]['dG'] = float(row[2])
        calculated_data[tag]['ddG'] = float(row[3])

pprint(calculated_data)
# Out:
# {'lig_10001-1->lig_11786-1': {'dG': 0.1599999999999966,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10001-1',
#                               'ligand_j': 'lig_11786-1'},
#  'lig_10001-1->lig_1428-1': {'dG': -4.079999999999998,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10001-1',
#                              'ligand_j': 'lig_1428-1'},
#  'lig_10001-1->lig_155-1': {'dG': 1.6000000000000003,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10001-1',
#                             'ligand_j': 'lig_155-1'},
#  'lig_10001-1->lig_15511-1': {'dG': -0.5700000000000003,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10001-1',
#                               'ligand_j': 'lig_15511-1'},
#  'lig_10001-1->lig_15511-4': {'dG': 2.4300000000000037,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10001-1',
#                               'ligand_j': 'lig_15511-4'},
#  'lig_10001-1->lig_1917-1': {'dG': 0.4399999999999977,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10001-1',
#                              'ligand_j': 'lig_1917-1'},
#  'lig_10001-1->lig_39834-1': {'dG': 0.8200000000000003,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10001-1',
#                               'ligand_j': 'lig_39834-1'},
#  'lig_10001-2->lig_23291-1': {'dG': 12.6,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10001-2',
#                               'ligand_j': 'lig_23291-1'},
#  'lig_10187-1->lig_16260-1': {'dG': -1.1899999999999975,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10187-1',
#                               'ligand_j': 'lig_16260-1'},
#  'lig_10187-1->lig_27555-1': {'dG': 2.0700000000000003,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10187-1',
#                               'ligand_j': 'lig_27555-1'},
#  'lig_10187-1->lig_3118-1': {'dG': 0.5499999999999972,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10187-1',
#                              'ligand_j': 'lig_3118-1'},
#  'lig_10202-1->lig_10504-3': {'dG': 10.58,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_10504-3'},
#  'lig_10202-1->lig_10504-7': {'dG': 2.1999999999999997,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_10504-7'},
#  'lig_10202-1->lig_12602-1': {'dG': -2.9799999999999898,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_12602-1'},
#  'lig_10202-1->lig_13591-2': {'dG': 0.1799999999999997,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_13591-2'},
#  'lig_10202-1->lig_14686-1': {'dG': -2.75,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_14686-1'},
#  'lig_10202-1->lig_15511-4': {'dG': 0.5799999999999983,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_15511-4'},
#  'lig_10202-1->lig_1597-1': {'dG': 3.4399999999999977,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10202-1',
#                              'ligand_j': 'lig_1597-1'},
#  'lig_10202-1->lig_16598-4': {'dG': 0.75,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_16598-4'},
#  'lig_10202-1->lig_17877-1': {'dG': 0.9299999999999996,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_17877-1'},
#  'lig_10202-1->lig_26759-2': {'dG': 1.1199999999999974,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_26759-2'},
#  'lig_10202-1->lig_26776-1': {'dG': 4.049999999999997,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_26776-1'},
#  'lig_10202-1->lig_3635-1': {'dG': 1.740000000000002,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10202-1',
#                              'ligand_j': 'lig_3635-1'},
#  'lig_10202-1->lig_37772-2': {'dG': -1.0099999999999998,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_37772-2'},
#  'lig_10202-1->lig_39208-1': {'dG': 1.4299999999999995,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_39208-1'},
#  'lig_10202-1->lig_39331-2': {'dG': 0.4700000000000006,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_39331-2'},
#  'lig_10202-1->lig_39971-2': {'dG': 5.960000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_39971-2'},
#  'lig_10202-1->lig_4362-1': {'dG': 0.2199999999999988,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10202-1',
#                              'ligand_j': 'lig_4362-1'},
#  'lig_10202-1->lig_43640-2': {'dG': 4.52,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-1',
#                               'ligand_j': 'lig_43640-2'},
#  'lig_10202-1->lig_4659-1': {'dG': 0.9800000000000004,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10202-1',
#                              'ligand_j': 'lig_4659-1'},
#  'lig_10202-1->lig_9952-1': {'dG': 1.2700000000000005,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10202-1',
#                              'ligand_j': 'lig_9952-1'},
#  'lig_10202-2->lig_16635-4': {'dG': 3.440000000000012,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-2',
#                               'ligand_j': 'lig_16635-4'},
#  'lig_10202-2->lig_21317-1': {'dG': 0.9299999999999926,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-2',
#                               'ligand_j': 'lig_21317-1'},
#  'lig_10202-2->lig_22-1': {'dG': 1.3899999999999997,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_10202-2',
#                            'ligand_j': 'lig_22-1'},
#  'lig_10202-2->lig_22011-2': {'dG': 2.469999999999999,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-2',
#                               'ligand_j': 'lig_22011-2'},
#  'lig_10202-2->lig_23260-2': {'dG': 1.1199999999999974,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-2',
#                               'ligand_j': 'lig_23260-2'},
#  'lig_10202-2->lig_27554-1': {'dG': 2.14,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-2',
#                               'ligand_j': 'lig_27554-1'},
#  'lig_10202-2->lig_2895-1': {'dG': 0.8399999999999999,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10202-2',
#                              'ligand_j': 'lig_2895-1'},
#  'lig_10202-2->lig_30432-4': {'dG': 2.84,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-2',
#                               'ligand_j': 'lig_30432-4'},
#  'lig_10202-2->lig_35182-1': {'dG': 1.7100000000000009,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-2',
#                               'ligand_j': 'lig_35182-1'},
#  'lig_10202-2->lig_3565-1': {'dG': 2.8699999999999903,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10202-2',
#                              'ligand_j': 'lig_3565-1'},
#  'lig_10202-2->lig_38254-2': {'dG': 0.0300000000000011,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10202-2',
#                               'ligand_j': 'lig_38254-2'},
#  'lig_10202-2->lig_3846-2': {'dG': 4.809999999999999,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10202-2',
#                              'ligand_j': 'lig_3846-2'},
#  'lig_10202-2->lig_4723-2': {'dG': -1.1199999999999974,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10202-2',
#                              'ligand_j': 'lig_4723-2'},
#  'lig_10202-2->lig_907-1': {'dG': 2.3299999999999983,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10202-2',
#                             'ligand_j': 'lig_907-1'},
#  'lig_10252-1->lig_11368-2': {'dG': 2.259999999999991,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10252-1',
#                               'ligand_j': 'lig_11368-2'},
#  'lig_10252-1->lig_42020-1': {'dG': 1.4399999999999975,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10252-1',
#                               'ligand_j': 'lig_42020-1'},
#  'lig_10254-1->lig_3376-1': {'dG': 8.420000000000002,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10254-1',
#                              'ligand_j': 'lig_3376-1'},
#  'lig_10255-1->lig_22-1': {'dG': -0.9299999999999996,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_10255-1',
#                            'ligand_j': 'lig_22-1'},
#  'lig_10255-1->lig_8979-1': {'dG': -0.0300000000000011,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10255-1',
#                              'ligand_j': 'lig_8979-1'},
#  'lig_10499-2->lig_4657-1': {'dG': -0.9500000000000012,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10499-2',
#                              'ligand_j': 'lig_4657-1'},
#  'lig_10504-1->lig_10499-1': {'dG': 0.1800000000000015,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10504-1',
#                               'ligand_j': 'lig_10499-1'},
#  'lig_10504-3->lig_10499-2': {'dG': -1.39,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10504-3',
#                               'ligand_j': 'lig_10499-2'},
#  'lig_10504-3->lig_39331-2': {'dG': -6.07,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10504-3',
#                               'ligand_j': 'lig_39331-2'},
#  'lig_10504-5->lig_15847-2': {'dG': 7.699999999999996,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10504-5',
#                               'ligand_j': 'lig_15847-2'},
#  'lig_10504-5->lig_3793-1': {'dG': 1.0999999999999996,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10504-5',
#                              'ligand_j': 'lig_3793-1'},
#  'lig_10504-6->lig_17771-1': {'dG': -0.07,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10504-6',
#                               'ligand_j': 'lig_17771-1'},
#  'lig_10504-6->lig_182-1': {'dG': -1.05,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10504-6',
#                             'ligand_j': 'lig_182-1'},
#  'lig_10504-6->lig_3326-1': {'dG': -0.4900000000000002,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10504-6',
#                              'ligand_j': 'lig_3326-1'},
#  'lig_10504-6->lig_3495-1': {'dG': -1.5199999999999996,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10504-6',
#                              'ligand_j': 'lig_3495-1'},
#  'lig_10504-8->lig_127-1': {'dG': 0.7999999999999972,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10504-8',
#                             'ligand_j': 'lig_127-1'},
#  'lig_10504-8->lig_23048-1': {'dG': -0.7900000000000009,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10504-8',
#                               'ligand_j': 'lig_23048-1'},
#  'lig_10504-8->lig_23048-2': {'dG': 4.279999999999999,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10504-8',
#                               'ligand_j': 'lig_23048-2'},
#  'lig_10504-8->lig_30778-1': {'dG': -1.1400000000000006,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10504-8',
#                               'ligand_j': 'lig_30778-1'},
#  'lig_10534-1->lig_14652-1': {'dG': -3.18,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10534-1',
#                               'ligand_j': 'lig_14652-1'},
#  'lig_10541-1->lig_11368-2': {'dG': 2.6599999999999966,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10541-1',
#                               'ligand_j': 'lig_11368-2'},
#  'lig_10541-1->lig_16199-1': {'dG': 0.1400000000000005,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10541-1',
#                               'ligand_j': 'lig_16199-1'},
#  'lig_10541-1->lig_20693-1': {'dG': 4.419999999999998,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10541-1',
#                               'ligand_j': 'lig_20693-1'},
#  'lig_10541-1->lig_20754-1': {'dG': 0.07,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10541-1',
#                               'ligand_j': 'lig_20754-1'},
#  'lig_10541-1->lig_22030-1': {'dG': 1.8700000000000043,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10541-1',
#                               'ligand_j': 'lig_22030-1'},
#  'lig_10541-1->lig_2714-1': {'dG': -0.1900000000000012,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10541-1',
#                              'ligand_j': 'lig_2714-1'},
#  'lig_10541-1->lig_34827-2': {'dG': 2.030000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10541-1',
#                               'ligand_j': 'lig_34827-2'},
#  'lig_10541-1->lig_5718-2': {'dG': 0.5300000000000002,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10541-1',
#                              'ligand_j': 'lig_5718-2'},
#  'lig_10541-1->lig_8384-1': {'dG': -1.509999999999998,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10541-1',
#                              'ligand_j': 'lig_8384-1'},
#  'lig_10548-1->lig_127-1': {'dG': 0.5900000000000034,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10548-1',
#                             'ligand_j': 'lig_127-1'},
#  'lig_10548-1->lig_19737-2': {'dG': -7.34,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10548-1',
#                               'ligand_j': 'lig_19737-2'},
#  'lig_10548-1->lig_21341-1': {'dG': -3.18,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10548-1',
#                               'ligand_j': 'lig_21341-1'},
#  'lig_10548-1->lig_24938-2': {'dG': -1.240000000000002,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10548-1',
#                               'ligand_j': 'lig_24938-2'},
#  'lig_10548-1->lig_26586-1': {'dG': -0.4699999999999988,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10548-1',
#                               'ligand_j': 'lig_26586-1'},
#  'lig_10548-1->lig_27554-1': {'dG': -2.4400000000000013,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10548-1',
#                               'ligand_j': 'lig_27554-1'},
#  'lig_10548-1->lig_29195-1': {'dG': -2.879999999999999,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10548-1',
#                               'ligand_j': 'lig_29195-1'},
#  'lig_10548-1->lig_29372-1': {'dG': 0.2200000000000059,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10548-1',
#                               'ligand_j': 'lig_29372-1'},
#  'lig_10548-1->lig_3376-1': {'dG': 0.6000000000000014,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10548-1',
#                              'ligand_j': 'lig_3376-1'},
#  'lig_10548-1->lig_39208-1': {'dG': -0.79,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10548-1',
#                               'ligand_j': 'lig_39208-1'},
#  'lig_10548-1->lig_44714-1': {'dG': -8.29,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10548-1',
#                               'ligand_j': 'lig_44714-1'},
#  'lig_10548-1->lig_8144-1': {'dG': 0.0999999999999998,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10548-1',
#                              'ligand_j': 'lig_8144-1'},
#  'lig_10634-1->lig_25909-1': {'dG': 2.6900000000000013,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10634-1',
#                               'ligand_j': 'lig_25909-1'},
#  'lig_10634-1->lig_43856-1': {'dG': 2.1599999999999966,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10634-1',
#                               'ligand_j': 'lig_43856-1'},
#  'lig_10634-1->lig_8384-1': {'dG': -0.2599999999999998,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10634-1',
#                              'ligand_j': 'lig_8384-1'},
#  'lig_10634-1->lig_9758-1': {'dG': -2.780000000000001,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10634-1',
#                              'ligand_j': 'lig_9758-1'},
#  'lig_10683-1->lig_20746-4': {'dG': 0.1899999999999977,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10683-1',
#                               'ligand_j': 'lig_20746-4'},
#  'lig_10683-1->lig_34746-1': {'dG': -6.82,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10683-1',
#                               'ligand_j': 'lig_34746-1'},
#  'lig_10683-1->lig_43689-1': {'dG': -2.510000000000005,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10683-1',
#                               'ligand_j': 'lig_43689-1'},
#  'lig_10684-1->lig_11347-1': {'dG': -2.309999999999974,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10684-1',
#                               'ligand_j': 'lig_11347-1'},
#  'lig_10684-1->lig_20709-3': {'dG': -1.039999999999992,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10684-1',
#                               'ligand_j': 'lig_20709-3'},
#  'lig_10684-1->lig_25923-1': {'dG': -2.240000000000009,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10684-1',
#                               'ligand_j': 'lig_25923-1'},
#  'lig_10684-1->lig_38552-1': {'dG': -3.2099999999999937,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10684-1',
#                               'ligand_j': 'lig_38552-1'},
#  'lig_10686-1->lig_21331-1': {'dG': 0.0600000000000005,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10686-1',
#                               'ligand_j': 'lig_21331-1'},
#  'lig_10688-1->lig_15546-1': {'dG': -0.9299999999999926,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10688-1',
#                               'ligand_j': 'lig_15546-1'},
#  'lig_10688-1->lig_25923-1': {'dG': -1.3299999999999983,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10688-1',
#                               'ligand_j': 'lig_25923-1'},
#  'lig_10688-1->lig_26725-1': {'dG': -0.4100000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10688-1',
#                               'ligand_j': 'lig_26725-1'},
#  'lig_10688-1->lig_27566-4': {'dG': -6.319999999999993,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10688-1',
#                               'ligand_j': 'lig_27566-4'},
#  'lig_10688-1->lig_38552-1': {'dG': 0.9099999999999966,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10688-1',
#                               'ligand_j': 'lig_38552-1'},
#  'lig_10689-1->lig_19249-1': {'dG': -7.43,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10689-1',
#                               'ligand_j': 'lig_19249-1'},
#  'lig_10689-1->lig_30797-2': {'dG': -1.5600000000000005,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10689-1',
#                               'ligand_j': 'lig_30797-2'},
#  'lig_10694-1->lig_20758-6': {'dG': 1.4699999999999989,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10694-1',
#                               'ligand_j': 'lig_20758-6'},
#  'lig_10694-1->lig_27566-3': {'dG': 2.6299999999999955,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10694-1',
#                               'ligand_j': 'lig_27566-3'},
#  'lig_10694-1->lig_30849-1': {'dG': -2.1599999999999997,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10694-1',
#                               'ligand_j': 'lig_30849-1'},
#  'lig_10694-1->lig_34233-1': {'dG': -0.2299999999999897,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10694-1',
#                               'ligand_j': 'lig_34233-1'},
#  'lig_10694-1->lig_3838-1': {'dG': -1.3500000000000014,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10694-1',
#                              'ligand_j': 'lig_3838-1'},
#  'lig_10715-1->lig_14057-1': {'dG': 2.8400000000000007,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-1',
#                               'ligand_j': 'lig_14057-1'},
#  'lig_10715-1->lig_15107-1': {'dG': 0.1300000000000007,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-1',
#                               'ligand_j': 'lig_15107-1'},
#  'lig_10715-1->lig_15107-2': {'dG': 3.129999999999999,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-1',
#                               'ligand_j': 'lig_15107-2'},
#  'lig_10715-1->lig_16343-2': {'dG': -0.7199999999999989,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-1',
#                               'ligand_j': 'lig_16343-2'},
#  'lig_10715-1->lig_17917-1': {'dG': 1.3800000000000026,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-1',
#                               'ligand_j': 'lig_17917-1'},
#  'lig_10715-1->lig_1917-2': {'dG': 5.290000000000001,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_1917-2'},
#  'lig_10715-1->lig_2318-1': {'dG': -0.6000000000000014,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_2318-1'},
#  'lig_10715-1->lig_27610-2': {'dG': -0.6900000000000048,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-1',
#                               'ligand_j': 'lig_27610-2'},
#  'lig_10715-1->lig_3118-1': {'dG': 0.8900000000000006,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_3118-1'},
#  'lig_10715-1->lig_3371-1': {'dG': -0.0300000000000011,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_3371-1'},
#  'lig_10715-1->lig_3570-1': {'dG': 0.1600000000000037,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_3570-1'},
#  'lig_10715-1->lig_3670-1': {'dG': 2.740000000000002,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_3670-1'},
#  'lig_10715-1->lig_3793-1': {'dG': 1.6000000000000014,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_3793-1'},
#  'lig_10715-1->lig_45240-1': {'dG': 1.4500000000000028,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-1',
#                               'ligand_j': 'lig_45240-1'},
#  'lig_10715-1->lig_4556-1': {'dG': 3.1899999999999977,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_4556-1'},
#  'lig_10715-1->lig_4657-1': {'dG': -1.5500000000000007,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_4657-1'},
#  'lig_10715-1->lig_9413-1': {'dG': 1.230000000000004,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-1',
#                              'ligand_j': 'lig_9413-1'},
#  'lig_10715-2->lig_10202-1': {'dG': -0.5199999999999996,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_10202-1'},
#  'lig_10715-2->lig_10254-1': {'dG': -0.0199999999999995,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_10254-1'},
#  'lig_10715-2->lig_12834-1': {'dG': 3.759999999999998,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_12834-1'},
#  'lig_10715-2->lig_13258-1': {'dG': 4.43,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_13258-1'},
#  'lig_10715-2->lig_16315-1': {'dG': 1.16,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_16315-1'},
#  'lig_10715-2->lig_16400-1': {'dG': 2.0599999999999987,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_16400-1'},
#  'lig_10715-2->lig_16635-4': {'dG': 3.8400000000000034,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_16635-4'},
#  'lig_10715-2->lig_16845-1': {'dG': 0.5399999999999991,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_16845-1'},
#  'lig_10715-2->lig_19259-1': {'dG': 1.2800000000000011,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_19259-1'},
#  'lig_10715-2->lig_19321-1': {'dG': 1.25,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_19321-1'},
#  'lig_10715-2->lig_21322-1': {'dG': 1.269999999999996,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_21322-1'},
#  'lig_10715-2->lig_21341-1': {'dG': -0.7600000000000051,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_21341-1'},
#  'lig_10715-2->lig_24945-1': {'dG': 2.7099999999999937,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_24945-1'},
#  'lig_10715-2->lig_35182-2': {'dG': 2.8999999999999986,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_35182-2'},
#  'lig_10715-2->lig_3828-1': {'dG': 4.090000000000003,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-2',
#                              'ligand_j': 'lig_3828-1'},
#  'lig_10715-2->lig_40488-1': {'dG': 2.549999999999999,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_40488-1'},
#  'lig_10715-2->lig_42436-1': {'dG': 4.440000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_42436-1'},
#  'lig_10715-2->lig_44391-1': {'dG': -1.41,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10715-2',
#                               'ligand_j': 'lig_44391-1'},
#  'lig_10715-2->lig_5605-1': {'dG': -0.5699999999999932,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-2',
#                              'ligand_j': 'lig_5605-1'},
#  'lig_10715-2->lig_907-1': {'dG': -0.0300000000000011,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10715-2',
#                             'ligand_j': 'lig_907-1'},
#  'lig_10715-2->lig_9952-1': {'dG': 0.3600000000000012,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10715-2',
#                              'ligand_j': 'lig_9952-1'},
#  'lig_10757-1->lig_17434-1': {'dG': 2.910000000000011,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10757-1',
#                               'ligand_j': 'lig_17434-1'},
#  'lig_10757-1->lig_17754-1': {'dG': 1.0700000000000005,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10757-1',
#                               'ligand_j': 'lig_17754-1'},
#  'lig_10757-1->lig_18158-1': {'dG': 0.1299999999999999,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10757-1',
#                               'ligand_j': 'lig_18158-1'},
#  'lig_10757-1->lig_24905-1': {'dG': -3.710000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10757-1',
#                               'ligand_j': 'lig_24905-1'},
#  'lig_10757-1->lig_3118-1': {'dG': 1.1499999999999986,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10757-1',
#                              'ligand_j': 'lig_3118-1'},
#  'lig_10758-1->lig_129-1': {'dG': -1.5300000000000011,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10758-1',
#                             'ligand_j': 'lig_129-1'},
#  'lig_10758-1->lig_16629-1': {'dG': 0.8200000000000003,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10758-1',
#                               'ligand_j': 'lig_16629-1'},
#  'lig_10758-1->lig_2895-1': {'dG': 1.27,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10758-1',
#                              'ligand_j': 'lig_2895-1'},
#  'lig_10758-1->lig_29198-2': {'dG': 1.3300000000000018,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10758-1',
#                               'ligand_j': 'lig_29198-2'},
#  'lig_10758-1->lig_32276-4': {'dG': 0.6200000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10758-1',
#                               'ligand_j': 'lig_32276-4'},
#  'lig_10758-1->lig_4362-1': {'dG': -1.77,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10758-1',
#                              'ligand_j': 'lig_4362-1'},
#  'lig_10758-1->lig_9998-1': {'dG': 1.75,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10758-1',
#                              'ligand_j': 'lig_9998-1'},
#  'lig_10777-1->lig_11786-2': {'dG': -3.2099999999999973,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_11786-2'},
#  'lig_10777-1->lig_155-1': {'dG': 0.0899999999999998,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10777-1',
#                             'ligand_j': 'lig_155-1'},
#  'lig_10777-1->lig_15816-1': {'dG': 1.1700000000000002,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_15816-1'},
#  'lig_10777-1->lig_17928-3': {'dG': -3.87,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_17928-3'},
#  'lig_10777-1->lig_19259-1': {'dG': 0.2800000000000011,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_19259-1'},
#  'lig_10777-1->lig_19264-1': {'dG': -0.0599999999999987,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_19264-1'},
#  'lig_10777-1->lig_21286-4': {'dG': -8.690000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_21286-4'},
#  'lig_10777-1->lig_22925-1': {'dG': -1.9200000000000017,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_22925-1'},
#  'lig_10777-1->lig_24905-2': {'dG': -6.409999999999997,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_24905-2'},
#  'lig_10777-1->lig_3326-1': {'dG': -1.240000000000002,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10777-1',
#                              'ligand_j': 'lig_3326-1'},
#  'lig_10777-1->lig_35489-1': {'dG': -0.259999999999998,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_35489-1'},
#  'lig_10777-1->lig_35489-2': {'dG': 3.5899999999999963,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_35489-2'},
#  'lig_10777-1->lig_3570-1': {'dG': -0.2900000000000009,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10777-1',
#                              'ligand_j': 'lig_3570-1'},
#  'lig_10777-1->lig_38254-1': {'dG': -1.4,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_38254-1'},
#  'lig_10777-1->lig_39844-1': {'dG': -0.6000000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_39844-1'},
#  'lig_10777-1->lig_42186-1': {'dG': 3.03,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10777-1',
#                               'ligand_j': 'lig_42186-1'},
#  'lig_10836-1->lig_39-1': {'dG': -1.0,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_10836-1',
#                            'ligand_j': 'lig_39-1'},
#  'lig_10839-1->lig_182-1': {'dG': 1.8000000000000007,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10839-1',
#                             'ligand_j': 'lig_182-1'},
#  'lig_10842-1->lig_120-1': {'dG': 1.23,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_10842-1',
#                             'ligand_j': 'lig_120-1'},
#  'lig_10842-1->lig_1663-1': {'dG': 1.3800000000000026,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10842-1',
#                              'ligand_j': 'lig_1663-1'},
#  'lig_10842-1->lig_17907-1': {'dG': 2.3400000000000034,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10842-1',
#                               'ligand_j': 'lig_17907-1'},
#  'lig_10842-1->lig_18861-1': {'dG': 1.230000000000004,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10842-1',
#                               'ligand_j': 'lig_18861-1'},
#  'lig_10842-1->lig_2137-2': {'dG': 3.9200000000000017,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10842-1',
#                              'ligand_j': 'lig_2137-2'},
#  'lig_10842-1->lig_2560-1': {'dG': 1.3200000000000005,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10842-1',
#                              'ligand_j': 'lig_2560-1'},
#  'lig_10842-1->lig_26782-1': {'dG': 4.980000000000004,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10842-1',
#                               'ligand_j': 'lig_26782-1'},
#  'lig_10842-1->lig_27105-2': {'dG': 5.969999999999999,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10842-1',
#                               'ligand_j': 'lig_27105-2'},
#  'lig_10913-1->lig_15107-2': {'dG': 2.3100000000000005,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-1',
#                               'ligand_j': 'lig_15107-2'},
#  'lig_10913-1->lig_16601-3': {'dG': 0.3299999999999983,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-1',
#                               'ligand_j': 'lig_16601-3'},
#  'lig_10913-1->lig_21119-1': {'dG': -1.3200000000000005,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-1',
#                               'ligand_j': 'lig_21119-1'},
#  'lig_10913-1->lig_22-1': {'dG': -1.0600000000000005,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_10913-1',
#                            'ligand_j': 'lig_22-1'},
#  'lig_10913-1->lig_24938-1': {'dG': -0.5,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-1',
#                               'ligand_j': 'lig_24938-1'},
#  'lig_10913-1->lig_30432-2': {'dG': 3.19,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-1',
#                               'ligand_j': 'lig_30432-2'},
#  'lig_10913-1->lig_3494-1': {'dG': -0.1999999999999993,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10913-1',
#                              'ligand_j': 'lig_3494-1'},
#  'lig_10913-1->lig_3685-1': {'dG': -2.769999999999982,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10913-1',
#                              'ligand_j': 'lig_3685-1'},
#  'lig_10913-1->lig_43197-1': {'dG': 10.090000000000003,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-1',
#                               'ligand_j': 'lig_43197-1'},
#  'lig_10913-2->lig_10315-1': {'dG': -0.1099999999999994,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_10315-1'},
#  'lig_10913-2->lig_10715-2': {'dG': 2.2200000000000006,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_10715-2'},
#  'lig_10913-2->lig_10839-2': {'dG': 1.4700000000000002,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_10839-2'},
#  'lig_10913-2->lig_15816-4': {'dG': 1.0300000000000011,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_15816-4'},
#  'lig_10913-2->lig_16635-2': {'dG': 3.719999999999999,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_16635-2'},
#  'lig_10913-2->lig_16635-3': {'dG': 1.4500000000000028,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_16635-3'},
#  'lig_10913-2->lig_17325-1': {'dG': 4.88000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_17325-1'},
#  'lig_10913-2->lig_17927-2': {'dG': 1.509999999999998,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_17927-2'},
#  'lig_10913-2->lig_19265-1': {'dG': -0.71,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_19265-1'},
#  'lig_10913-2->lig_21099-1': {'dG': 1.2199999999999989,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_21099-1'},
#  'lig_10913-2->lig_22925-1': {'dG': -0.5700000000000003,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_22925-1'},
#  'lig_10913-2->lig_33376-2': {'dG': -1.0999999999999996,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_33376-2'},
#  'lig_10913-2->lig_3635-1': {'dG': 1.009999999999998,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10913-2',
#                              'ligand_j': 'lig_3635-1'},
#  'lig_10913-2->lig_37772-1': {'dG': -0.5900000000000001,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_37772-1'},
#  'lig_10913-2->lig_39594-1': {'dG': 1.4400000000000013,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_39594-1'},
#  'lig_10913-2->lig_40523-1': {'dG': -1.0699999999999994,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10913-2',
#                               'ligand_j': 'lig_40523-1'},
#  'lig_10913-2->lig_4433-1': {'dG': 0.7999999999999998,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10913-2',
#                              'ligand_j': 'lig_4433-1'},
#  'lig_10913-2->lig_4556-1': {'dG': 2.0600000000000023,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10913-2',
#                              'ligand_j': 'lig_4556-1'},
#  'lig_10913-2->lig_4950-1': {'dG': 0.1000000000000005,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10913-2',
#                              'ligand_j': 'lig_4950-1'},
#  'lig_10913-2->lig_8-1': {'dG': -0.1899999999999999,
#                           'ddG': 0.01,
#                           'ligand_i': 'lig_10913-2',
#                           'ligand_j': 'lig_8-1'},
#  'lig_10913-2->lig_9998-1': {'dG': 2.440000000000005,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10913-2',
#                              'ligand_j': 'lig_9998-1'},
#  'lig_10935-1->lig_26895-1': {'dG': 1.5099999999999998,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10935-1',
#                               'ligand_j': 'lig_26895-1'},
#  'lig_10935-1->lig_27644-1': {'dG': -2.3499999999999943,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10935-1',
#                               'ligand_j': 'lig_27644-1'},
#  'lig_10935-1->lig_28075-1': {'dG': -1.4399999999999975,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_10935-1',
#                               'ligand_j': 'lig_28075-1'},
#  'lig_10935-1->lig_9924-1': {'dG': 1.4200000000000017,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_10935-1',
#                              'ligand_j': 'lig_9924-1'},
#  'lig_11063-1->lig_42023-1': {'dG': 8.480000000000004,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_11063-1',
#                               'ligand_j': 'lig_42023-1'},
#  'lig_11063-2->lig_12277-1': {'dG': 1.8800000000000008,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_11063-2',
#                               'ligand_j': 'lig_12277-1'},
#  'lig_11063-2->lig_18148-2': {'dG': -0.5199999999999996,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_11063-2',
#                               'ligand_j': 'lig_18148-2'},
#  'lig_11063-2->lig_31237-4': {'dG': 5.51,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_11063-2',
#                               'ligand_j': 'lig_31237-4'},
#  'lig_11063-2->lig_42068-1': {'dG': 0.7800000000000011,
#                               'ddG': 0.01,
#                               'ligand_i': 'lig_11063-2',
#                               'ligand_j': 'lig_42068-1'},
#  'lig_11063-2->lig_9998-1': {'dG': 0.7600000000000051,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_11063-2',
#                              'ligand_j': 'lig_9998-1'},
#  'lig_11189-1->lig_4723-2': {'dG': -2.469999999999999,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_11189-1',
#                              'ligand_j': 'lig_4723-2'},
#  'lig_11210-1->lig_1536-1': {'dG': 0.3400000000000034,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_11210-1',
#                              'ligand_j': 'lig_1536-1'},
#  'lig_11210-1->lig_155-1': {'dG': 2.0500000000000043,
#                             'ddG': 0.01,
# ...
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_8903-1',
#                            'ligand_j': 'lig_907-2'},
#  'lig_8964-1->lig_1373-1': {'dG': -0.2299999999999897,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_8964-1',
#                             'ligand_j': 'lig_1373-1'},
#  'lig_8964-1->lig_21119-1': {'dG': 1.8900000000000148,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_8964-1',
#                              'ligand_j': 'lig_21119-1'},
#  'lig_8964-1->lig_37432-1': {'dG': 4.889999999999986,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_8964-1',
#                              'ligand_j': 'lig_37432-1'},
#  'lig_8964-1->lig_40229-1': {'dG': -1.4800000000000182,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_8964-1',
#                              'ligand_j': 'lig_40229-1'},
#  'lig_8964-1->lig_42068-1': {'dG': 0.3400000000000034,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_8964-1',
#                              'ligand_j': 'lig_42068-1'},
#  'lig_8964-1->lig_42976-2': {'dG': 1.6499999999999773,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_8964-1',
#                              'ligand_j': 'lig_42976-2'},
#  'lig_8979-1->lig_40424-2': {'dG': -3.269999999999996,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_8979-1',
#                              'ligand_j': 'lig_40424-2'},
#  'lig_9004-1->lig_155-1': {'dG': 1.969999999999992,
#                            'ddG': 0.01,
#                            'ligand_i': 'lig_9004-1',
#                            'ligand_j': 'lig_155-1'},
#  'lig_9004-1->lig_18880-1': {'dG': 8.11,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9004-1',
#                              'ligand_j': 'lig_18880-1'},
#  'lig_9004-1->lig_2136-1': {'dG': 2.0600000000000023,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9004-1',
#                             'ligand_j': 'lig_2136-1'},
#  'lig_9004-1->lig_24606-1': {'dG': -0.7400000000000091,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9004-1',
#                              'ligand_j': 'lig_24606-1'},
#  'lig_9004-1->lig_28075-1': {'dG': -6.469999999999999,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9004-1',
#                              'ligand_j': 'lig_28075-1'},
#  'lig_9004-1->lig_35489-1': {'dG': 4.09,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9004-1',
#                              'ligand_j': 'lig_35489-1'},
#  'lig_9004-1->lig_37432-1': {'dG': 3.1999999999999886,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9004-1',
#                              'ligand_j': 'lig_37432-1'},
#  'lig_9007-1->lig_10548-1': {'dG': -0.129999999999999,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9007-1',
#                              'ligand_j': 'lig_10548-1'},
#  'lig_9007-1->lig_21927-2': {'dG': 7.800000000000001,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9007-1',
#                              'ligand_j': 'lig_21927-2'},
#  'lig_9007-1->lig_29646-1': {'dG': 1.9499999999999995,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9007-1',
#                              'ligand_j': 'lig_29646-1'},
#  'lig_9007-1->lig_35998-1': {'dG': -1.0200000000000014,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9007-1',
#                              'ligand_j': 'lig_35998-1'},
#  'lig_9007-1->lig_38906-2': {'dG': 1.2600000000000016,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9007-1',
#                              'ligand_j': 'lig_38906-2'},
#  'lig_9007-1->lig_5605-1': {'dG': -0.3200000000000003,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9007-1',
#                             'ligand_j': 'lig_5605-1'},
#  'lig_9007-1->lig_9998-1': {'dG': -1.3600000000000003,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9007-1',
#                             'ligand_j': 'lig_9998-1'},
#  'lig_9022-1->lig_10757-1': {'dG': 0.0099999999999997,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9022-1',
#                              'ligand_j': 'lig_10757-1'},
#  'lig_9022-1->lig_15107-2': {'dG': -1.8500000000000012,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9022-1',
#                              'ligand_j': 'lig_15107-2'},
#  'lig_9022-1->lig_3553-1': {'dG': -2.9800000000000004,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9022-1',
#                             'ligand_j': 'lig_3553-1'},
#  'lig_9022-1->lig_44002-1': {'dG': 2.5599999999999987,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9022-1',
#                              'ligand_j': 'lig_44002-1'},
#  'lig_9027-1->lig_40387-1': {'dG': 3.2700000000000102,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9027-1',
#                              'ligand_j': 'lig_40387-1'},
#  'lig_9027-1->lig_45240-1': {'dG': 1.869999999999976,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9027-1',
#                              'ligand_j': 'lig_45240-1'},
#  'lig_9027-1->lig_4814-2': {'dG': 0.1800000000000068,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9027-1',
#                             'ligand_j': 'lig_4814-2'},
#  'lig_9027-1->lig_6706-1': {'dG': -3.0900000000000034,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9027-1',
#                             'ligand_j': 'lig_6706-1'},
#  'lig_9027-1->lig_8858-1': {'dG': 9.870000000000005,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9027-1',
#                             'ligand_j': 'lig_8858-1'},
#  'lig_907-2->lig_10315-1': {'dG': 4.980000000000004,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_907-2',
#                             'ligand_j': 'lig_10315-1'},
#  'lig_907-3->lig_19737-2': {'dG': 7.270000000000003,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_907-3',
#                             'ligand_j': 'lig_19737-2'},
#  'lig_9124-1->lig_12201-1': {'dG': -0.2999999999999971,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9124-1',
#                              'ligand_j': 'lig_12201-1'},
#  'lig_9124-1->lig_20801-1': {'dG': 9.57,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9124-1',
#                              'ligand_j': 'lig_20801-1'},
#  'lig_9124-1->lig_44102-1': {'dG': -1.69,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9124-1',
#                              'ligand_j': 'lig_44102-1'},
#  'lig_9412-1->lig_10315-1': {'dG': 5.27,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_10315-1'},
#  'lig_9412-1->lig_13333-1': {'dG': 1.7899999999999991,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_13333-1'},
#  'lig_9412-1->lig_14384-1': {'dG': 2.6700000000000017,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_14384-1'},
#  'lig_9412-1->lig_15474-1': {'dG': -0.4099999999999966,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_15474-1'},
#  'lig_9412-1->lig_20730-1': {'dG': -0.4600000000000008,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_20730-1'},
#  'lig_9412-1->lig_26586-1': {'dG': -3.5500000000000007,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_26586-1'},
#  'lig_9412-1->lig_27578-1': {'dG': -1.5299999999999994,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_27578-1'},
#  'lig_9412-1->lig_29195-1': {'dG': -2.530000000000001,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_29195-1'},
#  'lig_9412-1->lig_29611-1': {'dG': 9.8,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_29611-1'},
#  'lig_9412-1->lig_3790-1': {'dG': 0.0599999999999987,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9412-1',
#                             'ligand_j': 'lig_3790-1'},
#  'lig_9412-1->lig_38906-2': {'dG': 0.8400000000000034,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_38906-2'},
#  'lig_9412-1->lig_45240-1': {'dG': 1.3299999999999983,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9412-1',
#                              'ligand_j': 'lig_45240-1'},
#  'lig_9412-1->lig_5675-1': {'dG': 1.6400000000000023,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9412-1',
#                             'ligand_j': 'lig_5675-1'},
#  'lig_9413-1->lig_21289-1': {'dG': 1.7600000000000051,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9413-1',
#                              'ligand_j': 'lig_21289-1'},
#  'lig_9413-1->lig_37772-2': {'dG': -6.080000000000002,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9413-1',
#                              'ligand_j': 'lig_37772-2'},
#  'lig_9413-1->lig_42433-1': {'dG': -1.489999999999999,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9413-1',
#                              'ligand_j': 'lig_42433-1'},
#  'lig_9745-1->lig_27566-2': {'dG': 1.990000000000002,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9745-1',
#                              'ligand_j': 'lig_27566-2'},
#  'lig_9745-1->lig_27566-3': {'dG': 2.989999999999995,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9745-1',
#                              'ligand_j': 'lig_27566-3'},
#  'lig_9745-1->lig_29835-1': {'dG': 0.0,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9745-1',
#                              'ligand_j': 'lig_29835-1'},
#  'lig_9745-1->lig_37203-1': {'dG': -1.4299999999999995,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9745-1',
#                              'ligand_j': 'lig_37203-1'},
#  'lig_9747-1->lig_10690-1': {'dG': 0.7599999999999998,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9747-1',
#                              'ligand_j': 'lig_10690-1'},
#  'lig_9757-1->lig_32428-1': {'dG': -2.299999999999999,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9757-1',
#                              'ligand_j': 'lig_32428-1'},
#  'lig_9757-1->lig_5718-1': {'dG': -3.879999999999999,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9757-1',
#                             'ligand_j': 'lig_5718-1'},
#  'lig_9758-1->lig_3109-1': {'dG': -2.129999999999999,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9758-1',
#                             'ligand_j': 'lig_3109-1'},
#  'lig_9910-1->lig_1428-1': {'dG': -1.209999999999999,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9910-1',
#                             'ligand_j': 'lig_1428-1'},
#  'lig_9910-1->lig_15514-1': {'dG': -2.9499999999999997,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9910-1',
#                              'ligand_j': 'lig_15514-1'},
#  'lig_9910-1->lig_17917-2': {'dG': -1.8699999999999972,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9910-1',
#                              'ligand_j': 'lig_17917-2'},
#  'lig_9910-1->lig_17928-3': {'dG': -2.75,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9910-1',
#                              'ligand_j': 'lig_17928-3'},
#  'lig_9910-1->lig_24930-2': {'dG': -2.13,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9910-1',
#                              'ligand_j': 'lig_24930-2'},
#  'lig_9910-1->lig_34551-1': {'dG': -3.2700000000000005,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9910-1',
#                              'ligand_j': 'lig_34551-1'},
#  'lig_9910-1->lig_3570-1': {'dG': 2.3200000000000003,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9910-1',
#                             'ligand_j': 'lig_3570-1'},
#  'lig_9910-1->lig_5605-1': {'dG': 0.1400000000000005,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9910-1',
#                             'ligand_j': 'lig_5605-1'},
#  'lig_9924-1->lig_35489-1': {'dG': 1.6099999999999994,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9924-1',
#                              'ligand_j': 'lig_35489-1'},
#  'lig_9952-1->lig_16400-1': {'dG': 1.4299999999999995,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9952-1',
#                              'ligand_j': 'lig_16400-1'},
#  'lig_9952-1->lig_19720-4': {'dG': 5.259999999999998,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9952-1',
#                              'ligand_j': 'lig_19720-4'},
#  'lig_9952-1->lig_21286-3': {'dG': -1.8800000000000023,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9952-1',
#                              'ligand_j': 'lig_21286-3'},
#  'lig_9952-1->lig_26782-2': {'dG': 3.649999999999999,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9952-1',
#                              'ligand_j': 'lig_26782-2'},
#  'lig_9952-1->lig_3446-1': {'dG': 1.0799999999999983,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9952-1',
#                             'ligand_j': 'lig_3446-1'},
#  'lig_9952-1->lig_3828-1': {'dG': 1.66,
#                             'ddG': 0.01,
#                             'ligand_i': 'lig_9952-1',
#                             'ligand_j': 'lig_3828-1'},
#  'lig_9998-1->lig_14703-1': {'dG': 1.88,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9998-1',
#                              'ligand_j': 'lig_14703-1'},
#  'lig_9998-1->lig_17917-2': {'dG': 0.6400000000000006,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9998-1',
#                              'ligand_j': 'lig_17917-2'},
#  'lig_9998-1->lig_42003-1': {'dG': 0.5,
#                              'ddG': 0.01,
#                              'ligand_i': 'lig_9998-1',
#                              'ligand_j': 'lig_42003-1'}}

# %%
cinnabar_filename = './final_results_core4_R2_cin.tsv'

with open(cinnabar_filename, 'w') as f:
    f.write("# Experimental block\n")
    f.write("# Ligand, expt_DDG, expt_dDDG\n")
    for entry in experimental_data:
        dG = experimental_data[entry]['dG']
        ddG = experimental_data[entry]['ddG']
        f.write(f"{entry},{dG:.2f},{ddG:.2f}\n")
    f.write('\n')
    f.write('# Calculated block\n')
    f.write('# Ligand1,Ligand2,calc_DDG,calc_dDDG(MBAR),calc_dDDG(additional)\n')
    for entry in calculated_data:
        dG = calculated_data[entry]['dG']
        ddG = calculated_data[entry]['ddG']
        molA = calculated_data[entry]['ligand_i']
        molB = calculated_data[entry]['ligand_j']
        f.write(f"{molA},{molB},{dG:.2f},0,{ddG:.2f}\n")

# %%
fe = femap.FEMap.from_csv('./final_results_core4_R2_cin.tsv')
fe.generate_absolute_values()  # Get MLE generated estimates of the absolute values
fe.draw_graph()
fe.generate_absolute_values()
# Out:
# /home/hiroyuki/miniforge3/envs/openfe_env/lib/python3.12/site-packages/cinnabar/femap.py:35: UserWarning: Assuming kcal/mol units on measurements
#   warnings.warn("Assuming kcal/mol units on measurements")

# %%
dG_results = {}
nodes = list(fe.to_legacy_graph().nodes.data())
print(nodes)


for key in range(len(nodes)):
    dG_results[nodes[key][0]] = {
        #'experimental_estimate': nodes[key][1]['exp_DG'],
        #'experimental_error': nodes[key][1]['exp_dDG'],
        'calculated_estimate': round(nodes[key][1]['calc_DG'],2),
        'calculated_error': round(nodes[key][1]['calc_dDG'],2),
    }

# write out the calculated results
# set the DE(MLE) of "lig_13-99" as the reference to 0
with open('./cinnabar_output_core4_R2.dat', 'w') as f:
    writer = csv.writer(f, delimiter="\t", lineterminator="\n")
    writer.writerow(["ligand", "DG(MLE)", "uncertainty (kcal/mol)",])
    for ligand in dG_results:
        writer.writerow([
            ligand,
            dG_results[ligand]['calculated_estimate']+3.64,
            dG_results[ligand]['calculated_error'],
        ])
        print(dG_results[ligand])
# Out:
# [('lig_14876-4', {'calc_DG': -2.0300312221747916, 'calc_dDG': 0.007705551498971998}), ('lig_182-1', {'calc_DG': -0.05448804394527329, 'calc_dDG': 0.002497610955882677}), ('lig_27644-1', {'calc_DG': 0.5744255995956244, 'calc_dDG': 0.004939411489652925}), ('lig_39967-1', {'calc_DG': -3.7940864284798472, 'calc_dDG': 0.007406232052944121}), ('lig_3514-1', {'calc_DG': 0.3276671991469975, 'calc_dDG': 0.005589857351839252}), ('lig_17905-1', {'calc_DG': 0.7263597662130064, 'calc_dDG': 0.004175924387658456}), ('lig_4357-1', {'calc_DG': 1.8510016431288001, 'calc_dDG': 0.006606632010513172}), ('lig_15485-1', {'calc_DG': 2.620296332836748, 'calc_dDG': 0.004707757907476087}), ('lig_44002-3', {'calc_DG': -0.07902643179554758, 'calc_dDG': 0.005420879933341153}), ('lig_18799-1', {'calc_DG': 4.372120426109969, 'calc_dDG': 0.004620473145698989}), ('lig_42003-1', {'calc_DG': 0.9811897392250124, 'calc_dDG': 0.005559878186304022}), ('lig_21641-1', {'calc_DG': 2.938473330084573, 'calc_dDG': 0.007608533387224468}), ('lig_11210-1', {'calc_DG': 0.8214347041144503, 'calc_dDG': 0.004312698376767697}), ('lig_41138-4', {'calc_DG': -0.5932018687273306, 'calc_dDG': 0.0070328755526170555}), ('lig_10839-1', {'calc_DG': -1.6072328921857846, 'calc_dDG': 0.007406384965445588}), ('lig_27098-1', {'calc_DG': 1.8255873920225998, 'calc_dDG': 0.006052848884532265}), ('lig_40812-1', {'calc_DG': -0.7363710705754567, 'calc_dDG': 0.0037658851944444446}), ('lig_2283-1', {'calc_DG': 2.797305040705689, 'calc_dDG': 0.006586076472020881}), ('lig_27098-2', {'calc_DG': 2.4459036419055806, 'calc_dDG': 0.007945264950494775}), ('lig_14989-1', {'calc_DG': 1.7465173655459285, 'calc_dDG': 0.006712857986926397}), ('lig_38285-2', {'calc_DG': 3.8989945468412177, 'calc_dDG': 0.005732838683029742}), ('lig_30363-1', {'calc_DG': 3.5850455937418015, 'calc_dDG': 0.0062303526244686935}), ('lig_14828-1', {'calc_DG': 0.01851259219946222, 'calc_dDG': 0.004381696354945365}), ('lig_27554-1', {'calc_DG': 0.5080960437460789, 'calc_dDG': 0.005033870636644496}), ('lig_41644-2', {'calc_DG': -0.7085265786003028, 'calc_dDG': 0.003941997824472948}), ('lig_15107-1', {'calc_DG': -1.0531323260023697, 'calc_dDG': 0.0029434042928964447}), ('lig_1943-1', {'calc_DG': -2.1407115857948504, 'calc_dDG': 0.0030360831812660154}), ('lig_21119-1', {'calc_DG': -0.8817756311745413, 'calc_dDG': 0.002949492725127959}), ('lig_17919-1', {'calc_DG': 0.359949620791312, 'calc_dDG': 0.0032666970372848846}), ('lig_12277-1', {'calc_DG': -0.16739533374915538, 'calc_dDG': 0.004738737500911821}), ('lig_2895-1', {'calc_DG': 0.38060783342916515, 'calc_dDG': 0.0028648597865791954}), ('lig_44143-1', {'calc_DG': 4.514858586859047, 'calc_dDG': 0.004278209902550703}), ('lig_16598-4', {'calc_DG': 0.28696235926261693, 'calc_dDG': 0.004730030749679726}), ('lig_38256-4', {'calc_DG': 2.219236612563229, 'calc_dDG': 0.005218719415770935}), ('lig_34121-2', {'calc_DG': -0.7882161054725518, 'calc_dDG': 0.004431599316954296}), ('lig_5693-1', {'calc_DG': -0.9419420843266053, 'calc_dDG': 0.00373265135693491}), ('lig_29605-2', {'calc_DG': 5.48551195605469, 'calc_dDG': 0.010300006383146704}), ('lig_29605-1', {'calc_DG': 2.6130594423660582, 'calc_dDG': 0.007621531307250938}), ('lig_29605-3', {'calc_DG': 1.2883741473259285, 'calc_dDG': 0.007548683518562925}), ('lig_17771-1', {'calc_DG': -2.358763661402863, 'calc_dDG': 0.003867904497433617}), ('lig_35181-4', {'calc_DG': 0.880508158048297, 'calc_dDG': 0.007720613053486539}), ('lig_16635-2', {'calc_DG': -0.8839338310511611, 'calc_dDG': 0.004323234008981402}), ('lig_1364-1', {'calc_DG': -0.709977740426254, 'calc_dDG': 0.0025569163363612433}), ('lig_39859-1', {'calc_DG': -0.0771084578138641, 'calc_dDG': 0.004513125943198223}), ('lig_1433-1', {'calc_DG': 0.11561549694669537, 'calc_dDG': 0.0027258698993626734}), ('lig_4616-1', {'calc_DG': 0.03820198661774121, 'calc_dDG': 0.0033959347052653437}), ('lig_5605-1', {'calc_DG': -0.4366823608252606, 'calc_dDG': 0.003402182156263544}), ('lig_27976-1', {'calc_DG': 1.043162829 ...
# {'calculated_estimate': -2.03, 'calculated_error': 0.01}
# {'calculated_estimate': -0.05, 'calculated_error': 0.0}
# {'calculated_estimate': 0.57, 'calculated_error': 0.0}
# {'calculated_estimate': -3.79, 'calculated_error': 0.01}
# {'calculated_estimate': 0.33, 'calculated_error': 0.01}
# {'calculated_estimate': 0.73, 'calculated_error': 0.0}
# {'calculated_estimate': 1.85, 'calculated_error': 0.01}
# {'calculated_estimate': 2.62, 'calculated_error': 0.0}
# {'calculated_estimate': -0.08, 'calculated_error': 0.01}
# {'calculated_estimate': 4.37, 'calculated_error': 0.0}
# {'calculated_estimate': 0.98, 'calculated_error': 0.01}
# {'calculated_estimate': 2.94, 'calculated_error': 0.01}
# {'calculated_estimate': 0.82, 'calculated_error': 0.0}
# {'calculated_estimate': -0.59, 'calculated_error': 0.01}
# {'calculated_estimate': -1.61, 'calculated_error': 0.01}
# {'calculated_estimate': 1.83, 'calculated_error': 0.01}
# {'calculated_estimate': -0.74, 'calculated_error': 0.0}
# {'calculated_estimate': 2.8, 'calculated_error': 0.01}
# {'calculated_estimate': 2.45, 'calculated_error': 0.01}
# {'calculated_estimate': 1.75, 'calculated_error': 0.01}
# {'calculated_estimate': 3.9, 'calculated_error': 0.01}
# {'calculated_estimate': 3.59, 'calculated_error': 0.01}
# {'calculated_estimate': 0.02, 'calculated_error': 0.0}
# {'calculated_estimate': 0.51, 'calculated_error': 0.01}
# {'calculated_estimate': -0.71, 'calculated_error': 0.0}
# {'calculated_estimate': -1.05, 'calculated_error': 0.0}
# {'calculated_estimate': -2.14, 'calculated_error': 0.0}
# {'calculated_estimate': -0.88, 'calculated_error': 0.0}
# {'calculated_estimate': 0.36, 'calculated_error': 0.0}
# {'calculated_estimate': -0.17, 'calculated_error': 0.0}
# {'calculated_estimate': 0.38, 'calculated_error': 0.0}
# {'calculated_estimate': 4.51, 'calculated_error': 0.0}
# {'calculated_estimate': 0.29, 'calculated_error': 0.0}
# {'calculated_estimate': 2.22, 'calculated_error': 0.01}
# {'calculated_estimate': -0.79, 'calculated_error': 0.0}
# {'calculated_estimate': -0.94, 'calculated_error': 0.0}
# {'calculated_estimate': 5.49, 'calculated_error': 0.01}
# {'calculated_estimate': 2.61, 'calculated_error': 0.01}
# {'calculated_estimate': 1.29, 'calculated_error': 0.01}
# {'calculated_estimate': -2.36, 'calculated_error': 0.0}
# {'calculated_estimate': 0.88, 'calculated_error': 0.01}
# {'calculated_estimate': -0.88, 'calculated_error': 0.0}
# {'calculated_estimate': -0.71, 'calculated_error': 0.0}
# {'calculated_estimate': -0.08, 'calculated_error': 0.0}
# {'calculated_estimate': 0.12, 'calculated_error': 0.0}
# {'calculated_estimate': 0.04, 'calculated_error': 0.0}
# {'calculated_estimate': -0.44, 'calculated_error': 0.0}
# {'calculated_estimate': 1.04, 'calculated_error': 0.0}
# {'calculated_estimate': 2.44, 'calculated_error': 0.0}
# {'calculated_estimate': 0.32, 'calculated_error': 0.0}
# {'calculated_estimate': -1.08, 'calculated_error': 0.0}
# {'calculated_estimate': 0.53, 'calculated_error': 0.01}
# {'calculated_estimate': 0.52, 'calculated_error': 0.0}
# {'calculated_estimate': 1.9, 'calculated_error': 0.0}
# {'calculated_estimate': 0.4, 'calculated_error': 0.0}
# {'calculated_estimate': 0.55, 'calculated_error': 0.01}
# {'calculated_estimate': -0.11, 'calculated_error': 0.0}
# {'calculated_estimate': -0.46, 'calculated_error': 0.01}
# {'calculated_estimate': -1.98, 'calculated_error': 0.0}
# {'calculated_estimate': -0.58, 'calculated_error': 0.0}
# {'calculated_estimate': 0.94, 'calculated_error': 0.01}
# {'calculated_estimate': 1.76, 'calculated_error': 0.0}
# {'calculated_estimate': 1.99, 'calculated_error': 0.0}
# {'calculated_estimate': 1.62, 'calculated_error': 0.01}
# {'calculated_estimate': 0.31, 'calculated_error': 0.01}
# {'calculated_estimate': 2.18, 'calculated_error': 0.01}
# {'calculated_estimate': 1.15, 'calculated_error': 0.0}
# {'calculated_estimate': 0.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.2, 'calculated_error': 0.0}
# {'calculated_estimate': 5.6, 'calculated_error': 0.01}
# {'calculated_estimate': -0.94, 'calculated_error': 0.0}
# {'calculated_estimate': -0.19, 'calculated_error': 0.01}
# {'calculated_estimate': -1.25, 'calculated_error': 0.01}
# {'calculated_estimate': 0.52, 'calculated_error': 0.01}
# {'calculated_estimate': 1.01, 'calculated_error': 0.0}
# {'calculated_estimate': -0.22, 'calculated_error': 0.0}
# {'calculated_estimate': 1.65, 'calculated_error': 0.01}
# {'calculated_estimate': -1.26, 'calculated_error': 0.0}
# {'calculated_estimate': 0.36, 'calculated_error': 0.0}
# {'calculated_estimate': -0.44, 'calculated_error': 0.01}
# {'calculated_estimate': 2.39, 'calculated_error': 0.01}
# {'calculated_estimate': 0.15, 'calculated_error': 0.01}
# {'calculated_estimate': -0.59, 'calculated_error': 0.01}
# {'calculated_estimate': 1.83, 'calculated_error': 0.01}
# {'calculated_estimate': 4.12, 'calculated_error': 0.01}
# {'calculated_estimate': -5.32, 'calculated_error': 0.01}
# {'calculated_estimate': 3.46, 'calculated_error': 0.0}
# {'calculated_estimate': 0.92, 'calculated_error': 0.0}
# {'calculated_estimate': -0.39, 'calculated_error': 0.01}
# {'calculated_estimate': 2.59, 'calculated_error': 0.0}
# {'calculated_estimate': -2.13, 'calculated_error': 0.0}
# {'calculated_estimate': 1.09, 'calculated_error': 0.0}
# {'calculated_estimate': -4.92, 'calculated_error': 0.01}
# {'calculated_estimate': 1.21, 'calculated_error': 0.01}
# {'calculated_estimate': -1.74, 'calculated_error': 0.01}
# {'calculated_estimate': 0.58, 'calculated_error': 0.0}
# {'calculated_estimate': -0.46, 'calculated_error': 0.0}
# {'calculated_estimate': 0.7, 'calculated_error': 0.0}
# {'calculated_estimate': 0.5, 'calculated_error': 0.01}
# {'calculated_estimate': -1.49, 'calculated_error': 0.0}
# {'calculated_estimate': 0.69, 'calculated_error': 0.01}
# {'calculated_estimate': -1.8, 'calculated_error': 0.01}
# {'calculated_estimate': 1.46, 'calculated_error': 0.0}
# {'calculated_estimate': 1.2, 'calculated_error': 0.01}
# {'calculated_estimate': 2.05, 'calculated_error': 0.0}
# {'calculated_estimate': 0.97, 'calculated_error': 0.0}
# {'calculated_estimate': -1.99, 'calculated_error': 0.0}
# {'calculated_estimate': 0.49, 'calculated_error': 0.0}
# {'calculated_estimate': -0.71, 'calculated_error': 0.0}
# {'calculated_estimate': -3.77, 'calculated_error': 0.0}
# {'calculated_estimate': 0.01, 'calculated_error': 0.0}
# {'calculated_estimate': -1.2, 'calculated_error': 0.0}
# {'calculated_estimate': 1.89, 'calculated_error': 0.01}
# {'calculated_estimate': -1.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.69, 'calculated_error': 0.0}
# {'calculated_estimate': 3.23, 'calculated_error': 0.01}
# {'calculated_estimate': -2.75, 'calculated_error': 0.01}
# {'calculated_estimate': -0.21, 'calculated_error': 0.01}
# {'calculated_estimate': 0.49, 'calculated_error': 0.01}
# {'calculated_estimate': 2.13, 'calculated_error': 0.01}
# {'calculated_estimate': 0.8, 'calculated_error': 0.0}
# {'calculated_estimate': 2.68, 'calculated_error': 0.0}
# {'calculated_estimate': -0.29, 'calculated_error': 0.01}
# {'calculated_estimate': 0.75, 'calculated_error': 0.0}
# {'calculated_estimate': 1.13, 'calculated_error': 0.0}
# {'calculated_estimate': 0.6, 'calculated_error': 0.01}
# {'calculated_estimate': 0.65, 'calculated_error': 0.0}
# {'calculated_estimate': 1.79, 'calculated_error': 0.01}
# {'calculated_estimate': 3.23, 'calculated_error': 0.01}
# {'calculated_estimate': -1.37, 'calculated_error': 0.0}
# {'calculated_estimate': -0.18, 'calculated_error': 0.0}
# {'calculated_estimate': 2.62, 'calculated_error': 0.0}
# {'calculated_estimate': -5.89, 'calculated_error': 0.01}
# {'calculated_estimate': 1.22, 'calculated_error': 0.0}
# {'calculated_estimate': -0.19, 'calculated_error': 0.0}
# {'calculated_estimate': 2.14, 'calculated_error': 0.0}
# {'calculated_estimate': -0.19, 'calculated_error': 0.0}
# {'calculated_estimate': -0.2, 'calculated_error': 0.0}
# {'calculated_estimate': -0.25, 'calculated_error': 0.0}
# {'calculated_estimate': 1.92, 'calculated_error': 0.0}
# {'calculated_estimate': -1.98, 'calculated_error': 0.0}
# {'calculated_estimate': 2.2, 'calculated_error': 0.01}
# {'calculated_estimate': 3.08, 'calculated_error': 0.0}
# {'calculated_estimate': 2.95, 'calculated_error': 0.0}
# {'calculated_estimate': 3.25, 'calculated_error': 0.01}
# {'calculated_estimate': 1.49, 'calculated_error': 0.0}
# {'calculated_estimate': 1.95, 'calculated_error': 0.01}
# {'calculated_estimate': 2.7, 'calculated_error': 0.01}
# {'calculated_estimate': 5.08, 'calculated_error': 0.01}
# {'calculated_estimate': -0.45, 'calculated_error': 0.01}
# {'calculated_estimate': -2.74, 'calculated_error': 0.01}
# {'calculated_estimate': 1.63, 'calculated_error': 0.0}
# {'calculated_estimate': 0.1, 'calculated_error': 0.0}
# {'calculated_estimate': 0.06, 'calculated_error': 0.0}
# {'calculated_estimate': 2.64, 'calculated_error': 0.0}
# {'calculated_estimate': 4.2, 'calculated_error': 0.0}
# {'calculated_estimate': -2.53, 'calculated_error': 0.01}
# {'calculated_estimate': -0.1, 'calculated_error': 0.0}
# {'calculated_estimate': -2.18, 'calculated_error': 0.0}
# {'calculated_estimate': 0.76, 'calculated_error': 0.0}
# {'calculated_estimate': 1.19, 'calculated_error': 0.01}
# {'calculated_estimate': -1.38, 'calculated_error': 0.01}
# {'calculated_estimate': -1.7, 'calculated_error': 0.01}
# {'calculated_estimate': -2.97, 'calculated_error': 0.01}
# {'calculated_estimate': 0.43, 'calculated_error': 0.01}
# {'calculated_estimate': -2.46, 'calculated_error': 0.01}
# {'calculated_estimate': -2.49, 'calculated_error': 0.01}
# {'calculated_estimate': -3.06, 'calculated_error': 0.01}
# {'calculated_estimate': -3.08, 'calculated_error': 0.01}
# {'calculated_estimate': -2.05, 'calculated_error': 0.01}
# {'calculated_estimate': -1.38, 'calculated_error': 0.01}
# {'calculated_estimate': -3.23, 'calculated_error': 0.01}
# {'calculated_estimate': -1.42, 'calculated_error': 0.01}
# {'calculated_estimate': -2.46, 'calculated_error': 0.01}
# {'calculated_estimate': -2.16, 'calculated_error': 0.01}
# {'calculated_estimate': -3.55, 'calculated_error': 0.01}
# {'calculated_estimate': -1.69, 'calculated_error': 0.01}
# {'calculated_estimate': -3.44, 'calculated_error': 0.01}
# {'calculated_estimate': -2.23, 'calculated_error': 0.01}
# {'calculated_estimate': -4.82, 'calculated_error': 0.01}
# {'calculated_estimate': -1.01, 'calculated_error': 0.01}
# {'calculated_estimate': -2.21, 'calculated_error': 0.01}
# {'calculated_estimate': -2.72, 'calculated_error': 0.01}
# {'calculated_estimate': -3.37, 'calculated_error': 0.01}
# {'calculated_estimate': -2.55, 'calculated_error': 0.01}
# {'calculated_estimate': -3.34, 'calculated_error': 0.01}
# {'calculated_estimate': -2.15, 'calculated_error': 0.01}
# {'calculated_estimate': -0.22, 'calculated_error': 0.01}
# {'calculated_estimate': -3.33, 'calculated_error': 0.01}
# {'calculated_estimate': -3.0, 'calculated_error': 0.01}
# {'calculated_estimate': -1.95, 'calculated_error': 0.01}
# {'calculated_estimate': -3.19, 'calculated_error': 0.01}
# {'calculated_estimate': -2.53, 'calculated_error': 0.01}
# {'calculated_estimate': -0.08, 'calculated_error': 0.01}
# {'calculated_estimate': -1.82, 'calculated_error': 0.01}
# {'calculated_estimate': -4.71, 'calculated_error': 0.01}
# {'calculated_estimate': -3.05, 'calculated_error': 0.01}
# {'calculated_estimate': -3.01, 'calculated_error': 0.01}
# {'calculated_estimate': -1.64, 'calculated_error': 0.01}
# {'calculated_estimate': -1.07, 'calculated_error': 0.01}
# {'calculated_estimate': 2.37, 'calculated_error': 0.01}
# {'calculated_estimate': 0.4, 'calculated_error': 0.01}
# {'calculated_estimate': -4.08, 'calculated_error': 0.01}
# {'calculated_estimate': -1.6, 'calculated_error': 0.01}
# {'calculated_estimate': -0.63, 'calculated_error': 0.01}
# {'calculated_estimate': -2.08, 'calculated_error': 0.01}
# {'calculated_estimate': -1.57, 'calculated_error': 0.01}
# {'calculated_estimate': -4.67, 'calculated_error': 0.01}
# {'calculated_estimate': -2.27, 'calculated_error': 0.01}
# {'calculated_estimate': -2.99, 'calculated_error': 0.01}
# {'calculated_estimate': -4.28, 'calculated_error': 0.01}
# {'calculated_estimate': 1.55, 'calculated_error': 0.01}
# {'calculated_estimate': -3.08, 'calculated_error': 0.01}
# {'calculated_estimate': -3.06, 'calculated_error': 0.01}
# {'calculated_estimate': -1.38, 'calculated_error': 0.01}
# {'calculated_estimate': 0.9, 'calculated_error': 0.01}
# {'calculated_estimate': -1.83, 'calculated_error': 0.01}
# {'calculated_estimate': -1.54, 'calculated_error': 0.01}
# {'calculated_estimate': -3.87, 'calculated_error': 0.01}
# {'calculated_estimate': 0.1, 'calculated_error': 0.01}
# {'calculated_estimate': -0.73, 'calculated_error': 0.01}
# {'calculated_estimate': -4.8, 'calculated_error': 0.01}
# {'calculated_estimate': -0.83, 'calculated_error': 0.01}
# {'calculated_estimate': -3.36, 'calculated_error': 0.01}
# {'calculated_estimate': -1.23, 'calculated_error': 0.01}
# {'calculated_estimate': -1.26, 'calculated_error': 0.01}
# {'calculated_estimate': -2.49, 'calculated_error': 0.01}
# {'calculated_estimate': -3.14, 'calculated_error': 0.01}
# {'calculated_estimate': -3.55, 'calculated_error': 0.01}
# {'calculated_estimate': -5.4, 'calculated_error': 0.01}
# {'calculated_estimate': -1.89, 'calculated_error': 0.01}
# {'calculated_estimate': -1.78, 'calculated_error': 0.01}
# {'calculated_estimate': -2.55, 'calculated_error': 0.01}
# {'calculated_estimate': -0.87, 'calculated_error': 0.01}
# {'calculated_estimate': -2.77, 'calculated_error': 0.01}
# {'calculated_estimate': -1.14, 'calculated_error': 0.01}
# {'calculated_estimate': -2.63, 'calculated_error': 0.01}
# {'calculated_estimate': -1.49, 'calculated_error': 0.01}
# {'calculated_estimate': -0.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.59, 'calculated_error': 0.01}
# {'calculated_estimate': -1.33, 'calculated_error': 0.01}
# {'calculated_estimate': 2.62, 'calculated_error': 0.01}
# {'calculated_estimate': 1.9, 'calculated_error': 0.01}
# {'calculated_estimate': -0.94, 'calculated_error': 0.01}
# {'calculated_estimate': -3.38, 'calculated_error': 0.01}
# {'calculated_estimate': -3.36, 'calculated_error': 0.01}
# {'calculated_estimate': -0.46, 'calculated_error': 0.01}
# {'calculated_estimate': -1.83, 'calculated_error': 0.01}
# {'calculated_estimate': -1.38, 'calculated_error': 0.01}
# {'calculated_estimate': -1.67, 'calculated_error': 0.01}
# {'calculated_estimate': -0.25, 'calculated_error': 0.01}
# {'calculated_estimate': -3.28, 'calculated_error': 0.01}
# {'calculated_estimate': -3.84, 'calculated_error': 0.01}
# {'calculated_estimate': -1.95, 'calculated_error': 0.01}
# {'calculated_estimate': -4.19, 'calculated_error': 0.01}
# {'calculated_estimate': -3.02, 'calculated_error': 0.01}
# {'calculated_estimate': -4.15, 'calculated_error': 0.01}
# {'calculated_estimate': -1.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.31, 'calculated_error': 0.01}
# {'calculated_estimate': -2.6, 'calculated_error': 0.01}
# {'calculated_estimate': -0.42, 'calculated_error': 0.01}
# {'calculated_estimate': -1.2, 'calculated_error': 0.01}
# {'calculated_estimate': -1.99, 'calculated_error': 0.01}
# {'calculated_estimate': -4.73, 'calculated_error': 0.01}
# {'calculated_estimate': -2.03, 'calculated_error': 0.01}
# {'calculated_estimate': -2.4, 'calculated_error': 0.01}
# {'calculated_estimate': 0.3, 'calculated_error': 0.01}
# {'calculated_estimate': -2.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.21, 'calculated_error': 0.01}
# {'calculated_estimate': -4.73, 'calculated_error': 0.01}
# {'calculated_estimate': -0.47, 'calculated_error': 0.01}
# {'calculated_estimate': -0.68, 'calculated_error': 0.01}
# {'calculated_estimate': -0.87, 'calculated_error': 0.01}
# {'calculated_estimate': -0.92, 'calculated_error': 0.01}
# {'calculated_estimate': -1.87, 'calculated_error': 0.01}
# {'calculated_estimate': 2.27, 'calculated_error': 0.01}
# {'calculated_estimate': 0.14, 'calculated_error': 0.01}
# {'calculated_estimate': -2.85, 'calculated_error': 0.01}
# {'calculated_estimate': -1.91, 'calculated_error': 0.01}
# {'calculated_estimate': 0.7, 'calculated_error': 0.01}
# {'calculated_estimate': 1.7, 'calculated_error': 0.01}
# {'calculated_estimate': -3.47, 'calculated_error': 0.01}
# {'calculated_estimate': 1.18, 'calculated_error': 0.01}
# {'calculated_estimate': 0.35, 'calculated_error': 0.01}
# {'calculated_estimate': 2.73, 'calculated_error': 0.01}
# {'calculated_estimate': 0.04, 'calculated_error': 0.01}
# {'calculated_estimate': 0.5, 'calculated_error': 0.01}
# {'calculated_estimate': 1.92, 'calculated_error': 0.01}
# {'calculated_estimate': 1.76, 'calculated_error': 0.01}
# {'calculated_estimate': -1.59, 'calculated_error': 0.01}
# {'calculated_estimate': -1.04, 'calculated_error': 0.01}
# {'calculated_estimate': -1.13, 'calculated_error': 0.01}
# {'calculated_estimate': 2.1, 'calculated_error': 0.01}
# {'calculated_estimate': -0.88, 'calculated_error': 0.01}
# {'calculated_estimate': -0.05, 'calculated_error': 0.01}
# {'calculated_estimate': -3.05, 'calculated_error': 0.01}
# {'calculated_estimate': -3.19, 'calculated_error': 0.01}
# {'calculated_estimate': -4.19, 'calculated_error': 0.01}
# {'calculated_estimate': -3.33, 'calculated_error': 0.01}
# {'calculated_estimate': -1.54, 'calculated_error': 0.01}
# {'calculated_estimate': -2.41, 'calculated_error': 0.01}
# {'calculated_estimate': -0.96, 'calculated_error': 0.01}
# {'calculated_estimate': -0.43, 'calculated_error': 0.01}
# {'calculated_estimate': -2.61, 'calculated_error': 0.01}
# {'calculated_estimate': -1.56, 'calculated_error': 0.01}
# {'calculated_estimate': -0.32, 'calculated_error': 0.01}
# {'calculated_estimate': -1.26, 'calculated_error': 0.01}
# {'calculated_estimate': 0.76, 'calculated_error': 0.01}
# {'calculated_estimate': -1.86, 'calculated_error': 0.01}
# {'calculated_estimate': -3.91, 'calculated_error': 0.01}
# {'calculated_estimate': -3.77, 'calculated_error': 0.01}
# {'calculated_estimate': -2.7, 'calculated_error': 0.01}
# {'calculated_estimate': -2.47, 'calculated_error': 0.01}
# {'calculated_estimate': 0.66, 'calculated_error': 0.01}
# {'calculated_estimate': -0.66, 'calculated_error': 0.01}
# {'calculated_estimate': -1.18, 'calculated_error': 0.01}
# {'calculated_estimate': -3.24, 'calculated_error': 0.01}
# {'calculated_estimate': -0.69, 'calculated_error': 0.01}
# {'calculated_estimate': -1.1, 'calculated_error': 0.01}
# {'calculated_estimate': -1.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.8, 'calculated_error': 0.01}
# {'calculated_estimate': -3.11, 'calculated_error': 0.01}
# {'calculated_estimate': -3.21, 'calculated_error': 0.01}
# {'calculated_estimate': -3.21, 'calculated_error': 0.01}
# {'calculated_estimate': -0.59, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.01}
# {'calculated_estimate': -0.47, 'calculated_error': 0.01}
# {'calculated_estimate': -1.3, 'calculated_error': 0.01}
# {'calculated_estimate': -3.15, 'calculated_error': 0.01}
# {'calculated_estimate': -2.11, 'calculated_error': 0.01}
# {'calculated_estimate': -0.84, 'calculated_error': 0.01}
# {'calculated_estimate': -4.53, 'calculated_error': 0.01}
# {'calculated_estimate': -7.35, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.01}
# {'calculated_estimate': -2.58, 'calculated_error': 0.01}
# {'calculated_estimate': 1.25, 'calculated_error': 0.01}
# {'calculated_estimate': -1.65, 'calculated_error': 0.01}
# {'calculated_estimate': 1.3, 'calculated_error': 0.01}
# {'calculated_estimate': 2.38, 'calculated_error': 0.01}
# {'calculated_estimate': -4.04, 'calculated_error': 0.01}
# {'calculated_estimate': -4.98, 'calculated_error': 0.01}
# {'calculated_estimate': 0.17, 'calculated_error': 0.01}
# {'calculated_estimate': -2.6, 'calculated_error': 0.01}
# {'calculated_estimate': -6.62, 'calculated_error': 0.01}
# {'calculated_estimate': -0.07, 'calculated_error': 0.01}
# {'calculated_estimate': -4.14, 'calculated_error': 0.01}
# {'calculated_estimate': -3.46, 'calculated_error': 0.01}
# {'calculated_estimate': -3.33, 'calculated_error': 0.01}
# {'calculated_estimate': -1.62, 'calculated_error': 0.01}
# {'calculated_estimate': 0.48, 'calculated_error': 0.01}
# {'calculated_estimate': -0.93, 'calculated_error': 0.01}
# {'calculated_estimate': -1.65, 'calculated_error': 0.01}
# {'calculated_estimate': -0.8, 'calculated_error': 0.01}
# {'calculated_estimate': -3.64, 'calculated_error': 0.01}
# {'calculated_estimate': -3.5, 'calculated_error': 0.01}
# {'calculated_estimate': -3.76, 'calculated_error': 0.01}
# {'calculated_estimate': -3.33, 'calculated_error': 0.01}
# {'calculated_estimate': -0.4, 'calculated_error': 0.01}
# {'calculated_estimate': -2.71, 'calculated_error': 0.01}
# {'calculated_estimate': -1.17, 'calculated_error': 0.01}
# {'calculated_estimate': -2.5, 'calculated_error': 0.01}
# {'calculated_estimate': -3.94, 'calculated_error': 0.01}
# {'calculated_estimate': -1.46, 'calculated_error': 0.01}
# {'calculated_estimate': -1.11, 'calculated_error': 0.01}
# {'calculated_estimate': -1.42, 'calculated_error': 0.01}
# {'calculated_estimate': -4.08, 'calculated_error': 0.01}
# {'calculated_estimate': -2.82, 'calculated_error': 0.01}
# {'calculated_estimate': -3.06, 'calculated_error': 0.01}
# {'calculated_estimate': -4.12, 'calculated_error': 0.01}
# {'calculated_estimate': -1.16, 'calculated_error': 0.01}
# {'calculated_estimate': -2.84, 'calculated_error': 0.01}
# {'calculated_estimate': -2.22, 'calculated_error': 0.01}
# {'calculated_estimate': 0.95, 'calculated_error': 0.0}
# {'calculated_estimate': -1.84, 'calculated_error': 0.01}
# {'calculated_estimate': -3.03, 'calculated_error': 0.01}
# {'calculated_estimate': -2.52, 'calculated_error': 0.01}
# {'calculated_estimate': -2.93, 'calculated_error': 0.01}
# {'calculated_estimate': -1.66, 'calculated_error': 0.01}
# {'calculated_estimate': -1.68, 'calculated_error': 0.01}
# {'calculated_estimate': -2.31, 'calculated_error': 0.01}
# {'calculated_estimate': 0.42, 'calculated_error': 0.01}
# {'calculated_estimate': 0.07, 'calculated_error': 0.01}
# {'calculated_estimate': -4.02, 'calculated_error': 0.01}
# {'calculated_estimate': -3.56, 'calculated_error': 0.01}
# {'calculated_estimate': -5.92, 'calculated_error': 0.01}
# {'calculated_estimate': -3.31, 'calculated_error': 0.01}
# {'calculated_estimate': -3.6, 'calculated_error': 0.01}
# {'calculated_estimate': -1.16, 'calculated_error': 0.0}
# {'calculated_estimate': -1.11, 'calculated_error': 0.0}
# {'calculated_estimate': 1.18, 'calculated_error': 0.01}
# {'calculated_estimate': 0.05, 'calculated_error': 0.0}
# {'calculated_estimate': -0.18, 'calculated_error': 0.0}
# {'calculated_estimate': -1.22, 'calculated_error': 0.01}
# {'calculated_estimate': -0.42, 'calculated_error': 0.0}
# {'calculated_estimate': 1.94, 'calculated_error': 0.01}
# {'calculated_estimate': 1.94, 'calculated_error': 0.0}
# {'calculated_estimate': -0.87, 'calculated_error': 0.0}
# {'calculated_estimate': 1.85, 'calculated_error': 0.01}
# {'calculated_estimate': -0.5, 'calculated_error': 0.01}
# {'calculated_estimate': 0.45, 'calculated_error': 0.0}
# {'calculated_estimate': 1.18, 'calculated_error': 0.0}
# {'calculated_estimate': 0.59, 'calculated_error': 0.0}
# {'calculated_estimate': -0.41, 'calculated_error': 0.0}
# {'calculated_estimate': -1.64, 'calculated_error': 0.0}
# {'calculated_estimate': 3.27, 'calculated_error': 0.01}
# {'calculated_estimate': 1.35, 'calculated_error': 0.0}
# {'calculated_estimate': -1.01, 'calculated_error': 0.01}
# {'calculated_estimate': 0.84, 'calculated_error': 0.01}
# {'calculated_estimate': 2.17, 'calculated_error': 0.0}
# {'calculated_estimate': -1.91, 'calculated_error': 0.0}
# {'calculated_estimate': 0.17, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.0}
# {'calculated_estimate': 0.8, 'calculated_error': 0.0}
# {'calculated_estimate': -2.44, 'calculated_error': 0.0}
# {'calculated_estimate': -1.71, 'calculated_error': 0.0}
# {'calculated_estimate': 1.86, 'calculated_error': 0.0}
# {'calculated_estimate': -0.13, 'calculated_error': 0.0}
# {'calculated_estimate': -2.87, 'calculated_error': 0.01}
# {'calculated_estimate': -0.69, 'calculated_error': 0.0}
# {'calculated_estimate': 0.09, 'calculated_error': 0.0}
# {'calculated_estimate': 3.29, 'calculated_error': 0.01}
# {'calculated_estimate': 0.31, 'calculated_error': 0.0}
# {'calculated_estimate': -1.29, 'calculated_error': 0.0}
# {'calculated_estimate': 1.96, 'calculated_error': 0.01}
# {'calculated_estimate': -0.28, 'calculated_error': 0.0}
# {'calculated_estimate': -2.95, 'calculated_error': 0.0}
# {'calculated_estimate': -3.02, 'calculated_error': 0.0}
# {'calculated_estimate': -2.51, 'calculated_error': 0.01}
# {'calculated_estimate': -2.17, 'calculated_error': 0.01}
# {'calculated_estimate': -1.1, 'calculated_error': 0.01}
# {'calculated_estimate': -1.63, 'calculated_error': 0.01}
# {'calculated_estimate': 0.07, 'calculated_error': 0.01}
# {'calculated_estimate': -1.47, 'calculated_error': 0.01}
# {'calculated_estimate': -2.2, 'calculated_error': 0.01}
# {'calculated_estimate': -4.59, 'calculated_error': 0.01}
# {'calculated_estimate': -3.5, 'calculated_error': 0.01}
# {'calculated_estimate': -1.42, 'calculated_error': 0.01}
# {'calculated_estimate': -3.6, 'calculated_error': 0.01}
# {'calculated_estimate': 0.55, 'calculated_error': 0.01}
# {'calculated_estimate': -2.95, 'calculated_error': 0.01}
# {'calculated_estimate': -2.83, 'calculated_error': 0.01}
# {'calculated_estimate': -2.23, 'calculated_error': 0.01}
# {'calculated_estimate': -3.21, 'calculated_error': 0.01}
# {'calculated_estimate': -5.43, 'calculated_error': 0.01}
# {'calculated_estimate': -3.46, 'calculated_error': 0.01}
# {'calculated_estimate': -4.35, 'calculated_error': 0.01}
# {'calculated_estimate': -0.85, 'calculated_error': 0.01}
# {'calculated_estimate': -3.43, 'calculated_error': 0.01}
# {'calculated_estimate': -1.87, 'calculated_error': 0.01}
# {'calculated_estimate': -3.13, 'calculated_error': 0.01}
# {'calculated_estimate': -2.68, 'calculated_error': 0.01}
# {'calculated_estimate': -4.27, 'calculated_error': 0.01}
# {'calculated_estimate': -1.34, 'calculated_error': 0.01}
# {'calculated_estimate': -2.6, 'calculated_error': 0.01}
# {'calculated_estimate': 0.03, 'calculated_error': 0.01}
# {'calculated_estimate': -2.39, 'calculated_error': 0.01}
# {'calculated_estimate': -1.42, 'calculated_error': 0.01}
# {'calculated_estimate': -2.65, 'calculated_error': 0.01}
# {'calculated_estimate': -1.94, 'calculated_error': 0.01}
# {'calculated_estimate': 1.43, 'calculated_error': 0.01}
# {'calculated_estimate': -1.6, 'calculated_error': 0.01}
# {'calculated_estimate': -3.78, 'calculated_error': 0.01}
# {'calculated_estimate': 0.1, 'calculated_error': 0.01}
# {'calculated_estimate': -4.14, 'calculated_error': 0.01}
# {'calculated_estimate': -1.2, 'calculated_error': 0.01}
# {'calculated_estimate': -1.18, 'calculated_error': 0.01}
# {'calculated_estimate': -2.82, 'calculated_error': 0.01}
# {'calculated_estimate': -5.33, 'calculated_error': 0.01}
# {'calculated_estimate': -0.03, 'calculated_error': 0.01}
# {'calculated_estimate': 0.79, 'calculated_error': 0.01}
# {'calculated_estimate': -1.61, 'calculated_error': 0.01}
# {'calculated_estimate': -2.62, 'calculated_error': 0.01}
# {'calculated_estimate': -2.52, 'calculated_error': 0.01}
# {'calculated_estimate': -3.38, 'calculated_error': 0.01}
# {'calculated_estimate': -0.97, 'calculated_error': 0.01}
# {'calculated_estimate': -1.98, 'calculated_error': 0.01}
# {'calculated_estimate': -0.61, 'calculated_error': 0.01}
# {'calculated_estimate': -4.4, 'calculated_error': 0.01}
# {'calculated_estimate': 0.87, 'calculated_error': 0.0}
# {'calculated_estimate': 5.42, 'calculated_error': 0.01}
# {'calculated_estimate': 2.12, 'calculated_error': 0.0}
# {'calculated_estimate': 2.63, 'calculated_error': 0.0}
# {'calculated_estimate': 0.75, 'calculated_error': 0.01}
# {'calculated_estimate': -0.68, 'calculated_error': 0.0}
# {'calculated_estimate': 0.19, 'calculated_error': 0.0}
# {'calculated_estimate': -0.76, 'calculated_error': 0.0}
# {'calculated_estimate': 0.42, 'calculated_error': 0.0}
# {'calculated_estimate': 1.96, 'calculated_error': 0.01}
# {'calculated_estimate': -0.13, 'calculated_error': 0.0}
# {'calculated_estimate': 0.69, 'calculated_error': 0.0}
# {'calculated_estimate': 2.73, 'calculated_error': 0.01}
# {'calculated_estimate': -0.37, 'calculated_error': 0.0}
# {'calculated_estimate': 5.25, 'calculated_error': 0.01}
# {'calculated_estimate': -0.05, 'calculated_error': 0.01}
# {'calculated_estimate': -0.81, 'calculated_error': 0.0}
# {'calculated_estimate': 1.91, 'calculated_error': 0.0}
# {'calculated_estimate': 2.13, 'calculated_error': 0.0}
# {'calculated_estimate': 0.51, 'calculated_error': 0.0}
# {'calculated_estimate': 0.4, 'calculated_error': 0.01}
# {'calculated_estimate': -8.63, 'calculated_error': 0.01}
# {'calculated_estimate': -4.81, 'calculated_error': 0.01}
# {'calculated_estimate': -0.75, 'calculated_error': 0.01}
# {'calculated_estimate': -2.18, 'calculated_error': 0.01}
# {'calculated_estimate': -0.77, 'calculated_error': 0.01}
# {'calculated_estimate': -0.04, 'calculated_error': 0.01}
# {'calculated_estimate': -1.27, 'calculated_error': 0.01}
# {'calculated_estimate': -5.58, 'calculated_error': 0.01}
# {'calculated_estimate': -0.98, 'calculated_error': 0.01}
# {'calculated_estimate': -2.16, 'calculated_error': 0.01}
# {'calculated_estimate': 1.87, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.01}
# {'calculated_estimate': -2.33, 'calculated_error': 0.01}
# {'calculated_estimate': -2.59, 'calculated_error': 0.01}
# {'calculated_estimate': -1.23, 'calculated_error': 0.01}
# {'calculated_estimate': -3.41, 'calculated_error': 0.01}
# {'calculated_estimate': -1.01, 'calculated_error': 0.01}
# {'calculated_estimate': -3.03, 'calculated_error': 0.01}
# {'calculated_estimate': 0.63, 'calculated_error': 0.01}
# {'calculated_estimate': -3.64, 'calculated_error': 0.01}
# {'calculated_estimate': -2.64, 'calculated_error': 0.01}
# {'calculated_estimate': 1.16, 'calculated_error': 0.01}
# {'calculated_estimate': -0.11, 'calculated_error': 0.01}
# {'calculated_estimate': -0.58, 'calculated_error': 0.01}
# {'calculated_estimate': 0.74, 'calculated_error': 0.01}
# {'calculated_estimate': -1.97, 'calculated_error': 0.01}
# {'calculated_estimate': -4.4, 'calculated_error': 0.01}
# {'calculated_estimate': -2.65, 'calculated_error': 0.01}
# {'calculated_estimate': 1.66, 'calculated_error': 0.01}
# {'calculated_estimate': -4.54, 'calculated_error': 0.01}
# {'calculated_estimate': 0.03, 'calculated_error': 0.01}
# {'calculated_estimate': 0.49, 'calculated_error': 0.01}
# {'calculated_estimate': 0.58, 'calculated_error': 0.01}
# {'calculated_estimate': -2.76, 'calculated_error': 0.01}
# {'calculated_estimate': -1.28, 'calculated_error': 0.01}
# {'calculated_estimate': -3.96, 'calculated_error': 0.01}
# {'calculated_estimate': -0.39, 'calculated_error': 0.01}
# {'calculated_estimate': -4.96, 'calculated_error': 0.01}
# {'calculated_estimate': -3.65, 'calculated_error': 0.01}
# {'calculated_estimate': -1.39, 'calculated_error': 0.01}
# {'calculated_estimate': -1.58, 'calculated_error': 0.01}
# {'calculated_estimate': 1.94, 'calculated_error': 0.01}
# {'calculated_estimate': 1.41, 'calculated_error': 0.01}
# {'calculated_estimate': 2.29, 'calculated_error': 0.01}
# {'calculated_estimate': 2.73, 'calculated_error': 0.0}
# {'calculated_estimate': 1.67, 'calculated_error': 0.01}
# {'calculated_estimate': 2.54, 'calculated_error': 0.01}
# {'calculated_estimate': -0.06, 'calculated_error': 0.0}
# {'calculated_estimate': -2.47, 'calculated_error': 0.0}
# {'calculated_estimate': 1.95, 'calculated_error': 0.0}
# {'calculated_estimate': 3.47, 'calculated_error': 0.0}
# {'calculated_estimate': -0.05, 'calculated_error': 0.0}
# {'calculated_estimate': -2.09, 'calculated_error': 0.01}
# {'calculated_estimate': -1.28, 'calculated_error': 0.01}
# {'calculated_estimate': -0.44, 'calculated_error': 0.01}
# {'calculated_estimate': -1.16, 'calculated_error': 0.01}
# {'calculated_estimate': -3.17, 'calculated_error': 0.01}
# {'calculated_estimate': -5.07, 'calculated_error': 0.01}
# {'calculated_estimate': -2.08, 'calculated_error': 0.01}
# {'calculated_estimate': 0.2, 'calculated_error': 0.01}
# {'calculated_estimate': 5.49, 'calculated_error': 0.01}
# {'calculated_estimate': -0.17, 'calculated_error': 0.01}
# {'calculated_estimate': -0.04, 'calculated_error': 0.01}
# {'calculated_estimate': -3.07, 'calculated_error': 0.01}
# {'calculated_estimate': -2.15, 'calculated_error': 0.01}
# {'calculated_estimate': -0.3, 'calculated_error': 0.01}
# {'calculated_estimate': -2.17, 'calculated_error': 0.01}
# {'calculated_estimate': -3.5, 'calculated_error': 0.01}
# {'calculated_estimate': 0.96, 'calculated_error': 0.01}
# {'calculated_estimate': -5.57, 'calculated_error': 0.01}
# {'calculated_estimate': -1.17, 'calculated_error': 0.01}
# {'calculated_estimate': -3.63, 'calculated_error': 0.01}
# {'calculated_estimate': -4.61, 'calculated_error': 0.01}
# {'calculated_estimate': -2.18, 'calculated_error': 0.01}
# {'calculated_estimate': 0.89, 'calculated_error': 0.01}
# {'calculated_estimate': 0.19, 'calculated_error': 0.01}
# {'calculated_estimate': -1.53, 'calculated_error': 0.01}
# {'calculated_estimate': -1.02, 'calculated_error': 0.0}
# {'calculated_estimate': -0.16, 'calculated_error': 0.0}
# {'calculated_estimate': 0.6, 'calculated_error': 0.01}
# {'calculated_estimate': -4.34, 'calculated_error': 0.01}
# {'calculated_estimate': -4.56, 'calculated_error': 0.01}
# {'calculated_estimate': -3.73, 'calculated_error': 0.01}
# {'calculated_estimate': -2.25, 'calculated_error': 0.01}
# {'calculated_estimate': -2.05, 'calculated_error': 0.01}
# {'calculated_estimate': -1.96, 'calculated_error': 0.01}
# {'calculated_estimate': -2.58, 'calculated_error': 0.01}
# {'calculated_estimate': -0.32, 'calculated_error': 0.01}
# {'calculated_estimate': 1.34, 'calculated_error': 0.01}
# {'calculated_estimate': -3.93, 'calculated_error': 0.01}
# {'calculated_estimate': 0.25, 'calculated_error': 0.01}
# {'calculated_estimate': -5.73, 'calculated_error': 0.01}
# {'calculated_estimate': -2.74, 'calculated_error': 0.01}
# {'calculated_estimate': -3.71, 'calculated_error': 0.01}
# {'calculated_estimate': -2.74, 'calculated_error': 0.01}
# {'calculated_estimate': -0.28, 'calculated_error': 0.01}
# {'calculated_estimate': 0.86, 'calculated_error': 0.01}
# {'calculated_estimate': -1.02, 'calculated_error': 0.0}
# {'calculated_estimate': 2.18, 'calculated_error': 0.0}
# {'calculated_estimate': -1.47, 'calculated_error': 0.01}
# {'calculated_estimate': 2.35, 'calculated_error': 0.01}
# {'calculated_estimate': 3.28, 'calculated_error': 0.0}
# {'calculated_estimate': 0.88, 'calculated_error': 0.01}
# {'calculated_estimate': -0.82, 'calculated_error': 0.01}
# {'calculated_estimate': 2.25, 'calculated_error': 0.01}
# {'calculated_estimate': -0.49, 'calculated_error': 0.01}
# {'calculated_estimate': 0.51, 'calculated_error': 0.0}
# {'calculated_estimate': 1.42, 'calculated_error': 0.0}
# {'calculated_estimate': 1.94, 'calculated_error': 0.0}
# {'calculated_estimate': 0.86, 'calculated_error': 0.01}
# {'calculated_estimate': 0.3, 'calculated_error': 0.0}
# {'calculated_estimate': -0.66, 'calculated_error': 0.0}
# {'calculated_estimate': -1.09, 'calculated_error': 0.0}
# {'calculated_estimate': -1.37, 'calculated_error': 0.0}
# {'calculated_estimate': 2.89, 'calculated_error': 0.0}
# {'calculated_estimate': 1.87, 'calculated_error': 0.0}
# {'calculated_estimate': -1.99, 'calculated_error': 0.01}
# {'calculated_estimate': 5.3, 'calculated_error': 0.01}
# {'calculated_estimate': 1.23, 'calculated_error': 0.01}
# {'calculated_estimate': 2.06, 'calculated_error': 0.01}
# {'calculated_estimate': -2.79, 'calculated_error': 0.0}
# {'calculated_estimate': 4.25, 'calculated_error': 0.01}
# {'calculated_estimate': 2.55, 'calculated_error': 0.01}
# {'calculated_estimate': 1.38, 'calculated_error': 0.01}
# {'calculated_estimate': 1.38, 'calculated_error': 0.01}
# {'calculated_estimate': 1.4, 'calculated_error': 0.0}
# {'calculated_estimate': 0.28, 'calculated_error': 0.01}
# {'calculated_estimate': -0.86, 'calculated_error': 0.01}
# {'calculated_estimate': 9.15, 'calculated_error': 0.01}
# {'calculated_estimate': 0.02, 'calculated_error': 0.0}
# {'calculated_estimate': -1.42, 'calculated_error': 0.0}
# {'calculated_estimate': -2.58, 'calculated_error': 0.01}
# {'calculated_estimate': 2.48, 'calculated_error': 0.0}
# {'calculated_estimate': 2.65, 'calculated_error': 0.01}
# {'calculated_estimate': 0.84, 'calculated_error': 0.01}
# {'calculated_estimate': -1.58, 'calculated_error': 0.01}
# {'calculated_estimate': -2.41, 'calculated_error': 0.01}
# {'calculated_estimate': 0.72, 'calculated_error': 0.01}
# {'calculated_estimate': 0.2, 'calculated_error': 0.01}
# {'calculated_estimate': -0.02, 'calculated_error': 0.01}
# {'calculated_estimate': 3.19, 'calculated_error': 0.01}
# {'calculated_estimate': -0.04, 'calculated_error': 0.0}
# {'calculated_estimate': 7.23, 'calculated_error': 0.01}
# {'calculated_estimate': -1.74, 'calculated_error': 0.0}
# {'calculated_estimate': -0.67, 'calculated_error': 0.0}
# {'calculated_estimate': 0.07, 'calculated_error': 0.0}
# {'calculated_estimate': 1.47, 'calculated_error': 0.01}
# {'calculated_estimate': 1.42, 'calculated_error': 0.01}
# {'calculated_estimate': 2.19, 'calculated_error': 0.0}
# {'calculated_estimate': 1.79, 'calculated_error': 0.0}
# {'calculated_estimate': 2.69, 'calculated_error': 0.01}
# {'calculated_estimate': -3.06, 'calculated_error': 0.01}
# {'calculated_estimate': -1.09, 'calculated_error': 0.0}
# {'calculated_estimate': -3.62, 'calculated_error': 0.01}
# {'calculated_estimate': 3.16, 'calculated_error': 0.01}
# {'calculated_estimate': -0.5, 'calculated_error': 0.01}
# {'calculated_estimate': -0.42, 'calculated_error': 0.0}
# {'calculated_estimate': -0.48, 'calculated_error': 0.0}
# {'calculated_estimate': 0.74, 'calculated_error': 0.0}
# {'calculated_estimate': 1.73, 'calculated_error': 0.0}
# {'calculated_estimate': 0.83, 'calculated_error': 0.0}
# {'calculated_estimate': 1.32, 'calculated_error': 0.01}
# {'calculated_estimate': 2.87, 'calculated_error': 0.01}
# {'calculated_estimate': 1.9, 'calculated_error': 0.01}
# {'calculated_estimate': 1.58, 'calculated_error': 0.01}
# {'calculated_estimate': -1.71, 'calculated_error': 0.02}
# {'calculated_estimate': 4.41, 'calculated_error': 0.0}
# {'calculated_estimate': 1.17, 'calculated_error': 0.0}
# {'calculated_estimate': 2.27, 'calculated_error': 0.0}
# {'calculated_estimate': -1.89, 'calculated_error': 0.0}
# {'calculated_estimate': 0.81, 'calculated_error': 0.01}
# {'calculated_estimate': -0.51, 'calculated_error': 0.01}
# {'calculated_estimate': 1.43, 'calculated_error': 0.01}
# {'calculated_estimate': 1.89, 'calculated_error': 0.01}
# {'calculated_estimate': -1.19, 'calculated_error': 0.0}
# {'calculated_estimate': 0.86, 'calculated_error': 0.0}
# {'calculated_estimate': 0.67, 'calculated_error': 0.0}
# {'calculated_estimate': -0.01, 'calculated_error': 0.0}
# {'calculated_estimate': 6.12, 'calculated_error': 0.01}
# {'calculated_estimate': -0.06, 'calculated_error': 0.0}
# {'calculated_estimate': -1.98, 'calculated_error': 0.0}
# {'calculated_estimate': 0.87, 'calculated_error': 0.01}
# {'calculated_estimate': 0.22, 'calculated_error': 0.0}
# {'calculated_estimate': 2.14, 'calculated_error': 0.0}
# {'calculated_estimate': 0.85, 'calculated_error': 0.0}
# {'calculated_estimate': -1.44, 'calculated_error': 0.0}
# {'calculated_estimate': 3.8, 'calculated_error': 0.01}
# {'calculated_estimate': -0.03, 'calculated_error': 0.0}
# {'calculated_estimate': 0.55, 'calculated_error': 0.01}
# {'calculated_estimate': 0.29, 'calculated_error': 0.0}
# {'calculated_estimate': 1.07, 'calculated_error': 0.01}
# {'calculated_estimate': 2.69, 'calculated_error': 0.01}
# {'calculated_estimate': -2.55, 'calculated_error': 0.0}
# {'calculated_estimate': 0.74, 'calculated_error': 0.0}
# {'calculated_estimate': -0.09, 'calculated_error': 0.0}
# {'calculated_estimate': 0.27, 'calculated_error': 0.0}
# {'calculated_estimate': 0.73, 'calculated_error': 0.01}
# {'calculated_estimate': 0.7, 'calculated_error': 0.01}
# {'calculated_estimate': 1.09, 'calculated_error': 0.0}
# {'calculated_estimate': 0.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.66, 'calculated_error': 0.01}
# {'calculated_estimate': 2.44, 'calculated_error': 0.01}
# {'calculated_estimate': -0.04, 'calculated_error': 0.01}
# {'calculated_estimate': 0.77, 'calculated_error': 0.0}
# {'calculated_estimate': -0.51, 'calculated_error': 0.0}
# {'calculated_estimate': -0.06, 'calculated_error': 0.0}
# {'calculated_estimate': 1.45, 'calculated_error': 0.0}
# {'calculated_estimate': -0.19, 'calculated_error': 0.01}
# {'calculated_estimate': -1.33, 'calculated_error': 0.0}
# {'calculated_estimate': 2.67, 'calculated_error': 0.01}
# {'calculated_estimate': 1.28, 'calculated_error': 0.0}
# {'calculated_estimate': 1.47, 'calculated_error': 0.01}
# {'calculated_estimate': 1.84, 'calculated_error': 0.01}
# {'calculated_estimate': 1.79, 'calculated_error': 0.01}
# {'calculated_estimate': 0.88, 'calculated_error': 0.01}
# {'calculated_estimate': 0.59, 'calculated_error': 0.01}
# {'calculated_estimate': -0.56, 'calculated_error': 0.01}
# {'calculated_estimate': -2.26, 'calculated_error': 0.01}
# {'calculated_estimate': 1.33, 'calculated_error': 0.01}
# {'calculated_estimate': -1.84, 'calculated_error': 0.01}
# {'calculated_estimate': 7.79, 'calculated_error': 0.01}
# {'calculated_estimate': 0.27, 'calculated_error': 0.01}
# {'calculated_estimate': -0.68, 'calculated_error': 0.01}
# {'calculated_estimate': -2.3, 'calculated_error': 0.01}
# {'calculated_estimate': -2.51, 'calculated_error': 0.01}
# {'calculated_estimate': -2.11, 'calculated_error': 0.0}
# {'calculated_estimate': -0.9, 'calculated_error': 0.01}
# {'calculated_estimate': 1.37, 'calculated_error': 0.0}
# {'calculated_estimate': -1.38, 'calculated_error': 0.0}
# {'calculated_estimate': 1.68, 'calculated_error': 0.01}
# {'calculated_estimate': 1.48, 'calculated_error': 0.01}
# {'calculated_estimate': -0.18, 'calculated_error': 0.01}
# {'calculated_estimate': 3.35, 'calculated_error': 0.01}
# {'calculated_estimate': -3.8, 'calculated_error': 0.01}
# {'calculated_estimate': 0.08, 'calculated_error': 0.01}
# {'calculated_estimate': -0.27, 'calculated_error': 0.01}
# {'calculated_estimate': 1.3, 'calculated_error': 0.01}
# {'calculated_estimate': -0.96, 'calculated_error': 0.01}
# {'calculated_estimate': -1.03, 'calculated_error': 0.01}
# {'calculated_estimate': -0.0, 'calculated_error': 0.01}
# {'calculated_estimate': 0.61, 'calculated_error': 0.01}
# {'calculated_estimate': -0.68, 'calculated_error': 0.01}
# {'calculated_estimate': 1.78, 'calculated_error': 0.0}
# {'calculated_estimate': 0.87, 'calculated_error': 0.01}
# {'calculated_estimate': -4.64, 'calculated_error': 0.01}
# {'calculated_estimate': -1.25, 'calculated_error': 0.01}
# {'calculated_estimate': 1.31, 'calculated_error': 0.01}
# {'calculated_estimate': 2.24, 'calculated_error': 0.0}
# {'calculated_estimate': -3.1, 'calculated_error': 0.0}
# {'calculated_estimate': 1.05, 'calculated_error': 0.0}
# {'calculated_estimate': 1.06, 'calculated_error': 0.01}
# {'calculated_estimate': -1.73, 'calculated_error': 0.0}
# {'calculated_estimate': -1.59, 'calculated_error': 0.0}
# {'calculated_estimate': 0.1, 'calculated_error': 0.0}
# {'calculated_estimate': -0.61, 'calculated_error': 0.0}
# {'calculated_estimate': 4.5, 'calculated_error': 0.01}
# {'calculated_estimate': 1.31, 'calculated_error': 0.01}
# {'calculated_estimate': -0.79, 'calculated_error': 0.0}
# {'calculated_estimate': -0.59, 'calculated_error': 0.0}
# {'calculated_estimate': 1.02, 'calculated_error': 0.0}
# {'calculated_estimate': 2.48, 'calculated_error': 0.0}
# {'calculated_estimate': 0.07, 'calculated_error': 0.0}
# {'calculated_estimate': 4.03, 'calculated_error': 0.01}
# {'calculated_estimate': -1.99, 'calculated_error': 0.01}
# {'calculated_estimate': -0.19, 'calculated_error': 0.0}
# {'calculated_estimate': 0.73, 'calculated_error': 0.01}
# {'calculated_estimate': 1.2, 'calculated_error': 0.01}
# {'calculated_estimate': 2.63, 'calculated_error': 0.01}
# {'calculated_estimate': -0.82, 'calculated_error': 0.0}
# {'calculated_estimate': 0.62, 'calculated_error': 0.01}
# {'calculated_estimate': -1.14, 'calculated_error': 0.0}
# {'calculated_estimate': -1.0, 'calculated_error': 0.01}
# {'calculated_estimate': -2.91, 'calculated_error': 0.01}
# {'calculated_estimate': 0.12, 'calculated_error': 0.0}
# {'calculated_estimate': 0.01, 'calculated_error': 0.01}
# {'calculated_estimate': 1.85, 'calculated_error': 0.0}
# {'calculated_estimate': 0.23, 'calculated_error': 0.0}
# {'calculated_estimate': -2.42, 'calculated_error': 0.01}
# {'calculated_estimate': -0.23, 'calculated_error': 0.0}
# {'calculated_estimate': -4.19, 'calculated_error': 0.01}
# {'calculated_estimate': -1.41, 'calculated_error': 0.0}
# {'calculated_estimate': 2.22, 'calculated_error': 0.0}
# {'calculated_estimate': 0.58, 'calculated_error': 0.01}
# ...
# {'calculated_estimate': -1.09, 'calculated_error': 0.01}
# {'calculated_estimate': 0.47, 'calculated_error': 0.0}
# {'calculated_estimate': 1.96, 'calculated_error': 0.01}
# {'calculated_estimate': 2.32, 'calculated_error': 0.0}
# {'calculated_estimate': -0.03, 'calculated_error': 0.01}
# {'calculated_estimate': 3.25, 'calculated_error': 0.0}
# {'calculated_estimate': 1.05, 'calculated_error': 0.01}
# {'calculated_estimate': 0.46, 'calculated_error': 0.01}
# {'calculated_estimate': 1.52, 'calculated_error': 0.0}
# {'calculated_estimate': 1.35, 'calculated_error': 0.01}
# {'calculated_estimate': 2.72, 'calculated_error': 0.01}
# {'calculated_estimate': 1.77, 'calculated_error': 0.01}
# {'calculated_estimate': -2.34, 'calculated_error': 0.01}
# {'calculated_estimate': -0.74, 'calculated_error': 0.01}
# {'calculated_estimate': -0.66, 'calculated_error': 0.0}
# {'calculated_estimate': 1.31, 'calculated_error': 0.0}
# {'calculated_estimate': 0.79, 'calculated_error': 0.01}
# {'calculated_estimate': 2.11, 'calculated_error': 0.01}
# {'calculated_estimate': 2.64, 'calculated_error': 0.01}
# {'calculated_estimate': 1.62, 'calculated_error': 0.01}
# {'calculated_estimate': 3.93, 'calculated_error': 0.01}
# {'calculated_estimate': -0.18, 'calculated_error': 0.01}
# {'calculated_estimate': -1.19, 'calculated_error': 0.01}
# {'calculated_estimate': 1.07, 'calculated_error': 0.0}
# {'calculated_estimate': 1.73, 'calculated_error': 0.01}
# {'calculated_estimate': 1.13, 'calculated_error': 0.01}
# {'calculated_estimate': 2.06, 'calculated_error': 0.0}
# {'calculated_estimate': -0.23, 'calculated_error': 0.01}
# {'calculated_estimate': 2.16, 'calculated_error': 0.01}
# {'calculated_estimate': -1.36, 'calculated_error': 0.0}
# {'calculated_estimate': 1.0, 'calculated_error': 0.01}
# {'calculated_estimate': 0.58, 'calculated_error': 0.01}
# {'calculated_estimate': -1.79, 'calculated_error': 0.0}
# {'calculated_estimate': 3.26, 'calculated_error': 0.01}
# {'calculated_estimate': 2.8, 'calculated_error': 0.01}
# {'calculated_estimate': -2.85, 'calculated_error': 0.01}
# {'calculated_estimate': 2.55, 'calculated_error': 0.01}
# {'calculated_estimate': 0.78, 'calculated_error': 0.0}
# {'calculated_estimate': 1.04, 'calculated_error': 0.01}
# {'calculated_estimate': -0.92, 'calculated_error': 0.01}
# {'calculated_estimate': 2.26, 'calculated_error': 0.01}
# {'calculated_estimate': 2.45, 'calculated_error': 0.01}
# {'calculated_estimate': 2.68, 'calculated_error': 0.01}
# {'calculated_estimate': 0.4, 'calculated_error': 0.0}
# {'calculated_estimate': 1.37, 'calculated_error': 0.01}
# {'calculated_estimate': -2.07, 'calculated_error': 0.0}
# {'calculated_estimate': 2.75, 'calculated_error': 0.0}
# {'calculated_estimate': -3.09, 'calculated_error': 0.0}
# {'calculated_estimate': 3.82, 'calculated_error': 0.01}
# {'calculated_estimate': 5.09, 'calculated_error': 0.01}
# {'calculated_estimate': 2.12, 'calculated_error': 0.01}
# {'calculated_estimate': -4.35, 'calculated_error': 0.01}
# {'calculated_estimate': 2.27, 'calculated_error': 0.01}
# {'calculated_estimate': 8.95, 'calculated_error': 0.01}
# {'calculated_estimate': 2.86, 'calculated_error': 0.01}
# {'calculated_estimate': 2.28, 'calculated_error': 0.01}
# {'calculated_estimate': 1.25, 'calculated_error': 0.01}
# {'calculated_estimate': -0.87, 'calculated_error': 0.01}
# {'calculated_estimate': -0.47, 'calculated_error': 0.0}
# {'calculated_estimate': 0.87, 'calculated_error': 0.01}
# {'calculated_estimate': 0.13, 'calculated_error': 0.01}
# {'calculated_estimate': -1.13, 'calculated_error': 0.01}
# {'calculated_estimate': -1.04, 'calculated_error': 0.0}
# {'calculated_estimate': 3.53, 'calculated_error': 0.01}
# {'calculated_estimate': -2.49, 'calculated_error': 0.01}
# {'calculated_estimate': -1.38, 'calculated_error': 0.01}
# {'calculated_estimate': 3.26, 'calculated_error': 0.01}
# {'calculated_estimate': 3.02, 'calculated_error': 0.0}
# {'calculated_estimate': 1.95, 'calculated_error': 0.01}
# {'calculated_estimate': 1.91, 'calculated_error': 0.01}
# {'calculated_estimate': -1.18, 'calculated_error': 0.01}
# {'calculated_estimate': 5.35, 'calculated_error': 0.01}
# {'calculated_estimate': -0.63, 'calculated_error': 0.01}
# {'calculated_estimate': 1.6, 'calculated_error': 0.01}
# {'calculated_estimate': -0.1, 'calculated_error': 0.01}
# {'calculated_estimate': 1.99, 'calculated_error': 0.0}
# {'calculated_estimate': -1.12, 'calculated_error': 0.01}
# {'calculated_estimate': 0.4, 'calculated_error': 0.0}
# {'calculated_estimate': -1.74, 'calculated_error': 0.0}
# {'calculated_estimate': 1.04, 'calculated_error': 0.01}
# {'calculated_estimate': -2.42, 'calculated_error': 0.01}
# {'calculated_estimate': -1.64, 'calculated_error': 0.0}
# {'calculated_estimate': 0.4, 'calculated_error': 0.0}
# {'calculated_estimate': 0.71, 'calculated_error': 0.01}
# {'calculated_estimate': 3.51, 'calculated_error': 0.0}
# {'calculated_estimate': 1.75, 'calculated_error': 0.0}
# {'calculated_estimate': 0.54, 'calculated_error': 0.01}
# {'calculated_estimate': 3.2, 'calculated_error': 0.01}
# {'calculated_estimate': -0.97, 'calculated_error': 0.01}
# {'calculated_estimate': 3.11, 'calculated_error': 0.0}
# {'calculated_estimate': 2.38, 'calculated_error': 0.0}
# {'calculated_estimate': -3.02, 'calculated_error': 0.01}
# {'calculated_estimate': 4.17, 'calculated_error': 0.01}
# {'calculated_estimate': -1.73, 'calculated_error': 0.01}
# {'calculated_estimate': -2.15, 'calculated_error': 0.01}
# {'calculated_estimate': 0.71, 'calculated_error': 0.01}
# {'calculated_estimate': -1.63, 'calculated_error': 0.01}
# {'calculated_estimate': 3.43, 'calculated_error': 0.01}
# {'calculated_estimate': 0.52, 'calculated_error': 0.01}
# {'calculated_estimate': -3.19, 'calculated_error': 0.01}
# {'calculated_estimate': 10.8, 'calculated_error': 0.01}
# {'calculated_estimate': 0.23, 'calculated_error': 0.01}
# {'calculated_estimate': -3.68, 'calculated_error': 0.01}
# {'calculated_estimate': 1.01, 'calculated_error': 0.01}
# {'calculated_estimate': 2.06, 'calculated_error': 0.01}
# {'calculated_estimate': 1.75, 'calculated_error': 0.01}
# {'calculated_estimate': -1.44, 'calculated_error': 0.01}
# {'calculated_estimate': -0.39, 'calculated_error': 0.01}
# {'calculated_estimate': -6.96, 'calculated_error': 0.01}
# {'calculated_estimate': 1.99, 'calculated_error': 0.01}
# {'calculated_estimate': -1.32, 'calculated_error': 0.01}
# {'calculated_estimate': 4.66, 'calculated_error': 0.01}
# {'calculated_estimate': -2.27, 'calculated_error': 0.01}
# {'calculated_estimate': -1.52, 'calculated_error': 0.01}
# {'calculated_estimate': -0.43, 'calculated_error': 0.01}
# {'calculated_estimate': 2.27, 'calculated_error': 0.01}
# {'calculated_estimate': -0.49, 'calculated_error': 0.0}
# {'calculated_estimate': 2.11, 'calculated_error': 0.01}
# {'calculated_estimate': 3.22, 'calculated_error': 0.01}
# {'calculated_estimate': 2.42, 'calculated_error': 0.01}
# {'calculated_estimate': -35.44, 'calculated_error': 0.01}
# {'calculated_estimate': 0.48, 'calculated_error': 0.01}
# {'calculated_estimate': 2.86, 'calculated_error': 0.01}
# {'calculated_estimate': 2.45, 'calculated_error': 0.01}
# {'calculated_estimate': 3.15, 'calculated_error': 0.0}
# {'calculated_estimate': -0.29, 'calculated_error': 0.01}
# {'calculated_estimate': 3.15, 'calculated_error': 0.01}
# {'calculated_estimate': 1.3, 'calculated_error': 0.0}
# {'calculated_estimate': 0.9, 'calculated_error': 0.0}
# {'calculated_estimate': -2.91, 'calculated_error': 0.01}
# {'calculated_estimate': -0.49, 'calculated_error': 0.01}
# {'calculated_estimate': 2.15, 'calculated_error': 0.0}
# {'calculated_estimate': 0.23, 'calculated_error': 0.01}
# {'calculated_estimate': -0.47, 'calculated_error': 0.01}
# {'calculated_estimate': -0.03, 'calculated_error': 0.01}
# {'calculated_estimate': 3.32, 'calculated_error': 0.0}
# {'calculated_estimate': 0.89, 'calculated_error': 0.01}
# {'calculated_estimate': -2.98, 'calculated_error': 0.01}
# {'calculated_estimate': 1.01, 'calculated_error': 0.01}
# {'calculated_estimate': -2.05, 'calculated_error': 0.01}
# {'calculated_estimate': 0.1, 'calculated_error': 0.0}
# {'calculated_estimate': -1.63, 'calculated_error': 0.0}
# {'calculated_estimate': -0.52, 'calculated_error': 0.0}
# {'calculated_estimate': 4.85, 'calculated_error': 0.01}
# {'calculated_estimate': 4.38, 'calculated_error': 0.01}
# {'calculated_estimate': 4.08, 'calculated_error': 0.01}
# {'calculated_estimate': 1.37, 'calculated_error': 0.0}
# {'calculated_estimate': 1.63, 'calculated_error': 0.01}
# {'calculated_estimate': -1.26, 'calculated_error': 0.01}
# {'calculated_estimate': 0.53, 'calculated_error': 0.01}
# {'calculated_estimate': -0.75, 'calculated_error': 0.0}
# {'calculated_estimate': -0.68, 'calculated_error': 0.0}
# {'calculated_estimate': 1.51, 'calculated_error': 0.01}
# {'calculated_estimate': 1.47, 'calculated_error': 0.01}
# {'calculated_estimate': 0.57, 'calculated_error': 0.01}
# {'calculated_estimate': -0.51, 'calculated_error': 0.01}
# {'calculated_estimate': 4.8, 'calculated_error': 0.0}
# {'calculated_estimate': -5.6, 'calculated_error': 0.01}
# {'calculated_estimate': -0.37, 'calculated_error': 0.0}
# {'calculated_estimate': 1.03, 'calculated_error': 0.01}
# {'calculated_estimate': -2.15, 'calculated_error': 0.0}
# {'calculated_estimate': -1.02, 'calculated_error': 0.01}
# {'calculated_estimate': 2.67, 'calculated_error': 0.01}
# {'calculated_estimate': 5.02, 'calculated_error': 0.01}
# {'calculated_estimate': 5.28, 'calculated_error': 0.01}
# {'calculated_estimate': 8.81, 'calculated_error': 0.01}
# {'calculated_estimate': 7.91, 'calculated_error': 0.01}
# {'calculated_estimate': 7.23, 'calculated_error': 0.01}
# {'calculated_estimate': 4.56, 'calculated_error': 0.01}
# {'calculated_estimate': 4.0, 'calculated_error': 0.01}
# {'calculated_estimate': 14.03, 'calculated_error': 0.01}
# {'calculated_estimate': 10.13, 'calculated_error': 0.01}
# {'calculated_estimate': 9.32, 'calculated_error': 0.01}
# {'calculated_estimate': 12.89, 'calculated_error': 0.01}
# {'calculated_estimate': 5.94, 'calculated_error': 0.01}
# {'calculated_estimate': 5.19, 'calculated_error': 0.01}
# {'calculated_estimate': 0.28, 'calculated_error': 0.01}
# {'calculated_estimate': -4.93, 'calculated_error': 0.0}
# {'calculated_estimate': 5.76, 'calculated_error': 0.01}
# {'calculated_estimate': 5.1, 'calculated_error': 0.01}
# {'calculated_estimate': 5.48, 'calculated_error': 0.01}
# {'calculated_estimate': 4.05, 'calculated_error': 0.01}
# {'calculated_estimate': -2.03, 'calculated_error': 0.0}
# {'calculated_estimate': 0.12, 'calculated_error': 0.01}
# {'calculated_estimate': 6.88, 'calculated_error': 0.01}
# {'calculated_estimate': 5.89, 'calculated_error': 0.01}
# {'calculated_estimate': 7.05, 'calculated_error': 0.01}
# {'calculated_estimate': 3.06, 'calculated_error': 0.01}
# {'calculated_estimate': 1.95, 'calculated_error': 0.0}
# {'calculated_estimate': -0.23, 'calculated_error': 0.0}
# {'calculated_estimate': 1.09, 'calculated_error': 0.0}
# {'calculated_estimate': 0.2, 'calculated_error': 0.01}
# {'calculated_estimate': 1.25, 'calculated_error': 0.01}
# {'calculated_estimate': 1.36, 'calculated_error': 0.01}
# {'calculated_estimate': -1.75, 'calculated_error': 0.01}
# {'calculated_estimate': -0.57, 'calculated_error': 0.0}
# {'calculated_estimate': 4.52, 'calculated_error': 0.01}
# {'calculated_estimate': 1.61, 'calculated_error': 0.01}
# {'calculated_estimate': 0.59, 'calculated_error': 0.01}
# {'calculated_estimate': 2.01, 'calculated_error': 0.0}
# {'calculated_estimate': 5.97, 'calculated_error': 0.01}
# {'calculated_estimate': 1.11, 'calculated_error': 0.01}
# {'calculated_estimate': 3.81, 'calculated_error': 0.01}
# {'calculated_estimate': -3.1, 'calculated_error': 0.01}
# {'calculated_estimate': 3.01, 'calculated_error': 0.01}
# {'calculated_estimate': -1.64, 'calculated_error': 0.01}
# {'calculated_estimate': 1.1, 'calculated_error': 0.0}
# {'calculated_estimate': 2.54, 'calculated_error': 0.0}
# {'calculated_estimate': 1.88, 'calculated_error': 0.01}
# {'calculated_estimate': 7.32, 'calculated_error': 0.01}
# {'calculated_estimate': 7.88, 'calculated_error': 0.01}
# {'calculated_estimate': 5.07, 'calculated_error': 0.01}
# {'calculated_estimate': -0.21, 'calculated_error': 0.01}
# {'calculated_estimate': -4.35, 'calculated_error': 0.01}
# {'calculated_estimate': -3.85, 'calculated_error': 0.01}
# {'calculated_estimate': 4.09, 'calculated_error': 0.01}
# {'calculated_estimate': 5.72, 'calculated_error': 0.01}
# {'calculated_estimate': 10.21, 'calculated_error': 0.01}
# {'calculated_estimate': -0.7, 'calculated_error': 0.01}
# {'calculated_estimate': 0.03, 'calculated_error': 0.01}
# {'calculated_estimate': 5.24, 'calculated_error': 0.01}
# {'calculated_estimate': 0.06, 'calculated_error': 0.01}
# {'calculated_estimate': 3.76, 'calculated_error': 0.01}
# {'calculated_estimate': 1.02, 'calculated_error': 0.0}
# {'calculated_estimate': -1.0, 'calculated_error': 0.01}
# {'calculated_estimate': -0.0, 'calculated_error': 0.0}
# {'calculated_estimate': -1.09, 'calculated_error': 0.01}
# {'calculated_estimate': -3.46, 'calculated_error': 0.01}
# {'calculated_estimate': 3.79, 'calculated_error': 0.01}
# {'calculated_estimate': -0.83, 'calculated_error': 0.0}
# {'calculated_estimate': 2.49, 'calculated_error': 0.01}
# {'calculated_estimate': -0.05, 'calculated_error': 0.01}
# {'calculated_estimate': 0.8, 'calculated_error': 0.01}
# {'calculated_estimate': -0.41, 'calculated_error': 0.01}
# {'calculated_estimate': 2.76, 'calculated_error': 0.01}
# {'calculated_estimate': 1.7, 'calculated_error': 0.01}
# {'calculated_estimate': -2.27, 'calculated_error': 0.01}
# {'calculated_estimate': 0.92, 'calculated_error': 0.01}
# {'calculated_estimate': -0.03, 'calculated_error': 0.01}
# {'calculated_estimate': 2.23, 'calculated_error': 0.01}
# {'calculated_estimate': 0.14, 'calculated_error': 0.0}
# {'calculated_estimate': -1.18, 'calculated_error': 0.01}
# {'calculated_estimate': -0.34, 'calculated_error': 0.0}
# {'calculated_estimate': -1.59, 'calculated_error': 0.01}
# {'calculated_estimate': -1.42, 'calculated_error': 0.01}
# {'calculated_estimate': 3.21, 'calculated_error': 0.01}
# {'calculated_estimate': -2.98, 'calculated_error': 0.01}
# {'calculated_estimate': 2.9, 'calculated_error': 0.01}
# {'calculated_estimate': 0.4, 'calculated_error': 0.01}
# {'calculated_estimate': 0.94, 'calculated_error': 0.0}
# {'calculated_estimate': 0.36, 'calculated_error': 0.0}
# {'calculated_estimate': 2.82, 'calculated_error': 0.01}
# {'calculated_estimate': 1.08, 'calculated_error': 0.01}
# {'calculated_estimate': -1.69, 'calculated_error': 0.01}
# {'calculated_estimate': 6.85, 'calculated_error': 0.01}
# {'calculated_estimate': 0.78, 'calculated_error': 0.01}
# {'calculated_estimate': 3.27, 'calculated_error': 0.01}
# {'calculated_estimate': 0.38, 'calculated_error': 0.01}
# {'calculated_estimate': 3.0, 'calculated_error': 0.0}
# {'calculated_estimate': -4.1, 'calculated_error': 0.01}
# {'calculated_estimate': -0.09, 'calculated_error': 0.01}
# {'calculated_estimate': 0.84, 'calculated_error': 0.0}
# {'calculated_estimate': -0.5, 'calculated_error': 0.01}
# {'calculated_estimate': 6.82, 'calculated_error': 0.01}
# {'calculated_estimate': 3.5, 'calculated_error': 0.01}
# {'calculated_estimate': 0.2, 'calculated_error': 0.01}
# {'calculated_estimate': 3.24, 'calculated_error': 0.01}
# {'calculated_estimate': -1.41, 'calculated_error': 0.01}
# {'calculated_estimate': 5.05, 'calculated_error': 0.01}
# {'calculated_estimate': -7.81, 'calculated_error': 0.01}
# {'calculated_estimate': 0.56, 'calculated_error': 0.01}
# {'calculated_estimate': 1.44, 'calculated_error': 0.01}
# {'calculated_estimate': 1.81, 'calculated_error': 0.01}
# {'calculated_estimate': 1.57, 'calculated_error': 0.01}
# {'calculated_estimate': 6.01, 'calculated_error': 0.01}
# {'calculated_estimate': 4.24, 'calculated_error': 0.01}
# {'calculated_estimate': 1.12, 'calculated_error': 0.01}
# {'calculated_estimate': 3.76, 'calculated_error': 0.01}
# {'calculated_estimate': -8.04, 'calculated_error': 0.01}
# {'calculated_estimate': 2.21, 'calculated_error': 0.01}
# {'calculated_estimate': 4.84, 'calculated_error': 0.01}
# {'calculated_estimate': 5.92, 'calculated_error': 0.01}
# {'calculated_estimate': 0.86, 'calculated_error': 0.01}
# {'calculated_estimate': -0.56, 'calculated_error': 0.01}
# {'calculated_estimate': 2.14, 'calculated_error': 0.01}

# %%
import pandas as pd

# タブ区切りのファイルを読み込む
df = pd.read_csv('./cinnabar_output_core4_R2.dat', delimiter='\t')

# 'ligand'カラムから'lig_'を取り除いた新しいカラム'ligand_num'を作成
df['ligand_num'] = df['ligand'].str.replace('lig_', '')

# カンマ区切りのCSVファイルとして保存
df.to_csv('./cinnabar_output_core4_R2.csv', index=False)
